# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
import random
import os
from collections import deque
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR

# Configuration
TICKER = 'BTCUSDT'
SEQ_LENGTH = 60
PREDICTION_STEPS = 10
INITIAL_BALANCE = 10000.0
TRADE_FEE_RATE = 0.0001
MIN_TRADE_AMOUNT = 10
GRID_COUNT = 20
EPOCHS = 0
EPISODES = 100
BATCH_SIZE = 256
MEMORY_SIZE = 10000
GAMMA = 0.95
EPSILON_DECAY = 0.9999995
MIN_EPSILON = 0.001
LEARNING_RATE = 0.0001
TARGET_UPDATE_FREQ = 100
LSTM_LEARNING_RATE = 1000
LSTM_PATH = 'lstm_predictor_fixed_grid2.pth'
DOUBLE_DQN_PATH = 'doubledqn_agent_fixed_grid.pth'

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

class DataProcessor:
    def __init__(self, filepath):
        self.data = pd.read_csv(filepath)
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        
    def preprocess(self):
        df = self.data.copy()
        # Feature engineering
        df['Returns'] = df['close'].pct_change()
        df['Volatility'] = df['Returns'].rolling(20).std()
        df.dropna(inplace=True)
        
        # Scale features
        scaled = self.scaler.fit_transform(df[['open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility']])
        return scaled, df['close'].values
    
    def create_sequences(self, data, target):
        X, y = [], []
        for i in range(len(data) - SEQ_LENGTH - PREDICTION_STEPS):
            X.append(data[i:i+SEQ_LENGTH])
            y.append(target[i+SEQ_LENGTH+PREDICTION_STEPS-1])
        return np.array(X), np.array(y)
    
class AdaptiveLRScheduler:
    def __init__(self, optimizer, patience=5, factor=0.5, min_lr=1e-20, max_lr=1.0, threshold=1e-4, fluctuation_threshold=0.2):
        self.optimizer = optimizer
        self.patience = patience
        self.factor = factor
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.threshold = threshold
        self.fluctuation_threshold = fluctuation_threshold
        
        self.loss_history = []
        self.wait = 0
        self.best_loss = float('inf')
    def step(self, current_loss):
        self.loss_history.append(current_loss)

        if len(self.loss_history) > 2:
            fluctuation = abs(self.loss_history[-1] - self.loss_history[-2]) / (self.loss_history[-2] + 1e-8)
        else:
            fluctuation = 0

        # 1. Detect fluctuations
        if fluctuation > self.fluctuation_threshold:
            self._reduce_lr("High fluctuation detected")
            self.wait = 0
            return

        # 2. Detect improvement
        improvement = self.best_loss - current_loss
        if improvement > self.threshold:
            self.best_loss = current_loss
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self._reduce_lr("Loss plateau detected")
                self.wait = 0

    def _reduce_lr(self, reason):
        for param_group in self.optimizer.param_groups:
            old_lr = param_group['lr']
            new_lr = max(old_lr * self.factor, self.min_lr)
            param_group['lr'] = new_lr
        print(f"[LR SCHEDULER] {reason}. LR reduced to: {new_lr:.10f}")

class LSTMPredictor(nn.Module):
    def __init__(self, input_size, hidden_size=50, num_layers=2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

    def save(self, path, best_loss):
        torch.save({
            'model_state_dict': self.state_dict(),
            'best_loss': best_loss
        }, path)
        print(best_loss)
    def load(self, path, map_location=None):
        if os.path.exists(path):
            checkpoint = torch.load(path, map_location=map_location)
            self.load_state_dict(checkpoint['model_state_dict'])
            self.eval()  # Optional: switch to eval mode.
            return checkpoint.get('best_loss', float('inf'))
        else:
            print(f"⚠️ Warning: No checkpoint found at {path}.")
            return float('inf')


class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class TradingEnvironment:
    def __init__(self, data, prices, predictor, grids):
        self.data = data
        self.prices = prices
        self.predictor = predictor
        self.grids = grids
        self.reset()
        
    def reset(self):
        self.current_step = SEQ_LENGTH
        self.balance = INITIAL_BALANCE
        self.btc_held = 0.0
        self.portfolio_value = [INITIAL_BALANCE]
        self.trades = []
        self.done = False
        self.prev_portfolio_value = INITIAL_BALANCE   # <-- Add this line
        return self.get_state()

    
    def get_state(self):
        current_data = self.data[self.current_step]
        price = self.prices[self.current_step]
        grid_position = np.digitize(price, self.grids) / GRID_COUNT
        
        # Get prediction
        with torch.no_grad():
            seq_data = self.data[self.current_step-SEQ_LENGTH:self.current_step]
            seq_tensor = torch.tensor(seq_data[np.newaxis, ...], dtype=torch.float32).to(device)
            prediction = self.predictor(seq_tensor).cpu().item()
        
        return np.array([
            *current_data,
            self.balance / INITIAL_BALANCE,
            self.btc_held * price / INITIAL_BALANCE,
            grid_position,
            prediction / price
        ])
    
    def execute_trade(self, action, amount):
        fee = amount * TRADE_FEE_RATE
        return amount - fee
    
    def step(self, action):
        """
        Actions:
        0 = hold
        1 = buy
        2 = sell
        """
        price = self.prices[self.current_step]
        grid_position = np.digitize(price, self.grids) / len(self.grids)  # normalized 0-1
        
        trade_amount = 0
        min_trade_usd = 10  # Minimum USD amount per trade, for example
        min_trade_btc = 0.001  # Minimum BTC amount per trade
        
        if action == 1:  # Buy
            # Buy more when price is near lower grids (grid_position close to 0)
            multiplier = max(0.1, 1 - grid_position)  # from 1 at bottom grid to 0.1 near top grid
            amount_to_spend = self.balance * multiplier
            trade_amount = max(amount_to_spend, min_trade_usd)
            
            btc_to_buy = trade_amount / price
            btc_to_buy = min(btc_to_buy, self.balance / price)  # Can't buy more than balance allows
            btc_to_buy = max(btc_to_buy, min_trade_btc)
            
            # Execute buy
            cost = btc_to_buy * price
            if cost <= self.balance:
                self.balance -= cost
                self.btc_held += btc_to_buy
                self.trades.append(('buy', price, self.current_step))
        
        elif action == 2:  # Sell
            # Sell more when price is near upper grids (grid_position close to 1)
            multiplier = max(0.1, grid_position)  # from 0.1 at bottom grid to 1 near top grid
            btc_to_sell = self.btc_held * multiplier
            btc_to_sell = max(btc_to_sell, min_trade_btc)
            
            # Execute sell
            if btc_to_sell <= self.btc_held:
                revenue = btc_to_sell * price
                self.balance += revenue
                self.btc_held -= btc_to_sell
                self.trades.append(('sell', price, self.current_step))
        
        else:
            # Hold - no trade
            pass
        
        # Update portfolio value, rewards, etc.
        self.current_step += 1
        self.done = self.current_step >= len(self.prices) - 1
        
        portfolio_value = self.balance + self.btc_held * price
        reward = portfolio_value - self.prev_portfolio_value
        self.prev_portfolio_value = portfolio_value
        
        next_state = self.get_state()
        
        return next_state, reward, self.done, portfolio_value

class AdaptiveTradingEnvironment(TradingEnvironment):
    def __init__(self, data, prices, predictor, initial_grids, 
                 recalibration_interval=100, lookback_window=500):
        self.original_grids = initial_grids
        self.recalibration_interval = recalibration_interval
        self.lookback_window = lookback_window
        self.steps_since_recalibration = 0
        self.grid_history = [initial_grids.copy()]
        super().__init__(data, prices, predictor, initial_grids)
    def reset(self):
        self.steps_since_recalibration = 0
        self.grids = self.original_grids.copy()
        return super().reset()
    
    def recalculate_grids(self):
        """Recalculate grids based on recent price window"""
        start_idx = max(0, self.current_step - self.lookback_window)
        recent_prices = self.prices[start_idx:self.current_step]
        
        # Use percentiles to avoid extreme values
        low = np.percentile(recent_prices, 10)  # 10th percentile
        high = np.percentile(recent_prices, 90)  # 90th percentile
        
        # Safety checks
        if high <= low:
            high = low * 1.2  # Prevent invalid range
            
        new_grids = np.linspace(low, high, num=GRID_COUNT+1)[1:-1]
        self.grid_history.append(new_grids)
        return new_grids
    
    def step(self, action):
        # Recalculate grids periodically
        self.steps_since_recalibration += 1
        if self.steps_since_recalibration >= self.recalibration_interval:
            self.grids = self.recalculate_grids()
            self.steps_since_recalibration = 0
        
        return super().step(action)
class DoubleDQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=MEMORY_SIZE)
        self.epsilon = 1
        self.model = DQN(state_size, action_size).to(device)
        self.target_model = DQN(state_size, action_size).to(device)
        self.target_model.load_state_dict(self.model.state_dict())
        self.target_model.eval()
        self.optimizer = optim.Adam(self.model.parameters(), lr=LEARNING_RATE)
        self.scheduler = StepLR(self.optimizer, step_size=5, gamma=0.95)
        self.criterion = nn.MSELoss()
        self.steps = 0
    
    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            with torch.no_grad():
                q_values = self.model(state_tensor)
            return torch.argmax(q_values).item()
    
    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return

        minibatch = random.sample(self.memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.tensor(np.array(states), dtype=torch.float32).to(device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32).to(device)
        dones = torch.tensor(dones, dtype=torch.float32).to(device)

        # Q(s,a)
        current_q = self.model(states).gather(1, actions)

        # Double DQN target
        with torch.no_grad():
            # Select best action using online network
            best_actions = self.model(next_states).argmax(1, keepdim=True)
            # Evaluate using target network
            next_q = self.target_model(next_states).gather(1, best_actions)
            target_q = rewards.unsqueeze(1) + (1 - dones.unsqueeze(1)) * GAMMA * next_q

        loss = self.criterion(current_q, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()

        self.steps += 1
        if self.steps % TARGET_UPDATE_FREQ == 0:
            self.update_target_model()

        if self.epsilon > MIN_EPSILON:
            self.epsilon *= EPSILON_DECAY

    
    def save(self, path):
        torch.save(self.model.state_dict(), path)
    
    def load(self, path):
        self.model.load_state_dict(torch.load(path))

def create_grids(prices, num_grids=GRID_COUNT):
    low = np.percentile(prices, 5)
    high = np.percentile(prices, 95)
    return np.linspace(low, high, num=num_grids+1)[1:-1]

def plot_grid_history(env):
    plt.figure(figsize=(12, 6))
    plt.plot(env.prices, label='Price', alpha=0.5)
    
    # Plot all grid levels over time
    for i, grids in enumerate(env.grid_history):
        if i % 5 == 0:  # Plot every 5th recalibration for clarity
            step = i * env.recalibration_interval
            for grid in grids:
                plt.axhline(y=grid, color='gray', alpha=0.1)
    
    plt.title('Adaptive Grid Levels Over Time')
    plt.legend()
    plt.show()
    
def train_lstm(X_train, y_train, input_size, epochs=20, batch_size=64):
    model = LSTMPredictor(input_size).to(device)
    best_val_loss = model.load(LSTM_PATH, map_location=device)
    print('loaded', best_val_loss)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=LSTM_LEARNING_RATE)
    scheduler = AdaptiveLRScheduler(optimizer, patience=10, factor=0.5)
    # Convert to tensors
    X_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1).to(device)
    
    dataset = TensorDataset(X_tensor, y_tensor)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for X_batch, y_batch in loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss/len(loader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
        scheduler.step(avg_loss)
        if avg_loss < best_val_loss:
            best_val_loss = avg_loss
            model.save(LSTM_PATH, best_val_loss)
            print('saved')
    return model
# Out:
# Using device: cuda

# %%
import time
from binance.client import Client
import pandas as pd
import os
from requests.exceptions import ReadTimeout, RequestException

client = Client()


def get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='60', retries=3, delay=20):
    """Fetch latest Binance OHLCV data with retry mechanism."""
    attempt = 0
    while attempt < retries:
        try:
            klines = client.get_klines(symbol=symbol, interval=interval, limit=int(lookback))
            break  # Break if successful
        except (ReadTimeout, RequestException) as e:
            attempt += 1
            print(f"[Attempt {attempt}/{retries}] Error fetching data: {e}. Retrying in {delay} seconds...")
            time.sleep(delay)
    else:
        print("Failed to fetch Binance data after multiple retries.")
        return pd.DataFrame()  # Return empty DataFrame on failure

    df = pd.DataFrame(klines, columns=[
        'timestamp', 'open', 'high', 'low', 'close', 'volume',
        'close_time', 'quote_asset_volume', 'num_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ])

    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume']].astype({
        'open': float, 'high': float, 'low': float, 'close': float, 'volume': float
    })

    return df

# %%
import joblib
def train_model(csv):
    
    processor = DataProcessor(csv)
    scaled_data, raw_prices = processor.preprocess()
    X, y = processor.create_sequences(scaled_data, raw_prices)
    joblib.dump(processor.scaler, 'min_max_scaler.joblib')
    # Split data
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    # 2. Train LSTM Price Predictor
    print("Training LSTM Price Predictor...")
    lstm_model = train_lstm(X_train, y_train, input_size=X.shape[2], epochs=EPOCHS, batch_size=BATCH_SIZE)

    lstm_model.eval()
    
    # 3. Prepare Trading Environment
    grids = create_grids(raw_prices)
    env = AdaptiveTradingEnvironment(
    scaled_data, 
    raw_prices, 
    lstm_model, 
    initial_grids=grids,
    recalibration_interval=1000,  # Recalculate every 200 steps
    lookback_window=500         # Use last 500 prices for recalculation
    )
    # 4. Initialize DQN Agent
    state_size = env.get_state().shape[0]
    action_size = 3  # hold, buy, sell
    agent = DoubleDQNAgent(state_size, action_size)
    agent.epsilon = 0.5
    # 5. Training Loop
    print("\nTraining DQN Agent...")
    portfolio_history = []

    for e in range(EPISODES):
        state = env.reset()
        total_reward = 0
        episode_portfolio = [INITIAL_BALANCE]
        
        while not env.done:
            action = agent.act(state)
            next_state, reward, done, portfolio_value = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            episode_portfolio.append(portfolio_value)
            
            if len(agent.memory) > BATCH_SIZE:
                agent.replay(BATCH_SIZE)
        
        portfolio_history.append(episode_portfolio[-1])
        print(f"Episode {e+1}/{EPISODES}, Reward: {total_reward:.4f}, Portfolio: ${episode_portfolio[-1]:,.2f}, Epsilon: {agent.epsilon:.4f}")
        if (e+1) % 10 == 0:
            agent.save(DOUBLE_DQN_PATH)
            print("Models saved successfully")
    # 6. Evaluation
    print("\nEvaluating on test data...")
    test_env = TradingEnvironment(scaled_data[split:], raw_prices[split:], lstm_model, grids)
    state = test_env.reset()
    portfolio_values = []
    trade_log = []

    while not test_env.done:
        action = agent.act(state)
        next_state, reward, done, portfolio_value = test_env.step(action)
        state = next_state
        portfolio_values.append(portfolio_value)
        
        if test_env.trades and test_env.trades[-1][0] in ['buy', 'sell']:
            trade_log.append(test_env.trades[-1])

    # 7. Results
    final_value = test_env.balance + test_env.btc_held * test_env.prices[-1]
    print(f"\n{'='*50}")
    print(f"Initial Balance: ${INITIAL_BALANCE:,.2f}")
    print(f"Final Portfolio Value: ${final_value:,.2f}")
    print(f"Total Return: {((final_value - INITIAL_BALANCE) / INITIAL_BALANCE)*100:.2f}%")
    print(f"Total Trades Executed: {len(test_env.trades)}")
    print(f"Grid Levels: {np.around(grids, 2)}")

    # # Plot results
    # plt.figure(figsize=(15, 10))

    # # Price and grid levels
    # plt.subplot(3, 1, 1)
    # plt.plot(test_env.prices, label='Price')
    # for grid in grids:
    #     plt.axhline(y=grid, color='gray', linestyle='--', alpha=0.3)
    # plt.title('Price with Grid Levels')
    # plt.legend()

    # # Portfolio value
    # plt.subplot(3, 1, 2)
    # plt.plot(portfolio_values)
    # plt.title('Portfolio Value')
    # plt.xlabel('Time Step')
    # plt.ylabel('Value (USD)')

    # # Trade visualization
    # plt.subplot(3, 1, 3)
    # buys = [t[1] for t in trade_log if t[0] == 'buy']
    # sells = [t[1] for t in trade_log if t[0] == 'sell']
    # plt.plot(test_env.prices, label='Price')
    # plt.scatter([i for i, t in enumerate(trade_log) if t[0]=='buy'], buys, 
    #             color='green', marker='^', alpha=0.7, label='Buy')
    # plt.scatter([i for i, t in enumerate(trade_log) if t[0]=='sell'], sells, 
    #             color='red', marker='v', alpha=0.7, label='Sell')
    # plt.title('Trading Signals')
    # plt.legend()

    # plt.tight_layout()
    # plt.savefig('trading_results.png')
    # plt.show()

    # plot_grid_history(env)
    # # Save models
    # torch.save(lstm_model.state_dict(), LSTM_PATH)
    # agent.save(DOUBLE_DQN_PATH)
    # print("Models saved successfully")

# 1. Data Preparation
def dataCreation():
    df_live = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='1000')
    if df_live.empty:
        raise Exception("No data retrieved; skipping model training.")
    temp_csv = 'live_temp.csv'
    df_live.to_csv(temp_csv, index=False)
    return temp_csv

for i in range(1000):
    try:
        print(f"=== Iteration {i+1} ===")
        temp_csv = dataCreation()
        train_model(temp_csv)
    except Exception as e:
        print(f"Error in loop iteration {i+1}: {e}")
# Out:
# === Iteration 1 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 122.1947, Portfolio: $10,122.19, Epsilon: 0.4998
# Episode 2/100, Reward: 306.9701, Portfolio: $10,306.97, Epsilon: 0.4996
# Episode 3/100, Reward: 221.3620, Portfolio: $10,221.36, Epsilon: 0.4994
# Episode 4/100, Reward: 94.4451, Portfolio: $10,094.45, Epsilon: 0.4991
# Episode 5/100, Reward: 211.9548, Portfolio: $10,211.95, Epsilon: 0.4989
# Episode 6/100, Reward: 128.1752, Portfolio: $10,128.18, Epsilon: 0.4987
# Episode 7/100, Reward: 187.9210, Portfolio: $10,187.92, Epsilon: 0.4985
# Episode 8/100, Reward: 117.4721, Portfolio: $10,117.47, Epsilon: 0.4982
# Episode 9/100, Reward: 60.9644, Portfolio: $10,060.96, Epsilon: 0.4980
# Episode 10/100, Reward: 123.0725, Portfolio: $10,123.07, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 155.9559, Portfolio: $10,155.96, Epsilon: 0.4975
# Episode 12/100, Reward: 245.2301, Portfolio: $10,245.23, Epsilon: 0.4973
# Episode 13/100, Reward: 186.8728, Portfolio: $10,186.87, Epsilon: 0.4971
# Episode 14/100, Reward: 195.8604, Portfolio: $10,195.86, Epsilon: 0.4969
# Episode 15/100, Reward: 237.2101, Portfolio: $10,237.21, Epsilon: 0.4966
# Episode 16/100, Reward: 160.4706, Portfolio: $10,160.47, Epsilon: 0.4964
# Episode 17/100, Reward: 123.7534, Portfolio: $10,123.75, Epsilon: 0.4962
# Episode 18/100, Reward: 104.7691, Portfolio: $10,104.77, Epsilon: 0.4959
# Episode 19/100, Reward: 150.4361, Portfolio: $10,150.44, Epsilon: 0.4957
# Episode 20/100, Reward: 223.3148, Portfolio: $10,223.31, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 132.7767, Portfolio: $10,132.78, Epsilon: 0.4953
# Episode 22/100, Reward: 154.3264, Portfolio: $10,154.33, Epsilon: 0.4950
# Episode 23/100, Reward: 249.8945, Portfolio: $10,249.89, Epsilon: 0.4948
# Episode 24/100, Reward: 217.1122, Portfolio: $10,217.11, Epsilon: 0.4946
# Episode 25/100, Reward: 191.9288, Portfolio: $10,191.93, Epsilon: 0.4944
# Episode 26/100, Reward: 79.6196, Portfolio: $10,079.62, Epsilon: 0.4941
# Episode 27/100, Reward: 229.2314, Portfolio: $10,229.23, Epsilon: 0.4939
# Episode 28/100, Reward: 136.4403, Portfolio: $10,136.44, Epsilon: 0.4937
# Episode 29/100, Reward: 148.0148, Portfolio: $10,148.01, Epsilon: 0.4934
# Episode 30/100, Reward: 242.2723, Portfolio: $10,242.27, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 221.0807, Portfolio: $10,221.08, Epsilon: 0.4930
# Episode 32/100, Reward: 211.2361, Portfolio: $10,211.24, Epsilon: 0.4928
# Episode 33/100, Reward: 268.0003, Portfolio: $10,268.00, Epsilon: 0.4925
# Episode 34/100, Reward: 175.4539, Portfolio: $10,175.45, Epsilon: 0.4923
# Episode 35/100, Reward: 125.9575, Portfolio: $10,125.96, Epsilon: 0.4921
# Episode 36/100, Reward: 150.5844, Portfolio: $10,150.58, Epsilon: 0.4919
# Episode 37/100, Reward: 186.2097, Portfolio: $10,186.21, Epsilon: 0.4916
# Episode 38/100, Reward: 140.4787, Portfolio: $10,140.48, Epsilon: 0.4914
# Episode 39/100, Reward: 195.6161, Portfolio: $10,195.62, Epsilon: 0.4912
# Episode 40/100, Reward: 170.5921, Portfolio: $10,170.59, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 202.7232, Portfolio: $10,202.72, Epsilon: 0.4907
# Episode 42/100, Reward: 119.0130, Portfolio: $10,119.01, Epsilon: 0.4905
# Episode 43/100, Reward: 135.7657, Portfolio: $10,135.77, Epsilon: 0.4903
# Episode 44/100, Reward: 205.3305, Portfolio: $10,205.33, Epsilon: 0.4901
# Episode 45/100, Reward: 172.1397, Portfolio: $10,172.14, Epsilon: 0.4898
# Episode 46/100, Reward: 243.2295, Portfolio: $10,243.23, Epsilon: 0.4896
# Episode 47/100, Reward: 127.9752, Portfolio: $10,127.98, Epsilon: 0.4894
# Episode 48/100, Reward: 248.4990, Portfolio: $10,248.50, Epsilon: 0.4892
# Episode 49/100, Reward: 172.3339, Portfolio: $10,172.33, Epsilon: 0.4889
# Episode 50/100, Reward: 150.6028, Portfolio: $10,150.60, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 162.3014, Portfolio: $10,162.30, Epsilon: 0.4885
# Episode 52/100, Reward: 183.8777, Portfolio: $10,183.88, Epsilon: 0.4883
# Episode 53/100, Reward: 242.0801, Portfolio: $10,242.08, Epsilon: 0.4880
# Episode 54/100, Reward: 180.0331, Portfolio: $10,180.03, Epsilon: 0.4878
# Episode 55/100, Reward: 122.7017, Portfolio: $10,122.70, Epsilon: 0.4876
# Episode 56/100, Reward: 146.6648, Portfolio: $10,146.66, Epsilon: 0.4874
# Episode 57/100, Reward: 246.1690, Portfolio: $10,246.17, Epsilon: 0.4871
# Episode 58/100, Reward: 236.9726, Portfolio: $10,236.97, Epsilon: 0.4869
# Episode 59/100, Reward: 122.9099, Portfolio: $10,122.91, Epsilon: 0.4867
# Episode 60/100, Reward: 187.6018, Portfolio: $10,187.60, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 256.7329, Portfolio: $10,256.73, Epsilon: 0.4862
# Episode 62/100, Reward: 169.4485, Portfolio: $10,169.45, Epsilon: 0.4860
# Episode 63/100, Reward: 127.8654, Portfolio: $10,127.87, Epsilon: 0.4858
# Episode 64/100, Reward: 144.2266, Portfolio: $10,144.23, Epsilon: 0.4856
# Episode 65/100, Reward: 206.1011, Portfolio: $10,206.10, Epsilon: 0.4853
# Episode 66/100, Reward: 192.6002, Portfolio: $10,192.60, Epsilon: 0.4851
# Episode 67/100, Reward: 132.2136, Portfolio: $10,132.21, Epsilon: 0.4849
# Episode 68/100, Reward: 163.4655, Portfolio: $10,163.47, Epsilon: 0.4847
# Episode 69/100, Reward: 218.8663, Portfolio: $10,218.87, Epsilon: 0.4845
# Episode 70/100, Reward: 162.9371, Portfolio: $10,162.94, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 178.0923, Portfolio: $10,178.09, Epsilon: 0.4840
# Episode 72/100, Reward: 188.3501, Portfolio: $10,188.35, Epsilon: 0.4838
# Episode 73/100, Reward: 161.7041, Portfolio: $10,161.70, Epsilon: 0.4836
# Episode 74/100, Reward: 241.1349, Portfolio: $10,241.13, Epsilon: 0.4833
# Episode 75/100, Reward: 125.4136, Portfolio: $10,125.41, Epsilon: 0.4831
# Episode 76/100, Reward: 220.1251, Portfolio: $10,220.13, Epsilon: 0.4829
# Episode 77/100, Reward: 162.2059, Portfolio: $10,162.21, Epsilon: 0.4827
# Episode 78/100, Reward: 204.5140, Portfolio: $10,204.51, Epsilon: 0.4825
# Episode 79/100, Reward: 130.7770, Portfolio: $10,130.78, Epsilon: 0.4822
# Episode 80/100, Reward: 171.2654, Portfolio: $10,171.27, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 180.9867, Portfolio: $10,180.99, Epsilon: 0.4818
# Episode 82/100, Reward: 174.4432, Portfolio: $10,174.44, Epsilon: 0.4816
# Episode 83/100, Reward: 208.6822, Portfolio: $10,208.68, Epsilon: 0.4814
# Episode 84/100, Reward: 157.9085, Portfolio: $10,157.91, Epsilon: 0.4811
# Episode 85/100, Reward: 135.4542, Portfolio: $10,135.45, Epsilon: 0.4809
# Episode 86/100, Reward: 98.5717, Portfolio: $10,098.57, Epsilon: 0.4807
# Episode 87/100, Reward: 129.8119, Portfolio: $10,129.81, Epsilon: 0.4805
# Episode 88/100, Reward: 148.9279, Portfolio: $10,148.93, Epsilon: 0.4802
# Episode 89/100, Reward: 140.9155, Portfolio: $10,140.92, Epsilon: 0.4800
# Episode 90/100, Reward: 196.7207, Portfolio: $10,196.72, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 135.2643, Portfolio: $10,135.26, Epsilon: 0.4796
# Episode 92/100, Reward: 261.8590, Portfolio: $10,261.86, Epsilon: 0.4794
# Episode 93/100, Reward: 236.7945, Portfolio: $10,236.79, Epsilon: 0.4791
# Episode 94/100, Reward: 309.1073, Portfolio: $10,309.11, Epsilon: 0.4789
# Episode 95/100, Reward: 210.1486, Portfolio: $10,210.15, Epsilon: 0.4787
# Episode 96/100, Reward: 167.0756, Portfolio: $10,167.08, Epsilon: 0.4785
# Episode 97/100, Reward: 85.3585, Portfolio: $10,085.36, Epsilon: 0.4783
# Episode 98/100, Reward: 107.1024, Portfolio: $10,107.10, Epsilon: 0.4780
# Episode 99/100, Reward: 146.8443, Portfolio: $10,146.84, Epsilon: 0.4778
# Episode 100/100, Reward: 188.1947, Portfolio: $10,188.19, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,085.49
# Total Return: 0.85%
# Total Trades Executed: 137
# Grid Levels: [103505.25 103610.59 103715.94 103821.28 103926.63 104031.98 104137.32
#  104242.67 104348.02 104453.36 104558.71 104664.05 104769.4  104874.75
#  104980.09 105085.44 105190.78 105296.13 105401.48]
# === Iteration 2 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 234.6083, Portfolio: $10,234.61, Epsilon: 0.4998
# Episode 2/100, Reward: 268.4551, Portfolio: $10,268.46, Epsilon: 0.4996
# Episode 3/100, Reward: 171.1012, Portfolio: $10,171.10, Epsilon: 0.4994
# Episode 4/100, Reward: 222.4614, Portfolio: $10,222.46, Epsilon: 0.4991
# Episode 5/100, Reward: 266.0658, Portfolio: $10,266.07, Epsilon: 0.4989
# Episode 6/100, Reward: 228.4509, Portfolio: $10,228.45, Epsilon: 0.4987
# Episode 7/100, Reward: 287.1323, Portfolio: $10,287.13, Epsilon: 0.4985
# Episode 8/100, Reward: 170.4956, Portfolio: $10,170.50, Epsilon: 0.4982
# Episode 9/100, Reward: 167.4116, Portfolio: $10,167.41, Epsilon: 0.4980
# Episode 10/100, Reward: 135.0157, Portfolio: $10,135.02, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 248.0104, Portfolio: $10,248.01, Epsilon: 0.4975
# Episode 12/100, Reward: 237.2894, Portfolio: $10,237.29, Epsilon: 0.4973
# Episode 13/100, Reward: 271.6210, Portfolio: $10,271.62, Epsilon: 0.4971
# Episode 14/100, Reward: 171.9557, Portfolio: $10,171.96, Epsilon: 0.4969
# Episode 15/100, Reward: 245.3087, Portfolio: $10,245.31, Epsilon: 0.4966
# Episode 16/100, Reward: 227.1707, Portfolio: $10,227.17, Epsilon: 0.4964
# Episode 17/100, Reward: 284.5583, Portfolio: $10,284.56, Epsilon: 0.4962
# Episode 18/100, Reward: 227.0335, Portfolio: $10,227.03, Epsilon: 0.4959
# Episode 19/100, Reward: 204.9330, Portfolio: $10,204.93, Epsilon: 0.4957
# Episode 20/100, Reward: 227.1103, Portfolio: $10,227.11, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 187.0200, Portfolio: $10,187.02, Epsilon: 0.4953
# Episode 22/100, Reward: 232.1583, Portfolio: $10,232.16, Epsilon: 0.4950
# Episode 23/100, Reward: 208.5954, Portfolio: $10,208.60, Epsilon: 0.4948
# Episode 24/100, Reward: 149.4323, Portfolio: $10,149.43, Epsilon: 0.4946
# Episode 25/100, Reward: 262.9958, Portfolio: $10,263.00, Epsilon: 0.4944
# Episode 26/100, Reward: 146.1691, Portfolio: $10,146.17, Epsilon: 0.4941
# Episode 27/100, Reward: 178.4991, Portfolio: $10,178.50, Epsilon: 0.4939
# Episode 28/100, Reward: 150.4891, Portfolio: $10,150.49, Epsilon: 0.4937
# Episode 29/100, Reward: 238.6857, Portfolio: $10,238.69, Epsilon: 0.4934
# Episode 30/100, Reward: 187.8240, Portfolio: $10,187.82, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 160.3267, Portfolio: $10,160.33, Epsilon: 0.4930
# Episode 32/100, Reward: 253.1234, Portfolio: $10,253.12, Epsilon: 0.4928
# Episode 33/100, Reward: 189.7875, Portfolio: $10,189.79, Epsilon: 0.4925
# Episode 34/100, Reward: 227.2449, Portfolio: $10,227.24, Epsilon: 0.4923
# Episode 35/100, Reward: 150.6244, Portfolio: $10,150.62, Epsilon: 0.4921
# Episode 36/100, Reward: 170.6513, Portfolio: $10,170.65, Epsilon: 0.4919
# Episode 37/100, Reward: 257.1260, Portfolio: $10,257.13, Epsilon: 0.4916
# Episode 38/100, Reward: 257.8158, Portfolio: $10,257.82, Epsilon: 0.4914
# Episode 39/100, Reward: 274.9314, Portfolio: $10,274.93, Epsilon: 0.4912
# Episode 40/100, Reward: 241.3774, Portfolio: $10,241.38, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 183.9711, Portfolio: $10,183.97, Epsilon: 0.4907
# Episode 42/100, Reward: 152.2611, Portfolio: $10,152.26, Epsilon: 0.4905
# Episode 43/100, Reward: 189.5283, Portfolio: $10,189.53, Epsilon: 0.4903
# Episode 44/100, Reward: 270.7346, Portfolio: $10,270.73, Epsilon: 0.4901
# Episode 45/100, Reward: 175.0360, Portfolio: $10,175.04, Epsilon: 0.4898
# Episode 46/100, Reward: 167.4945, Portfolio: $10,167.49, Epsilon: 0.4896
# Episode 47/100, Reward: 232.2460, Portfolio: $10,232.25, Epsilon: 0.4894
# Episode 48/100, Reward: 197.4638, Portfolio: $10,197.46, Epsilon: 0.4892
# Episode 49/100, Reward: 279.9245, Portfolio: $10,279.92, Epsilon: 0.4889
# Episode 50/100, Reward: 253.5904, Portfolio: $10,253.59, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 251.9935, Portfolio: $10,251.99, Epsilon: 0.4885
# Episode 52/100, Reward: 251.3646, Portfolio: $10,251.36, Epsilon: 0.4883
# Episode 53/100, Reward: 180.3503, Portfolio: $10,180.35, Epsilon: 0.4880
# Episode 54/100, Reward: 267.1602, Portfolio: $10,267.16, Epsilon: 0.4878
# Episode 55/100, Reward: 260.3619, Portfolio: $10,260.36, Epsilon: 0.4876
# Episode 56/100, Reward: 163.7956, Portfolio: $10,163.80, Epsilon: 0.4874
# Episode 57/100, Reward: 198.6041, Portfolio: $10,198.60, Epsilon: 0.4871
# Episode 58/100, Reward: 210.0939, Portfolio: $10,210.09, Epsilon: 0.4869
# Episode 59/100, Reward: 266.5448, Portfolio: $10,266.54, Epsilon: 0.4867
# Episode 60/100, Reward: 309.9868, Portfolio: $10,309.99, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 249.8268, Portfolio: $10,249.83, Epsilon: 0.4862
# Episode 62/100, Reward: 216.7038, Portfolio: $10,216.70, Epsilon: 0.4860
# Episode 63/100, Reward: 171.6401, Portfolio: $10,171.64, Epsilon: 0.4858
# Episode 64/100, Reward: 162.8533, Portfolio: $10,162.85, Epsilon: 0.4856
# Episode 65/100, Reward: 229.2573, Portfolio: $10,229.26, Epsilon: 0.4853
# Episode 66/100, Reward: 185.2846, Portfolio: $10,185.28, Epsilon: 0.4851
# Episode 67/100, Reward: 200.5247, Portfolio: $10,200.52, Epsilon: 0.4849
# Episode 68/100, Reward: 279.5438, Portfolio: $10,279.54, Epsilon: 0.4847
# Episode 69/100, Reward: 255.0623, Portfolio: $10,255.06, Epsilon: 0.4845
# Episode 70/100, Reward: 232.4070, Portfolio: $10,232.41, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 201.2006, Portfolio: $10,201.20, Epsilon: 0.4840
# Episode 72/100, Reward: 280.3043, Portfolio: $10,280.30, Epsilon: 0.4838
# Episode 73/100, Reward: 198.9490, Portfolio: $10,198.95, Epsilon: 0.4836
# Episode 74/100, Reward: 169.7798, Portfolio: $10,169.78, Epsilon: 0.4833
# Episode 75/100, Reward: 232.5267, Portfolio: $10,232.53, Epsilon: 0.4831
# Episode 76/100, Reward: 233.8003, Portfolio: $10,233.80, Epsilon: 0.4829
# Episode 77/100, Reward: 239.3100, Portfolio: $10,239.31, Epsilon: 0.4827
# Episode 78/100, Reward: 147.7281, Portfolio: $10,147.73, Epsilon: 0.4825
# Episode 79/100, Reward: 123.7413, Portfolio: $10,123.74, Epsilon: 0.4822
# Episode 80/100, Reward: 239.2293, Portfolio: $10,239.23, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 186.8333, Portfolio: $10,186.83, Epsilon: 0.4818
# Episode 82/100, Reward: 210.3236, Portfolio: $10,210.32, Epsilon: 0.4816
# Episode 83/100, Reward: 88.1193, Portfolio: $10,088.12, Epsilon: 0.4814
# Episode 84/100, Reward: 195.7700, Portfolio: $10,195.77, Epsilon: 0.4811
# Episode 85/100, Reward: 128.0776, Portfolio: $10,128.08, Epsilon: 0.4809
# Episode 86/100, Reward: 118.6829, Portfolio: $10,118.68, Epsilon: 0.4807
# Episode 87/100, Reward: 222.8884, Portfolio: $10,222.89, Epsilon: 0.4805
# Episode 88/100, Reward: 297.7240, Portfolio: $10,297.72, Epsilon: 0.4802
# Episode 89/100, Reward: 188.8373, Portfolio: $10,188.84, Epsilon: 0.4800
# Episode 90/100, Reward: 190.7783, Portfolio: $10,190.78, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 153.7355, Portfolio: $10,153.74, Epsilon: 0.4796
# Episode 92/100, Reward: 217.1081, Portfolio: $10,217.11, Epsilon: 0.4794
# Episode 93/100, Reward: 256.8226, Portfolio: $10,256.82, Epsilon: 0.4791
# Episode 94/100, Reward: 209.8040, Portfolio: $10,209.80, Epsilon: 0.4789
# Episode 95/100, Reward: 249.6920, Portfolio: $10,249.69, Epsilon: 0.4787
# Episode 96/100, Reward: 162.3348, Portfolio: $10,162.33, Epsilon: 0.4785
# Episode 97/100, Reward: 231.3106, Portfolio: $10,231.31, Epsilon: 0.4783
# Episode 98/100, Reward: 269.4412, Portfolio: $10,269.44, Epsilon: 0.4780
# Episode 99/100, Reward: 258.8473, Portfolio: $10,258.85, Epsilon: 0.4778
# Episode 100/100, Reward: 230.0317, Portfolio: $10,230.03, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,092.64
# Total Return: 0.93%
# Total Trades Executed: 148
# Grid Levels: [103510.15 103620.4  103730.65 103840.9  103951.15 104061.4  104171.65
#  104281.9  104392.15 104502.4  104612.66 104722.91 104833.16 104943.41
#  105053.66 105163.91 105274.16 105384.41 105494.66]
# === Iteration 3 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 236.1755, Portfolio: $10,236.18, Epsilon: 0.4998
# Episode 2/100, Reward: 193.6174, Portfolio: $10,193.62, Epsilon: 0.4996
# Episode 3/100, Reward: 191.9613, Portfolio: $10,191.96, Epsilon: 0.4994
# Episode 4/100, Reward: 205.8156, Portfolio: $10,205.82, Epsilon: 0.4991
# Episode 5/100, Reward: 96.9759, Portfolio: $10,096.98, Epsilon: 0.4989
# Episode 6/100, Reward: 241.4447, Portfolio: $10,241.44, Epsilon: 0.4987
# Episode 7/100, Reward: 178.3383, Portfolio: $10,178.34, Epsilon: 0.4985
# Episode 8/100, Reward: 228.0734, Portfolio: $10,228.07, Epsilon: 0.4982
# Episode 9/100, Reward: 103.8819, Portfolio: $10,103.88, Epsilon: 0.4980
# Episode 10/100, Reward: 202.1800, Portfolio: $10,202.18, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 153.2060, Portfolio: $10,153.21, Epsilon: 0.4975
# Episode 12/100, Reward: 235.2545, Portfolio: $10,235.25, Epsilon: 0.4973
# Episode 13/100, Reward: 218.1823, Portfolio: $10,218.18, Epsilon: 0.4971
# Episode 14/100, Reward: 211.0150, Portfolio: $10,211.01, Epsilon: 0.4969
# Episode 15/100, Reward: 251.0128, Portfolio: $10,251.01, Epsilon: 0.4966
# Episode 16/100, Reward: 128.9865, Portfolio: $10,128.99, Epsilon: 0.4964
# Episode 17/100, Reward: 159.7740, Portfolio: $10,159.77, Epsilon: 0.4962
# Episode 18/100, Reward: 144.0022, Portfolio: $10,144.00, Epsilon: 0.4959
# Episode 19/100, Reward: 264.1453, Portfolio: $10,264.15, Epsilon: 0.4957
# Episode 20/100, Reward: 186.1489, Portfolio: $10,186.15, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 227.4273, Portfolio: $10,227.43, Epsilon: 0.4953
# Episode 22/100, Reward: 222.4421, Portfolio: $10,222.44, Epsilon: 0.4950
# Episode 23/100, Reward: 183.6275, Portfolio: $10,183.63, Epsilon: 0.4948
# Episode 24/100, Reward: 195.5789, Portfolio: $10,195.58, Epsilon: 0.4946
# Episode 25/100, Reward: 191.7132, Portfolio: $10,191.71, Epsilon: 0.4944
# Episode 26/100, Reward: 169.1362, Portfolio: $10,169.14, Epsilon: 0.4941
# Episode 27/100, Reward: 227.6488, Portfolio: $10,227.65, Epsilon: 0.4939
# Episode 28/100, Reward: 188.8263, Portfolio: $10,188.83, Epsilon: 0.4937
# Episode 29/100, Reward: 124.8836, Portfolio: $10,124.88, Epsilon: 0.4934
# Episode 30/100, Reward: 220.7280, Portfolio: $10,220.73, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 148.9430, Portfolio: $10,148.94, Epsilon: 0.4930
# Episode 32/100, Reward: 228.8497, Portfolio: $10,228.85, Epsilon: 0.4928
# Episode 33/100, Reward: 244.5836, Portfolio: $10,244.58, Epsilon: 0.4925
# Episode 34/100, Reward: 232.9348, Portfolio: $10,232.93, Epsilon: 0.4923
# Episode 35/100, Reward: 159.3318, Portfolio: $10,159.33, Epsilon: 0.4921
# Episode 36/100, Reward: 254.4179, Portfolio: $10,254.42, Epsilon: 0.4919
# Episode 37/100, Reward: 248.8279, Portfolio: $10,248.83, Epsilon: 0.4916
# Episode 38/100, Reward: 208.7229, Portfolio: $10,208.72, Epsilon: 0.4914
# Episode 39/100, Reward: 143.0736, Portfolio: $10,143.07, Epsilon: 0.4912
# Episode 40/100, Reward: 225.6686, Portfolio: $10,225.67, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 205.1875, Portfolio: $10,205.19, Epsilon: 0.4907
# Episode 42/100, Reward: 200.0891, Portfolio: $10,200.09, Epsilon: 0.4905
# Episode 43/100, Reward: 187.4184, Portfolio: $10,187.42, Epsilon: 0.4903
# Episode 44/100, Reward: 162.6307, Portfolio: $10,162.63, Epsilon: 0.4901
# Episode 45/100, Reward: 241.2137, Portfolio: $10,241.21, Epsilon: 0.4898
# Episode 46/100, Reward: 281.2944, Portfolio: $10,281.29, Epsilon: 0.4896
# Episode 47/100, Reward: 219.6065, Portfolio: $10,219.61, Epsilon: 0.4894
# Episode 48/100, Reward: 161.2099, Portfolio: $10,161.21, Epsilon: 0.4892
# Episode 49/100, Reward: 272.1620, Portfolio: $10,272.16, Epsilon: 0.4889
# Episode 50/100, Reward: 181.8670, Portfolio: $10,181.87, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 287.4300, Portfolio: $10,287.43, Epsilon: 0.4885
# Episode 52/100, Reward: 229.3123, Portfolio: $10,229.31, Epsilon: 0.4883
# Episode 53/100, Reward: 229.4140, Portfolio: $10,229.41, Epsilon: 0.4880
# Episode 54/100, Reward: 193.3624, Portfolio: $10,193.36, Epsilon: 0.4878
# Episode 55/100, Reward: 194.1023, Portfolio: $10,194.10, Epsilon: 0.4876
# Episode 56/100, Reward: 183.3605, Portfolio: $10,183.36, Epsilon: 0.4874
# Episode 57/100, Reward: 134.7107, Portfolio: $10,134.71, Epsilon: 0.4871
# Episode 58/100, Reward: 163.6255, Portfolio: $10,163.63, Epsilon: 0.4869
# Episode 59/100, Reward: 201.5026, Portfolio: $10,201.50, Epsilon: 0.4867
# Episode 60/100, Reward: 196.9497, Portfolio: $10,196.95, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 220.0243, Portfolio: $10,220.02, Epsilon: 0.4862
# Episode 62/100, Reward: 189.3011, Portfolio: $10,189.30, Epsilon: 0.4860
# Episode 63/100, Reward: 217.9962, Portfolio: $10,218.00, Epsilon: 0.4858
# Episode 64/100, Reward: 149.8762, Portfolio: $10,149.88, Epsilon: 0.4856
# Episode 65/100, Reward: 178.9706, Portfolio: $10,178.97, Epsilon: 0.4853
# Episode 66/100, Reward: 196.1399, Portfolio: $10,196.14, Epsilon: 0.4851
# Episode 67/100, Reward: 131.4497, Portfolio: $10,131.45, Epsilon: 0.4849
# Episode 68/100, Reward: 245.6541, Portfolio: $10,245.65, Epsilon: 0.4847
# Episode 69/100, Reward: 172.4670, Portfolio: $10,172.47, Epsilon: 0.4845
# Episode 70/100, Reward: 143.6099, Portfolio: $10,143.61, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 141.7100, Portfolio: $10,141.71, Epsilon: 0.4840
# Episode 72/100, Reward: 175.0167, Portfolio: $10,175.02, Epsilon: 0.4838
# Episode 73/100, Reward: 252.5587, Portfolio: $10,252.56, Epsilon: 0.4836
# Episode 74/100, Reward: 169.0650, Portfolio: $10,169.07, Epsilon: 0.4833
# Episode 75/100, Reward: 177.0762, Portfolio: $10,177.08, Epsilon: 0.4831
# Episode 76/100, Reward: 204.5196, Portfolio: $10,204.52, Epsilon: 0.4829
# Episode 77/100, Reward: 231.3442, Portfolio: $10,231.34, Epsilon: 0.4827
# Episode 78/100, Reward: 194.6596, Portfolio: $10,194.66, Epsilon: 0.4825
# Episode 79/100, Reward: 163.5905, Portfolio: $10,163.59, Epsilon: 0.4822
# Episode 80/100, Reward: 237.1821, Portfolio: $10,237.18, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 220.4953, Portfolio: $10,220.50, Epsilon: 0.4818
# Episode 82/100, Reward: 216.3850, Portfolio: $10,216.38, Epsilon: 0.4816
# Episode 83/100, Reward: 140.4709, Portfolio: $10,140.47, Epsilon: 0.4814
# Episode 84/100, Reward: 172.8520, Portfolio: $10,172.85, Epsilon: 0.4811
# Episode 85/100, Reward: 144.8441, Portfolio: $10,144.84, Epsilon: 0.4809
# Episode 86/100, Reward: 192.4534, Portfolio: $10,192.45, Epsilon: 0.4807
# Episode 87/100, Reward: 176.0312, Portfolio: $10,176.03, Epsilon: 0.4805
# Episode 88/100, Reward: 148.6490, Portfolio: $10,148.65, Epsilon: 0.4802
# Episode 89/100, Reward: 185.5089, Portfolio: $10,185.51, Epsilon: 0.4800
# Episode 90/100, Reward: 140.0998, Portfolio: $10,140.10, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 234.7080, Portfolio: $10,234.71, Epsilon: 0.4796
# Episode 92/100, Reward: 169.1201, Portfolio: $10,169.12, Epsilon: 0.4794
# Episode 93/100, Reward: 128.8970, Portfolio: $10,128.90, Epsilon: 0.4791
# Episode 94/100, Reward: 171.0343, Portfolio: $10,171.03, Epsilon: 0.4789
# Episode 95/100, Reward: 188.1100, Portfolio: $10,188.11, Epsilon: 0.4787
# Episode 96/100, Reward: 128.2748, Portfolio: $10,128.27, Epsilon: 0.4785
# Episode 97/100, Reward: 190.8256, Portfolio: $10,190.83, Epsilon: 0.4783
# Episode 98/100, Reward: 279.3368, Portfolio: $10,279.34, Epsilon: 0.4780
# Episode 99/100, Reward: 177.8519, Portfolio: $10,177.85, Epsilon: 0.4778
# Episode 100/100, Reward: 216.1307, Portfolio: $10,216.13, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,056.70
# Total Return: 0.57%
# Total Trades Executed: 153
# Grid Levels: [103559.65 103668.1  103776.54 103884.99 103993.43 104101.88 104210.32
#  104318.76 104427.21 104535.65 104644.1  104752.54 104860.98 104969.43
#  105077.87 105186.32 105294.76 105403.21 105511.65]
# === Iteration 4 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 104.5396, Portfolio: $10,104.54, Epsilon: 0.4998
# Episode 2/100, Reward: 58.0567, Portfolio: $10,058.06, Epsilon: 0.4996
# Episode 3/100, Reward: 77.8283, Portfolio: $10,077.83, Epsilon: 0.4994
# Episode 4/100, Reward: 39.0250, Portfolio: $10,039.03, Epsilon: 0.4991
# Episode 5/100, Reward: 158.3783, Portfolio: $10,158.38, Epsilon: 0.4989
# Episode 6/100, Reward: 44.2472, Portfolio: $10,044.25, Epsilon: 0.4987
# Episode 7/100, Reward: 112.8526, Portfolio: $10,112.85, Epsilon: 0.4985
# Episode 8/100, Reward: 131.8113, Portfolio: $10,131.81, Epsilon: 0.4982
# Episode 9/100, Reward: 127.2333, Portfolio: $10,127.23, Epsilon: 0.4980
# Episode 10/100, Reward: 57.3237, Portfolio: $10,057.32, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 35.1628, Portfolio: $10,035.16, Epsilon: 0.4975
# Episode 12/100, Reward: 58.6080, Portfolio: $10,058.61, Epsilon: 0.4973
# Episode 13/100, Reward: 122.3557, Portfolio: $10,122.36, Epsilon: 0.4971
# Episode 14/100, Reward: 42.7009, Portfolio: $10,042.70, Epsilon: 0.4969
# Episode 15/100, Reward: 88.7624, Portfolio: $10,088.76, Epsilon: 0.4966
# Episode 16/100, Reward: 149.4844, Portfolio: $10,149.48, Epsilon: 0.4964
# Episode 17/100, Reward: 31.6064, Portfolio: $10,031.61, Epsilon: 0.4962
# Episode 18/100, Reward: 91.2585, Portfolio: $10,091.26, Epsilon: 0.4959
# Episode 19/100, Reward: 96.0222, Portfolio: $10,096.02, Epsilon: 0.4957
# Episode 20/100, Reward: 193.5283, Portfolio: $10,193.53, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 146.6627, Portfolio: $10,146.66, Epsilon: 0.4953
# Episode 22/100, Reward: 115.7941, Portfolio: $10,115.79, Epsilon: 0.4950
# Episode 23/100, Reward: 84.3352, Portfolio: $10,084.34, Epsilon: 0.4948
# Episode 24/100, Reward: 183.4150, Portfolio: $10,183.42, Epsilon: 0.4946
# Episode 25/100, Reward: 39.2553, Portfolio: $10,039.26, Epsilon: 0.4944
# Episode 26/100, Reward: 62.3321, Portfolio: $10,062.33, Epsilon: 0.4941
# Episode 27/100, Reward: 70.8607, Portfolio: $10,070.86, Epsilon: 0.4939
# Episode 28/100, Reward: 143.0069, Portfolio: $10,143.01, Epsilon: 0.4937
# Episode 29/100, Reward: 147.3920, Portfolio: $10,147.39, Epsilon: 0.4934
# Episode 30/100, Reward: 119.5416, Portfolio: $10,119.54, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 80.3944, Portfolio: $10,080.39, Epsilon: 0.4930
# Episode 32/100, Reward: 92.3889, Portfolio: $10,092.39, Epsilon: 0.4928
# Episode 33/100, Reward: 39.4160, Portfolio: $10,039.42, Epsilon: 0.4925
# Episode 34/100, Reward: 130.3161, Portfolio: $10,130.32, Epsilon: 0.4923
# Episode 35/100, Reward: 89.6391, Portfolio: $10,089.64, Epsilon: 0.4921
# Episode 36/100, Reward: 102.5336, Portfolio: $10,102.53, Epsilon: 0.4919
# Episode 37/100, Reward: 133.3757, Portfolio: $10,133.38, Epsilon: 0.4916
# Episode 38/100, Reward: 71.9364, Portfolio: $10,071.94, Epsilon: 0.4914
# Episode 39/100, Reward: 114.1650, Portfolio: $10,114.16, Epsilon: 0.4912
# Episode 40/100, Reward: 101.5125, Portfolio: $10,101.51, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 150.7539, Portfolio: $10,150.75, Epsilon: 0.4907
# Episode 42/100, Reward: 72.7386, Portfolio: $10,072.74, Epsilon: 0.4905
# Episode 43/100, Reward: 115.2414, Portfolio: $10,115.24, Epsilon: 0.4903
# Episode 44/100, Reward: 76.2552, Portfolio: $10,076.26, Epsilon: 0.4901
# Episode 45/100, Reward: 72.4468, Portfolio: $10,072.45, Epsilon: 0.4898
# Episode 46/100, Reward: 134.0094, Portfolio: $10,134.01, Epsilon: 0.4896
# Episode 47/100, Reward: 109.9751, Portfolio: $10,109.98, Epsilon: 0.4894
# Episode 48/100, Reward: 113.8227, Portfolio: $10,113.82, Epsilon: 0.4892
# Episode 49/100, Reward: 97.5407, Portfolio: $10,097.54, Epsilon: 0.4889
# Episode 50/100, Reward: 90.7843, Portfolio: $10,090.78, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 193.2788, Portfolio: $10,193.28, Epsilon: 0.4885
# Episode 52/100, Reward: 67.4740, Portfolio: $10,067.47, Epsilon: 0.4883
# Episode 53/100, Reward: 83.5717, Portfolio: $10,083.57, Epsilon: 0.4880
# Episode 54/100, Reward: 98.5058, Portfolio: $10,098.51, Epsilon: 0.4878
# Episode 55/100, Reward: 71.2765, Portfolio: $10,071.28, Epsilon: 0.4876
# Episode 56/100, Reward: 116.6035, Portfolio: $10,116.60, Epsilon: 0.4874
# Episode 57/100, Reward: 25.7339, Portfolio: $10,025.73, Epsilon: 0.4871
# Episode 58/100, Reward: 24.8190, Portfolio: $10,024.82, Epsilon: 0.4869
# Episode 59/100, Reward: 75.2540, Portfolio: $10,075.25, Epsilon: 0.4867
# Episode 60/100, Reward: 103.0530, Portfolio: $10,103.05, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 148.2891, Portfolio: $10,148.29, Epsilon: 0.4862
# Episode 62/100, Reward: 56.5774, Portfolio: $10,056.58, Epsilon: 0.4860
# Episode 63/100, Reward: 165.2209, Portfolio: $10,165.22, Epsilon: 0.4858
# Episode 64/100, Reward: 75.6526, Portfolio: $10,075.65, Epsilon: 0.4856
# Episode 65/100, Reward: 105.2655, Portfolio: $10,105.27, Epsilon: 0.4853
# Episode 66/100, Reward: 36.6772, Portfolio: $10,036.68, Epsilon: 0.4851
# Episode 67/100, Reward: 177.7415, Portfolio: $10,177.74, Epsilon: 0.4849
# Episode 68/100, Reward: 134.3696, Portfolio: $10,134.37, Epsilon: 0.4847
# Episode 69/100, Reward: 107.6345, Portfolio: $10,107.63, Epsilon: 0.4845
# Episode 70/100, Reward: 33.9704, Portfolio: $10,033.97, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 68.7012, Portfolio: $10,068.70, Epsilon: 0.4840
# Episode 72/100, Reward: 79.8940, Portfolio: $10,079.89, Epsilon: 0.4838
# Episode 73/100, Reward: 36.5059, Portfolio: $10,036.51, Epsilon: 0.4836
# Episode 74/100, Reward: 120.7969, Portfolio: $10,120.80, Epsilon: 0.4833
# Episode 75/100, Reward: 32.3991, Portfolio: $10,032.40, Epsilon: 0.4831
# Episode 76/100, Reward: 17.6785, Portfolio: $10,017.68, Epsilon: 0.4829
# Episode 77/100, Reward: 91.8286, Portfolio: $10,091.83, Epsilon: 0.4827
# Episode 78/100, Reward: 20.4696, Portfolio: $10,020.47, Epsilon: 0.4825
# Episode 79/100, Reward: 74.1924, Portfolio: $10,074.19, Epsilon: 0.4822
# Episode 80/100, Reward: 101.0489, Portfolio: $10,101.05, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 132.1342, Portfolio: $10,132.13, Epsilon: 0.4818
# Episode 82/100, Reward: 90.0339, Portfolio: $10,090.03, Epsilon: 0.4816
# Episode 83/100, Reward: 94.0477, Portfolio: $10,094.05, Epsilon: 0.4814
# Episode 84/100, Reward: 48.2250, Portfolio: $10,048.23, Epsilon: 0.4811
# Episode 85/100, Reward: 89.7238, Portfolio: $10,089.72, Epsilon: 0.4809
# Episode 86/100, Reward: 158.1119, Portfolio: $10,158.11, Epsilon: 0.4807
# Episode 87/100, Reward: 23.9166, Portfolio: $10,023.92, Epsilon: 0.4805
# Episode 88/100, Reward: 183.8743, Portfolio: $10,183.87, Epsilon: 0.4802
# Episode 89/100, Reward: 155.5430, Portfolio: $10,155.54, Epsilon: 0.4800
# Episode 90/100, Reward: 49.4023, Portfolio: $10,049.40, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 100.6609, Portfolio: $10,100.66, Epsilon: 0.4796
# Episode 92/100, Reward: 80.4382, Portfolio: $10,080.44, Epsilon: 0.4794
# Episode 93/100, Reward: 126.4594, Portfolio: $10,126.46, Epsilon: 0.4791
# Episode 94/100, Reward: 81.9443, Portfolio: $10,081.94, Epsilon: 0.4789
# Episode 95/100, Reward: 181.9951, Portfolio: $10,182.00, Epsilon: 0.4787
# Episode 96/100, Reward: 86.2224, Portfolio: $10,086.22, Epsilon: 0.4785
# Episode 97/100, Reward: 51.3347, Portfolio: $10,051.33, Epsilon: 0.4783
# Episode 98/100, Reward: 97.6889, Portfolio: $10,097.69, Epsilon: 0.4780
# Episode 99/100, Reward: 72.4888, Portfolio: $10,072.49, Epsilon: 0.4778
# Episode 100/100, Reward: 112.2930, Portfolio: $10,112.29, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,008.79
# Total Return: 0.09%
# Total Trades Executed: 132
# Grid Levels: [103662.61 103765.64 103868.66 103971.69 104074.71 104177.74 104280.76
#  104383.79 104486.81 104589.84 104692.87 104795.89 104898.92 105001.94
#  105104.97 105207.99 105311.02 105414.04 105517.07]
# === Iteration 5 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 118.9388, Portfolio: $10,118.94, Epsilon: 0.4998
# Episode 2/100, Reward: 113.0717, Portfolio: $10,113.07, Epsilon: 0.4996
# Episode 3/100, Reward: 97.8290, Portfolio: $10,097.83, Epsilon: 0.4994
# Episode 4/100, Reward: 115.3812, Portfolio: $10,115.38, Epsilon: 0.4991
# Episode 5/100, Reward: 139.0428, Portfolio: $10,139.04, Epsilon: 0.4989
# Episode 6/100, Reward: 121.0283, Portfolio: $10,121.03, Epsilon: 0.4987
# Episode 7/100, Reward: 185.3162, Portfolio: $10,185.32, Epsilon: 0.4985
# Episode 8/100, Reward: 189.6801, Portfolio: $10,189.68, Epsilon: 0.4982
# Episode 9/100, Reward: 115.3503, Portfolio: $10,115.35, Epsilon: 0.4980
# Episode 10/100, Reward: 157.6815, Portfolio: $10,157.68, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 114.3205, Portfolio: $10,114.32, Epsilon: 0.4975
# Episode 12/100, Reward: 192.0403, Portfolio: $10,192.04, Epsilon: 0.4973
# Episode 13/100, Reward: 152.3343, Portfolio: $10,152.33, Epsilon: 0.4971
# Episode 14/100, Reward: 48.2278, Portfolio: $10,048.23, Epsilon: 0.4969
# Episode 15/100, Reward: 130.6797, Portfolio: $10,130.68, Epsilon: 0.4966
# Episode 16/100, Reward: 103.3051, Portfolio: $10,103.31, Epsilon: 0.4964
# Episode 17/100, Reward: 146.1696, Portfolio: $10,146.17, Epsilon: 0.4962
# Episode 18/100, Reward: 67.4273, Portfolio: $10,067.43, Epsilon: 0.4959
# Episode 19/100, Reward: 81.0388, Portfolio: $10,081.04, Epsilon: 0.4957
# Episode 20/100, Reward: 76.8425, Portfolio: $10,076.84, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 98.9506, Portfolio: $10,098.95, Epsilon: 0.4953
# Episode 22/100, Reward: 41.9877, Portfolio: $10,041.99, Epsilon: 0.4950
# Episode 23/100, Reward: 107.1580, Portfolio: $10,107.16, Epsilon: 0.4948
# Episode 24/100, Reward: 95.3435, Portfolio: $10,095.34, Epsilon: 0.4946
# Episode 25/100, Reward: 220.2804, Portfolio: $10,220.28, Epsilon: 0.4944
# Episode 26/100, Reward: 139.9024, Portfolio: $10,139.90, Epsilon: 0.4941
# Episode 27/100, Reward: 92.3420, Portfolio: $10,092.34, Epsilon: 0.4939
# Episode 28/100, Reward: 136.4290, Portfolio: $10,136.43, Epsilon: 0.4937
# Episode 29/100, Reward: 156.1892, Portfolio: $10,156.19, Epsilon: 0.4934
# Episode 30/100, Reward: 117.9055, Portfolio: $10,117.91, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 168.7622, Portfolio: $10,168.76, Epsilon: 0.4930
# Episode 32/100, Reward: 108.2930, Portfolio: $10,108.29, Epsilon: 0.4928
# Episode 33/100, Reward: 107.9542, Portfolio: $10,107.95, Epsilon: 0.4925
# Episode 34/100, Reward: 53.4813, Portfolio: $10,053.48, Epsilon: 0.4923
# Episode 35/100, Reward: 92.2951, Portfolio: $10,092.30, Epsilon: 0.4921
# Episode 36/100, Reward: 98.0735, Portfolio: $10,098.07, Epsilon: 0.4919
# Episode 37/100, Reward: 54.9542, Portfolio: $10,054.95, Epsilon: 0.4916
# Episode 38/100, Reward: 59.4656, Portfolio: $10,059.47, Epsilon: 0.4914
# Episode 39/100, Reward: 127.2167, Portfolio: $10,127.22, Epsilon: 0.4912
# Episode 40/100, Reward: 73.6358, Portfolio: $10,073.64, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 182.1061, Portfolio: $10,182.11, Epsilon: 0.4907
# Episode 42/100, Reward: 147.7899, Portfolio: $10,147.79, Epsilon: 0.4905
# Episode 43/100, Reward: 152.6814, Portfolio: $10,152.68, Epsilon: 0.4903
# Episode 44/100, Reward: 108.5078, Portfolio: $10,108.51, Epsilon: 0.4901
# Episode 45/100, Reward: 113.5300, Portfolio: $10,113.53, Epsilon: 0.4898
# Episode 46/100, Reward: 147.2174, Portfolio: $10,147.22, Epsilon: 0.4896
# Episode 47/100, Reward: 154.3602, Portfolio: $10,154.36, Epsilon: 0.4894
# Episode 48/100, Reward: 110.3674, Portfolio: $10,110.37, Epsilon: 0.4892
# Episode 49/100, Reward: 194.5290, Portfolio: $10,194.53, Epsilon: 0.4889
# Episode 50/100, Reward: 102.2359, Portfolio: $10,102.24, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 17.3007, Portfolio: $10,017.30, Epsilon: 0.4885
# Episode 52/100, Reward: 166.3665, Portfolio: $10,166.37, Epsilon: 0.4883
# Episode 53/100, Reward: 93.1805, Portfolio: $10,093.18, Epsilon: 0.4880
# Episode 54/100, Reward: 120.1928, Portfolio: $10,120.19, Epsilon: 0.4878
# Episode 55/100, Reward: 191.7258, Portfolio: $10,191.73, Epsilon: 0.4876
# Episode 56/100, Reward: 145.6441, Portfolio: $10,145.64, Epsilon: 0.4874
# Episode 57/100, Reward: 67.3248, Portfolio: $10,067.32, Epsilon: 0.4871
# Episode 58/100, Reward: 122.0895, Portfolio: $10,122.09, Epsilon: 0.4869
# Episode 59/100, Reward: 155.7762, Portfolio: $10,155.78, Epsilon: 0.4867
# Episode 60/100, Reward: 77.2227, Portfolio: $10,077.22, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 173.6077, Portfolio: $10,173.61, Epsilon: 0.4862
# Episode 62/100, Reward: 89.0270, Portfolio: $10,089.03, Epsilon: 0.4860
# Episode 63/100, Reward: 126.1921, Portfolio: $10,126.19, Epsilon: 0.4858
# Episode 64/100, Reward: 97.6969, Portfolio: $10,097.70, Epsilon: 0.4856
# Episode 65/100, Reward: 169.8940, Portfolio: $10,169.89, Epsilon: 0.4853
# Episode 66/100, Reward: 98.0274, Portfolio: $10,098.03, Epsilon: 0.4851
# Episode 67/100, Reward: 116.1369, Portfolio: $10,116.14, Epsilon: 0.4849
# Episode 68/100, Reward: 79.6363, Portfolio: $10,079.64, Epsilon: 0.4847
# Episode 69/100, Reward: 80.7815, Portfolio: $10,080.78, Epsilon: 0.4845
# Episode 70/100, Reward: 126.9265, Portfolio: $10,126.93, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 90.0536, Portfolio: $10,090.05, Epsilon: 0.4840
# Episode 72/100, Reward: 31.2625, Portfolio: $10,031.26, Epsilon: 0.4838
# Episode 73/100, Reward: 44.4313, Portfolio: $10,044.43, Epsilon: 0.4836
# Episode 74/100, Reward: 64.4914, Portfolio: $10,064.49, Epsilon: 0.4833
# Episode 75/100, Reward: 114.6912, Portfolio: $10,114.69, Epsilon: 0.4831
# Episode 76/100, Reward: 183.9487, Portfolio: $10,183.95, Epsilon: 0.4829
# Episode 77/100, Reward: 44.0809, Portfolio: $10,044.08, Epsilon: 0.4827
# Episode 78/100, Reward: 114.9702, Portfolio: $10,114.97, Epsilon: 0.4825
# Episode 79/100, Reward: 115.5764, Portfolio: $10,115.58, Epsilon: 0.4822
# Episode 80/100, Reward: 99.4989, Portfolio: $10,099.50, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 149.6046, Portfolio: $10,149.60, Epsilon: 0.4818
# Episode 82/100, Reward: 125.2718, Portfolio: $10,125.27, Epsilon: 0.4816
# Episode 83/100, Reward: 75.9997, Portfolio: $10,076.00, Epsilon: 0.4814
# Episode 84/100, Reward: 29.5709, Portfolio: $10,029.57, Epsilon: 0.4811
# Episode 85/100, Reward: 148.0260, Portfolio: $10,148.03, Epsilon: 0.4809
# Episode 86/100, Reward: 102.7035, Portfolio: $10,102.70, Epsilon: 0.4807
# Episode 87/100, Reward: 120.5213, Portfolio: $10,120.52, Epsilon: 0.4805
# Episode 88/100, Reward: 98.9002, Portfolio: $10,098.90, Epsilon: 0.4802
# Episode 89/100, Reward: 232.5465, Portfolio: $10,232.55, Epsilon: 0.4800
# Episode 90/100, Reward: 144.8303, Portfolio: $10,144.83, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 85.9725, Portfolio: $10,085.97, Epsilon: 0.4796
# Episode 92/100, Reward: 104.4162, Portfolio: $10,104.42, Epsilon: 0.4794
# Episode 93/100, Reward: 72.4929, Portfolio: $10,072.49, Epsilon: 0.4791
# Episode 94/100, Reward: 225.1227, Portfolio: $10,225.12, Epsilon: 0.4789
# Episode 95/100, Reward: 178.1377, Portfolio: $10,178.14, Epsilon: 0.4787
# Episode 96/100, Reward: 15.5242, Portfolio: $10,015.52, Epsilon: 0.4785
# Episode 97/100, Reward: 55.5174, Portfolio: $10,055.52, Epsilon: 0.4783
# Episode 98/100, Reward: 136.3897, Portfolio: $10,136.39, Epsilon: 0.4780
# Episode 99/100, Reward: 107.7483, Portfolio: $10,107.75, Epsilon: 0.4778
# Episode 100/100, Reward: 93.4387, Portfolio: $10,093.44, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,018.41
# Total Return: 0.18%
# Total Trades Executed: 55
# Grid Levels: [103799.57 103895.38 103991.2  104087.02 104182.84 104278.65 104374.47
#  104470.29 104566.1  104661.92 104757.74 104853.56 104949.37 105045.19
#  105141.01 105236.83 105332.64 105428.46 105524.28]
# === Iteration 6 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 168.7983, Portfolio: $10,168.80, Epsilon: 0.4998
# Episode 2/100, Reward: 90.5896, Portfolio: $10,090.59, Epsilon: 0.4996
# Episode 3/100, Reward: 107.4654, Portfolio: $10,107.47, Epsilon: 0.4994
# Episode 4/100, Reward: 97.9211, Portfolio: $10,097.92, Epsilon: 0.4991
# Episode 5/100, Reward: 82.3157, Portfolio: $10,082.32, Epsilon: 0.4989
# Episode 6/100, Reward: 167.8283, Portfolio: $10,167.83, Epsilon: 0.4987
# Episode 7/100, Reward: 73.3900, Portfolio: $10,073.39, Epsilon: 0.4985
# Episode 8/100, Reward: 114.7553, Portfolio: $10,114.76, Epsilon: 0.4982
# Episode 9/100, Reward: 78.3583, Portfolio: $10,078.36, Epsilon: 0.4980
# Episode 10/100, Reward: 109.1675, Portfolio: $10,109.17, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 140.9108, Portfolio: $10,140.91, Epsilon: 0.4975
# Episode 12/100, Reward: 116.0848, Portfolio: $10,116.08, Epsilon: 0.4973
# Episode 13/100, Reward: 78.8343, Portfolio: $10,078.83, Epsilon: 0.4971
# Episode 14/100, Reward: 69.0797, Portfolio: $10,069.08, Epsilon: 0.4969
# Episode 15/100, Reward: 150.9669, Portfolio: $10,150.97, Epsilon: 0.4966
# Episode 16/100, Reward: 106.0283, Portfolio: $10,106.03, Epsilon: 0.4964
# Episode 17/100, Reward: 23.7391, Portfolio: $10,023.74, Epsilon: 0.4962
# Episode 18/100, Reward: 115.0240, Portfolio: $10,115.02, Epsilon: 0.4959
# Episode 19/100, Reward: 119.5147, Portfolio: $10,119.51, Epsilon: 0.4957
# Episode 20/100, Reward: 128.0026, Portfolio: $10,128.00, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 156.6801, Portfolio: $10,156.68, Epsilon: 0.4953
# Episode 22/100, Reward: 128.6251, Portfolio: $10,128.63, Epsilon: 0.4950
# Episode 23/100, Reward: 190.6170, Portfolio: $10,190.62, Epsilon: 0.4948
# Episode 24/100, Reward: 123.9307, Portfolio: $10,123.93, Epsilon: 0.4946
# Episode 25/100, Reward: 68.9917, Portfolio: $10,068.99, Epsilon: 0.4944
# Episode 26/100, Reward: 97.4010, Portfolio: $10,097.40, Epsilon: 0.4941
# Episode 27/100, Reward: 105.1346, Portfolio: $10,105.13, Epsilon: 0.4939
# Episode 28/100, Reward: 136.3436, Portfolio: $10,136.34, Epsilon: 0.4937
# Episode 29/100, Reward: 144.3438, Portfolio: $10,144.34, Epsilon: 0.4934
# Episode 30/100, Reward: 161.3222, Portfolio: $10,161.32, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 182.7975, Portfolio: $10,182.80, Epsilon: 0.4930
# Episode 32/100, Reward: 116.2228, Portfolio: $10,116.22, Epsilon: 0.4928
# Episode 33/100, Reward: 119.1009, Portfolio: $10,119.10, Epsilon: 0.4925
# Episode 34/100, Reward: 170.1447, Portfolio: $10,170.14, Epsilon: 0.4923
# Episode 35/100, Reward: 85.1895, Portfolio: $10,085.19, Epsilon: 0.4921
# Episode 36/100, Reward: 123.8988, Portfolio: $10,123.90, Epsilon: 0.4919
# Episode 37/100, Reward: 115.3263, Portfolio: $10,115.33, Epsilon: 0.4916
# Episode 38/100, Reward: 84.0964, Portfolio: $10,084.10, Epsilon: 0.4914
# Episode 39/100, Reward: 136.3223, Portfolio: $10,136.32, Epsilon: 0.4912
# Episode 40/100, Reward: 124.1651, Portfolio: $10,124.17, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 95.5351, Portfolio: $10,095.54, Epsilon: 0.4907
# Episode 42/100, Reward: 152.6196, Portfolio: $10,152.62, Epsilon: 0.4905
# Episode 43/100, Reward: 113.7426, Portfolio: $10,113.74, Epsilon: 0.4903
# Episode 44/100, Reward: 151.5516, Portfolio: $10,151.55, Epsilon: 0.4901
# Episode 45/100, Reward: 161.4276, Portfolio: $10,161.43, Epsilon: 0.4898
# Episode 46/100, Reward: 124.0516, Portfolio: $10,124.05, Epsilon: 0.4896
# Episode 47/100, Reward: 120.6321, Portfolio: $10,120.63, Epsilon: 0.4894
# Episode 48/100, Reward: 142.3596, Portfolio: $10,142.36, Epsilon: 0.4892
# Episode 49/100, Reward: 93.3020, Portfolio: $10,093.30, Epsilon: 0.4889
# Episode 50/100, Reward: 103.5369, Portfolio: $10,103.54, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 62.3526, Portfolio: $10,062.35, Epsilon: 0.4885
# Episode 52/100, Reward: 129.3109, Portfolio: $10,129.31, Epsilon: 0.4883
# Episode 53/100, Reward: 136.4910, Portfolio: $10,136.49, Epsilon: 0.4880
# Episode 54/100, Reward: 100.1111, Portfolio: $10,100.11, Epsilon: 0.4878
# Episode 55/100, Reward: 114.0543, Portfolio: $10,114.05, Epsilon: 0.4876
# Episode 56/100, Reward: 104.5791, Portfolio: $10,104.58, Epsilon: 0.4874
# Episode 57/100, Reward: 134.2762, Portfolio: $10,134.28, Epsilon: 0.4871
# Episode 58/100, Reward: 96.2189, Portfolio: $10,096.22, Epsilon: 0.4869
# Episode 59/100, Reward: 128.6480, Portfolio: $10,128.65, Epsilon: 0.4867
# Episode 60/100, Reward: 189.6396, Portfolio: $10,189.64, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 107.1458, Portfolio: $10,107.15, Epsilon: 0.4862
# Episode 62/100, Reward: 151.3057, Portfolio: $10,151.31, Epsilon: 0.4860
# Episode 63/100, Reward: 82.9486, Portfolio: $10,082.95, Epsilon: 0.4858
# Episode 64/100, Reward: 131.5152, Portfolio: $10,131.52, Epsilon: 0.4856
# Episode 65/100, Reward: 141.7887, Portfolio: $10,141.79, Epsilon: 0.4853
# Episode 66/100, Reward: 113.8056, Portfolio: $10,113.81, Epsilon: 0.4851
# Episode 67/100, Reward: 127.5854, Portfolio: $10,127.59, Epsilon: 0.4849
# Episode 68/100, Reward: 70.3808, Portfolio: $10,070.38, Epsilon: 0.4847
# Episode 69/100, Reward: 68.5574, Portfolio: $10,068.56, Epsilon: 0.4845
# Episode 70/100, Reward: 119.5691, Portfolio: $10,119.57, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 148.0157, Portfolio: $10,148.02, Epsilon: 0.4840
# Episode 72/100, Reward: 134.1705, Portfolio: $10,134.17, Epsilon: 0.4838
# Episode 73/100, Reward: 60.1392, Portfolio: $10,060.14, Epsilon: 0.4836
# Episode 74/100, Reward: 62.1269, Portfolio: $10,062.13, Epsilon: 0.4833
# Episode 75/100, Reward: 142.0408, Portfolio: $10,142.04, Epsilon: 0.4831
# Episode 76/100, Reward: 157.6455, Portfolio: $10,157.65, Epsilon: 0.4829
# Episode 77/100, Reward: 144.1293, Portfolio: $10,144.13, Epsilon: 0.4827
# Episode 78/100, Reward: 69.7683, Portfolio: $10,069.77, Epsilon: 0.4825
# Episode 79/100, Reward: 10.1881, Portfolio: $10,010.19, Epsilon: 0.4822
# Episode 80/100, Reward: 124.1224, Portfolio: $10,124.12, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 144.3887, Portfolio: $10,144.39, Epsilon: 0.4818
# Episode 82/100, Reward: 156.0520, Portfolio: $10,156.05, Epsilon: 0.4816
# Episode 83/100, Reward: 122.6009, Portfolio: $10,122.60, Epsilon: 0.4814
# Episode 84/100, Reward: 71.3117, Portfolio: $10,071.31, Epsilon: 0.4811
# Episode 85/100, Reward: 97.3808, Portfolio: $10,097.38, Epsilon: 0.4809
# Episode 86/100, Reward: 121.2268, Portfolio: $10,121.23, Epsilon: 0.4807
# Episode 87/100, Reward: 145.4451, Portfolio: $10,145.45, Epsilon: 0.4805
# Episode 88/100, Reward: 104.1220, Portfolio: $10,104.12, Epsilon: 0.4802
# Episode 89/100, Reward: 180.2091, Portfolio: $10,180.21, Epsilon: 0.4800
# Episode 90/100, Reward: 122.9601, Portfolio: $10,122.96, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 67.3351, Portfolio: $10,067.34, Epsilon: 0.4796
# Episode 92/100, Reward: 61.7873, Portfolio: $10,061.79, Epsilon: 0.4794
# Episode 93/100, Reward: 100.7242, Portfolio: $10,100.72, Epsilon: 0.4791
# Episode 94/100, Reward: 50.0277, Portfolio: $10,050.03, Epsilon: 0.4789
# Episode 95/100, Reward: 111.0921, Portfolio: $10,111.09, Epsilon: 0.4787
# Episode 96/100, Reward: 132.8099, Portfolio: $10,132.81, Epsilon: 0.4785
# Episode 97/100, Reward: 101.7173, Portfolio: $10,101.72, Epsilon: 0.4783
# Episode 98/100, Reward: 61.7310, Portfolio: $10,061.73, Epsilon: 0.4780
# Episode 99/100, Reward: 64.4929, Portfolio: $10,064.49, Epsilon: 0.4778
# Episode 100/100, Reward: 83.0846, Portfolio: $10,083.08, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $9,997.08
# Total Return: -0.03%
# Total Trades Executed: 71
# ...
# Episode 93/100, Reward: 195.9784, Portfolio: $10,195.98, Epsilon: 0.4791
# Episode 94/100, Reward: 190.3936, Portfolio: $10,190.39, Epsilon: 0.4789
# Episode 95/100, Reward: 186.0069, Portfolio: $10,186.01, Epsilon: 0.4787
# Episode 96/100, Reward: 192.7233, Portfolio: $10,192.72, Epsilon: 0.4785
# Episode 97/100, Reward: 197.9396, Portfolio: $10,197.94, Epsilon: 0.4783
# Episode 98/100, Reward: 185.7962, Portfolio: $10,185.80, Epsilon: 0.4780
# Episode 99/100, Reward: 193.6467, Portfolio: $10,193.65, Epsilon: 0.4778
# Episode 100/100, Reward: 167.8478, Portfolio: $10,167.85, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $9,976.21
# Total Return: -0.24%
# Total Trades Executed: 156
# Grid Levels: [103954.69 104042.35 104130.   104217.65 104305.3  104392.96 104480.61
#  104568.26 104655.91 104743.57 104831.22 104918.87 105006.53 105094.18
#  105181.83 105269.48 105357.14 105444.79 105532.44]
# === Iteration 8 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 87.6193, Portfolio: $10,087.62, Epsilon: 0.4998
# Episode 2/100, Reward: 22.5890, Portfolio: $10,022.59, Epsilon: 0.4996
# Episode 3/100, Reward: 33.9585, Portfolio: $10,033.96, Epsilon: 0.4994
# Episode 4/100, Reward: 59.4384, Portfolio: $10,059.44, Epsilon: 0.4991
# Episode 5/100, Reward: 63.6695, Portfolio: $10,063.67, Epsilon: 0.4989
# Episode 6/100, Reward: 139.5614, Portfolio: $10,139.56, Epsilon: 0.4987
# Episode 7/100, Reward: 96.8034, Portfolio: $10,096.80, Epsilon: 0.4985
# Episode 8/100, Reward: 115.4919, Portfolio: $10,115.49, Epsilon: 0.4982
# Episode 9/100, Reward: 114.3849, Portfolio: $10,114.38, Epsilon: 0.4980
# Episode 10/100, Reward: 77.2938, Portfolio: $10,077.29, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 53.9766, Portfolio: $10,053.98, Epsilon: 0.4975
# Episode 12/100, Reward: 124.9188, Portfolio: $10,124.92, Epsilon: 0.4973
# Episode 13/100, Reward: 148.9218, Portfolio: $10,148.92, Epsilon: 0.4971
# Episode 14/100, Reward: 76.6600, Portfolio: $10,076.66, Epsilon: 0.4969
# Episode 15/100, Reward: 15.9989, Portfolio: $10,016.00, Epsilon: 0.4966
# Episode 16/100, Reward: 146.8142, Portfolio: $10,146.81, Epsilon: 0.4964
# Episode 17/100, Reward: 127.0061, Portfolio: $10,127.01, Epsilon: 0.4962
# Episode 18/100, Reward: 85.3580, Portfolio: $10,085.36, Epsilon: 0.4959
# Episode 19/100, Reward: 72.5924, Portfolio: $10,072.59, Epsilon: 0.4957
# Episode 20/100, Reward: 103.6232, Portfolio: $10,103.62, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 94.5860, Portfolio: $10,094.59, Epsilon: 0.4953
# Episode 22/100, Reward: 135.9530, Portfolio: $10,135.95, Epsilon: 0.4950
# Episode 23/100, Reward: 84.1793, Portfolio: $10,084.18, Epsilon: 0.4948
# Episode 24/100, Reward: 118.1791, Portfolio: $10,118.18, Epsilon: 0.4946
# Episode 25/100, Reward: 153.8821, Portfolio: $10,153.88, Epsilon: 0.4944
# Episode 26/100, Reward: 1.3649, Portfolio: $10,001.36, Epsilon: 0.4941
# Episode 27/100, Reward: 57.4764, Portfolio: $10,057.48, Epsilon: 0.4939
# Episode 28/100, Reward: 67.9499, Portfolio: $10,067.95, Epsilon: 0.4937
# Episode 29/100, Reward: 92.0934, Portfolio: $10,092.09, Epsilon: 0.4934
# Episode 30/100, Reward: 48.0079, Portfolio: $10,048.01, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 66.5872, Portfolio: $10,066.59, Epsilon: 0.4930
# Episode 32/100, Reward: 69.0892, Portfolio: $10,069.09, Epsilon: 0.4928
# Episode 33/100, Reward: 95.7964, Portfolio: $10,095.80, Epsilon: 0.4925
# Episode 34/100, Reward: 125.4040, Portfolio: $10,125.40, Epsilon: 0.4923
# Episode 35/100, Reward: 119.0004, Portfolio: $10,119.00, Epsilon: 0.4921
# Episode 36/100, Reward: 90.0562, Portfolio: $10,090.06, Epsilon: 0.4919
# Episode 37/100, Reward: 111.6912, Portfolio: $10,111.69, Epsilon: 0.4916
# Episode 38/100, Reward: 77.4928, Portfolio: $10,077.49, Epsilon: 0.4914
# Episode 39/100, Reward: 54.9269, Portfolio: $10,054.93, Epsilon: 0.4912
# Episode 40/100, Reward: 118.0705, Portfolio: $10,118.07, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 48.5730, Portfolio: $10,048.57, Epsilon: 0.4907
# Episode 42/100, Reward: 74.5082, Portfolio: $10,074.51, Epsilon: 0.4905
# Episode 43/100, Reward: 59.3832, Portfolio: $10,059.38, Epsilon: 0.4903
# Episode 44/100, Reward: 94.8953, Portfolio: $10,094.90, Epsilon: 0.4901
# Episode 45/100, Reward: 34.7247, Portfolio: $10,034.72, Epsilon: 0.4898
# Episode 46/100, Reward: 97.5500, Portfolio: $10,097.55, Epsilon: 0.4896
# Episode 47/100, Reward: 54.3054, Portfolio: $10,054.31, Epsilon: 0.4894
# Episode 48/100, Reward: 46.9764, Portfolio: $10,046.98, Epsilon: 0.4892
# Episode 49/100, Reward: 71.7694, Portfolio: $10,071.77, Epsilon: 0.4889
# Episode 50/100, Reward: 115.4956, Portfolio: $10,115.50, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 83.6899, Portfolio: $10,083.69, Epsilon: 0.4885
# Episode 52/100, Reward: 132.5587, Portfolio: $10,132.56, Epsilon: 0.4883
# Episode 53/100, Reward: 58.3174, Portfolio: $10,058.32, Epsilon: 0.4880
# Episode 54/100, Reward: 32.7186, Portfolio: $10,032.72, Epsilon: 0.4878
# Episode 55/100, Reward: -1.6224, Portfolio: $9,998.38, Epsilon: 0.4876
# Episode 56/100, Reward: 90.8961, Portfolio: $10,090.90, Epsilon: 0.4874
# Episode 57/100, Reward: 69.4020, Portfolio: $10,069.40, Epsilon: 0.4871
# Episode 58/100, Reward: 82.0255, Portfolio: $10,082.03, Epsilon: 0.4869
# Episode 59/100, Reward: 3.5447, Portfolio: $10,003.54, Epsilon: 0.4867
# Episode 60/100, Reward: 52.6695, Portfolio: $10,052.67, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 69.4658, Portfolio: $10,069.47, Epsilon: 0.4862
# Episode 62/100, Reward: 59.5975, Portfolio: $10,059.60, Epsilon: 0.4860
# Episode 63/100, Reward: 109.2634, Portfolio: $10,109.26, Epsilon: 0.4858
# Episode 64/100, Reward: 61.1926, Portfolio: $10,061.19, Epsilon: 0.4856
# Episode 65/100, Reward: 136.5836, Portfolio: $10,136.58, Epsilon: 0.4853
# Episode 66/100, Reward: 78.0734, Portfolio: $10,078.07, Epsilon: 0.4851
# Episode 67/100, Reward: 44.6695, Portfolio: $10,044.67, Epsilon: 0.4849
# Episode 68/100, Reward: 46.3834, Portfolio: $10,046.38, Epsilon: 0.4847
# Episode 69/100, Reward: 99.6664, Portfolio: $10,099.67, Epsilon: 0.4845
# Episode 70/100, Reward: 64.9545, Portfolio: $10,064.95, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 77.5604, Portfolio: $10,077.56, Epsilon: 0.4840
# Episode 72/100, Reward: 140.8077, Portfolio: $10,140.81, Epsilon: 0.4838
# Episode 73/100, Reward: 100.1469, Portfolio: $10,100.15, Epsilon: 0.4836
# Episode 74/100, Reward: 67.7668, Portfolio: $10,067.77, Epsilon: 0.4833
# Episode 75/100, Reward: 136.2740, Portfolio: $10,136.27, Epsilon: 0.4831
# Episode 76/100, Reward: 90.4504, Portfolio: $10,090.45, Epsilon: 0.4829
# Episode 77/100, Reward: 64.2045, Portfolio: $10,064.20, Epsilon: 0.4827
# Episode 78/100, Reward: 77.4556, Portfolio: $10,077.46, Epsilon: 0.4825
# Episode 79/100, Reward: 68.2375, Portfolio: $10,068.24, Epsilon: 0.4822
# Episode 80/100, Reward: 116.3092, Portfolio: $10,116.31, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 121.7727, Portfolio: $10,121.77, Epsilon: 0.4818
# Episode 82/100, Reward: 15.8716, Portfolio: $10,015.87, Epsilon: 0.4816
# Episode 83/100, Reward: -4.3366, Portfolio: $9,995.66, Epsilon: 0.4814
# Episode 84/100, Reward: 56.7630, Portfolio: $10,056.76, Epsilon: 0.4811
# Episode 85/100, Reward: 97.7075, Portfolio: $10,097.71, Epsilon: 0.4809
# Episode 86/100, Reward: 70.1402, Portfolio: $10,070.14, Epsilon: 0.4807
# Episode 87/100, Reward: 117.7970, Portfolio: $10,117.80, Epsilon: 0.4805
# Episode 88/100, Reward: 61.8552, Portfolio: $10,061.86, Epsilon: 0.4802
# Episode 89/100, Reward: 136.7608, Portfolio: $10,136.76, Epsilon: 0.4800
# Episode 90/100, Reward: 89.8458, Portfolio: $10,089.85, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 124.2705, Portfolio: $10,124.27, Epsilon: 0.4796
# Episode 92/100, Reward: 114.3350, Portfolio: $10,114.34, Epsilon: 0.4794
# Episode 93/100, Reward: 112.3255, Portfolio: $10,112.33, Epsilon: 0.4791
# Episode 94/100, Reward: 99.9687, Portfolio: $10,099.97, Epsilon: 0.4789
# Episode 95/100, Reward: 53.2055, Portfolio: $10,053.21, Epsilon: 0.4787
# Episode 96/100, Reward: 25.3489, Portfolio: $10,025.35, Epsilon: 0.4785
# Episode 97/100, Reward: 162.6830, Portfolio: $10,162.68, Epsilon: 0.4783
# Episode 98/100, Reward: 93.6891, Portfolio: $10,093.69, Epsilon: 0.4780
# Episode 99/100, Reward: 43.4780, Portfolio: $10,043.48, Epsilon: 0.4778
# Episode 100/100, Reward: 96.9623, Portfolio: $10,096.96, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,013.96
# Total Return: 0.14%
# Total Trades Executed: 74
# Grid Levels: [104025.15 104109.09 104193.04 104276.98 104360.93 104444.87 104528.81
#  104612.76 104696.7  104780.65 104864.59 104948.54 105032.48 105116.43
#  105200.37 105284.32 105368.26 105452.21 105536.15]
# === Iteration 9 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 121.5585, Portfolio: $10,121.56, Epsilon: 0.4998
# Episode 2/100, Reward: 150.0025, Portfolio: $10,150.00, Epsilon: 0.4996
# Episode 3/100, Reward: 124.3571, Portfolio: $10,124.36, Epsilon: 0.4994
# Episode 4/100, Reward: 176.1463, Portfolio: $10,176.15, Epsilon: 0.4991
# Episode 5/100, Reward: 173.4521, Portfolio: $10,173.45, Epsilon: 0.4989
# Episode 6/100, Reward: 166.6741, Portfolio: $10,166.67, Epsilon: 0.4987
# Episode 7/100, Reward: 113.9792, Portfolio: $10,113.98, Epsilon: 0.4985
# Episode 8/100, Reward: 194.1120, Portfolio: $10,194.11, Epsilon: 0.4982
# Episode 9/100, Reward: 159.5344, Portfolio: $10,159.53, Epsilon: 0.4980
# Episode 10/100, Reward: 199.3913, Portfolio: $10,199.39, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 201.1247, Portfolio: $10,201.12, Epsilon: 0.4975
# Episode 12/100, Reward: 244.9850, Portfolio: $10,244.99, Epsilon: 0.4973
# Episode 13/100, Reward: 189.3032, Portfolio: $10,189.30, Epsilon: 0.4971
# Episode 14/100, Reward: 181.7262, Portfolio: $10,181.73, Epsilon: 0.4969
# Episode 15/100, Reward: 99.6396, Portfolio: $10,099.64, Epsilon: 0.4966
# Episode 16/100, Reward: 129.1145, Portfolio: $10,129.11, Epsilon: 0.4964
# Episode 17/100, Reward: 107.9274, Portfolio: $10,107.93, Epsilon: 0.4962
# Episode 18/100, Reward: 165.7637, Portfolio: $10,165.76, Epsilon: 0.4959
# Episode 19/100, Reward: 72.7262, Portfolio: $10,072.73, Epsilon: 0.4957
# Episode 20/100, Reward: 101.9371, Portfolio: $10,101.94, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 148.5069, Portfolio: $10,148.51, Epsilon: 0.4953
# Episode 22/100, Reward: 56.0864, Portfolio: $10,056.09, Epsilon: 0.4950
# Episode 23/100, Reward: 121.3668, Portfolio: $10,121.37, Epsilon: 0.4948
# Episode 24/100, Reward: 234.8791, Portfolio: $10,234.88, Epsilon: 0.4946
# Episode 25/100, Reward: 138.2298, Portfolio: $10,138.23, Epsilon: 0.4944
# Episode 26/100, Reward: 144.5119, Portfolio: $10,144.51, Epsilon: 0.4941
# Episode 27/100, Reward: 82.6505, Portfolio: $10,082.65, Epsilon: 0.4939
# Episode 28/100, Reward: 138.9095, Portfolio: $10,138.91, Epsilon: 0.4937
# Episode 29/100, Reward: 143.4621, Portfolio: $10,143.46, Epsilon: 0.4934
# Episode 30/100, Reward: 191.0096, Portfolio: $10,191.01, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 257.7188, Portfolio: $10,257.72, Epsilon: 0.4930
# Episode 32/100, Reward: 120.7779, Portfolio: $10,120.78, Epsilon: 0.4928
# Episode 33/100, Reward: 202.2657, Portfolio: $10,202.27, Epsilon: 0.4925
# Episode 34/100, Reward: 109.8841, Portfolio: $10,109.88, Epsilon: 0.4923
# Episode 35/100, Reward: 186.6165, Portfolio: $10,186.62, Epsilon: 0.4921
# Episode 36/100, Reward: 117.5710, Portfolio: $10,117.57, Epsilon: 0.4919
# Episode 37/100, Reward: 199.4361, Portfolio: $10,199.44, Epsilon: 0.4916
# Episode 38/100, Reward: 235.8893, Portfolio: $10,235.89, Epsilon: 0.4914
# Episode 39/100, Reward: 155.9158, Portfolio: $10,155.92, Epsilon: 0.4912
# Episode 40/100, Reward: 273.8892, Portfolio: $10,273.89, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 101.8797, Portfolio: $10,101.88, Epsilon: 0.4907
# Episode 42/100, Reward: 99.7343, Portfolio: $10,099.73, Epsilon: 0.4905
# Episode 43/100, Reward: 97.4826, Portfolio: $10,097.48, Epsilon: 0.4903
# Episode 44/100, Reward: 59.9401, Portfolio: $10,059.94, Epsilon: 0.4901
# Episode 45/100, Reward: 106.3892, Portfolio: $10,106.39, Epsilon: 0.4898
# Episode 46/100, Reward: 120.5525, Portfolio: $10,120.55, Epsilon: 0.4896
# Episode 47/100, Reward: 162.5281, Portfolio: $10,162.53, Epsilon: 0.4894
# Episode 48/100, Reward: 174.3085, Portfolio: $10,174.31, Epsilon: 0.4892
# Episode 49/100, Reward: 158.8605, Portfolio: $10,158.86, Epsilon: 0.4889
# Episode 50/100, Reward: 137.7426, Portfolio: $10,137.74, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 135.0297, Portfolio: $10,135.03, Epsilon: 0.4885
# Episode 52/100, Reward: 129.7935, Portfolio: $10,129.79, Epsilon: 0.4883
# Episode 53/100, Reward: 160.3275, Portfolio: $10,160.33, Epsilon: 0.4880
# Episode 54/100, Reward: 194.2253, Portfolio: $10,194.23, Epsilon: 0.4878
# Episode 55/100, Reward: 212.8785, Portfolio: $10,212.88, Epsilon: 0.4876
# Episode 56/100, Reward: 170.5058, Portfolio: $10,170.51, Epsilon: 0.4874
# Episode 57/100, Reward: 185.3153, Portfolio: $10,185.32, Epsilon: 0.4871
# Episode 58/100, Reward: 83.7135, Portfolio: $10,083.71, Epsilon: 0.4869
# Episode 59/100, Reward: 196.3892, Portfolio: $10,196.39, Epsilon: 0.4867
# Episode 60/100, Reward: 130.0153, Portfolio: $10,130.02, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 124.7666, Portfolio: $10,124.77, Epsilon: 0.4862
# Episode 62/100, Reward: 146.2557, Portfolio: $10,146.26, Epsilon: 0.4860
# Episode 63/100, Reward: 131.5513, Portfolio: $10,131.55, Epsilon: 0.4858
# Episode 64/100, Reward: 80.0352, Portfolio: $10,080.04, Epsilon: 0.4856
# Episode 65/100, Reward: 172.7172, Portfolio: $10,172.72, Epsilon: 0.4853
# Episode 66/100, Reward: 77.9371, Portfolio: $10,077.94, Epsilon: 0.4851
# Episode 67/100, Reward: 152.4461, Portfolio: $10,152.45, Epsilon: 0.4849
# Episode 68/100, Reward: 137.7551, Portfolio: $10,137.76, Epsilon: 0.4847
# Episode 69/100, Reward: 192.1064, Portfolio: $10,192.11, Epsilon: 0.4845
# Episode 70/100, Reward: 171.0224, Portfolio: $10,171.02, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 132.6098, Portfolio: $10,132.61, Epsilon: 0.4840
# Episode 72/100, Reward: 117.7453, Portfolio: $10,117.75, Epsilon: 0.4838
# Episode 73/100, Reward: 96.7381, Portfolio: $10,096.74, Epsilon: 0.4836
# Episode 74/100, Reward: 206.8097, Portfolio: $10,206.81, Epsilon: 0.4833
# Episode 75/100, Reward: 126.4644, Portfolio: $10,126.46, Epsilon: 0.4831
# Episode 76/100, Reward: 68.5336, Portfolio: $10,068.53, Epsilon: 0.4829
# Episode 77/100, Reward: 211.7459, Portfolio: $10,211.75, Epsilon: 0.4827
# Episode 78/100, Reward: 154.8230, Portfolio: $10,154.82, Epsilon: 0.4825
# Episode 79/100, Reward: 146.7666, Portfolio: $10,146.77, Epsilon: 0.4822
# Episode 80/100, Reward: 136.1758, Portfolio: $10,136.18, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 157.3598, Portfolio: $10,157.36, Epsilon: 0.4818
# Episode 82/100, Reward: 137.6851, Portfolio: $10,137.69, Epsilon: 0.4816
# Episode 83/100, Reward: 75.9592, Portfolio: $10,075.96, Epsilon: 0.4814
# Episode 84/100, Reward: 139.4667, Portfolio: $10,139.47, Epsilon: 0.4811
# Episode 85/100, Reward: 200.3975, Portfolio: $10,200.40, Epsilon: 0.4809
# Episode 86/100, Reward: 147.5089, Portfolio: $10,147.51, Epsilon: 0.4807
# Episode 87/100, Reward: 61.2535, Portfolio: $10,061.25, Epsilon: 0.4805
# Episode 88/100, Reward: 166.0869, Portfolio: $10,166.09, Epsilon: 0.4802
# Episode 89/100, Reward: 128.7876, Portfolio: $10,128.79, Epsilon: 0.4800
# Episode 90/100, Reward: 102.2826, Portfolio: $10,102.28, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 61.3573, Portfolio: $10,061.36, Epsilon: 0.4796

# %%
import os
import time
import schedule
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from binance.client import Client
from binance.exceptions import BinanceAPIException, BinanceOrderException
from collections import deque
import joblib # For loading scaler  

# --- Configuration (mostly from your Cell 1) ---
TICKER = 'BTCUSDT'
SEQ_LENGTH = 60
PREDICTION_STEPS = 1 # Not directly used in live state construction if LSTM predicts next price
INITIAL_BALANCE_REF = 10000.0 # Reference for normalization, actual balance managed live
TRADE_FEE_RATE = 0.0001 # For local simulation if needed, actual fees by Binance
MIN_TRADE_AMOUNT_USD = 10 # Minimum trade value in USD
GRID_COUNT = 100
LSTM_INPUT_FEATURES = 7 # open, high, low, close, volume, Returns, Volatility
DQN_STATE_SIZE = 11    # 7 market features + norm_balance + norm_btc_value + grid_pos + pred/price
ACTION_SIZE = 3        # Hold, Buy, Sell

# Live trading parameters
LIVE_RECALIBRATION_INTERVAL = 200 # Steps (minutes)
LIVE_LOOKBACK_WINDOW_GRID = 500 # Steps (minutes) for grid recalc
ORDER_TYPE = Client.ORDER_TYPE_MARKET

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device for live trading: {device}")

# --- Global State (Initialize once) ---
# These will be initialized in start_live_trading_bot()
binance_client = None
lstm_predictor_live = None
dqn_agent_live = None
min_max_scaler_live = None

# Portfolio and Grid State
current_usdt_balance = 1000.0 # Example: Starting USDT for live test
current_btc_held = 0.0
current_grid_levels = np.array([])
live_steps_since_recal = 0
live_recent_prices_for_grid = deque(maxlen=LIVE_LOOKBACK_WINDOW_GRID)

# --- Helper: Load your LSTMPredictor and DQN classes (copy from Cell 1) ---
# class LSTMPredictor(nn.Module): ... (already defined in your notebook)
# class DQN(nn.Module): ... (already defined in your notebook)
# class DoubleDQNAgent: ... (already defined in your notebook, we only need its model for acting)
# def create_grids(prices, num_grids=GRID_COUNT): ... (already defined)
# def get_binance_data(...): ... (already defined)

def initialize_live_trader():
    global binance_client, lstm_predictor_live, dqn_agent_live, min_max_scaler_live
    global current_grid_levels, current_usdt_balance, current_btc_held

    # 1. Initialize Binance Client (Testnet)

    api_key = 'OrR1dfYW9wa8pjjgfOrk5XhdICHZEwFvsKSCgmUgyGrFu7YMfvR2WBhbTMELu858'
    api_secret = 'JOENNjZJ7PWeVp6GbQBMcBJC95VzjlASitaeSVol1jIzjmIpnLXUWsganegbQZVE'
    if not api_key or not api_secret:
        print("FATAL: Binance Testnet API keys not found in environment variables.")
        return False
    binance_client = Client(api_key, api_secret, testnet=True)
    try:
        binance_client.ping()
        print("Binance Testnet client initialized and connected.")
    except Exception as e:
        print(f"Failed to connect to Binance Testnet: {e}")
        return False

    # 2. Load Scaler
    try:
        min_max_scaler_live = joblib.load('min_max_scaler.joblib')
        print("MinMaxScaler loaded successfully.")
    except FileNotFoundError:
        print("FATAL: min_max_scaler.joblib not found. Train model first to generate it.")
        return False
    except Exception as e:
        print(f"Error loading scaler: {e}")
        return False

    # 3. Load LSTM Predictor
    lstm_predictor_live = LSTMPredictor(input_size=LSTM_INPUT_FEATURES).to(device)
    try:
        lstm_predictor_live.load_state_dict(torch.load(LSTM_PATH, map_location=device))
        lstm_predictor_live.eval()
        print("LSTM model loaded successfully.")
    except FileNotFoundError:
        print("FATAL: lstm_predictor_fixed_grid2.pth not found.")
        return False
    except Exception as e:
        print(f"Error loading LSTM model: {e}")
        return False

    # 4. Load DQN Agent's Model
    # We need the DoubleDQNAgent class definition if not already available globally
    # For simplicity, we'll load the state_dict into a DQN model instance
    dqn_model_live = DQN(DQN_STATE_SIZE, ACTION_SIZE).to(device)
    try:
        # Assuming doubledqn_agent_fixed_grid.pth saves the model.state_dict()
        dqn_model_live.load_state_dict(torch.load(DOUBLE_DQN_PATH, map_location=device))
        dqn_model_live.eval()
        # Wrap it in a simple structure for the .act() method or use dqn_model_live directly
        class TempDoubleDQNAgent:
            def __init__(self, model):
                self.model = model
                self.action_size = model.fc3.out_features # Infer action_size
                self.epsilon = 0.0 # No exploration in live trading

            def act(self, state_tensor): # Expects a tensor
                if np.random.rand() <= self.epsilon:
                    return random.randrange(self.action_size)
                with torch.no_grad():
                    q_values = self.model(state_tensor)
                return torch.argmax(q_values).item()

        dqn_agent_live = TempDoubleDQNAgent(dqn_model_live)
        print("DQN model loaded successfully.")

    except FileNotFoundError:
        print("FATAL: doubledqn_agent_fixed_grid.pth not found.")
        return False
    except Exception as e:
        print(f"Error loading DQN model: {e}")
        return False

    # 5. Initialize Grids (fetch some recent data to base them on)
    print("Fetching initial data for grid setup...")
    initial_price_data = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='200')
    if not initial_price_data.empty and len(initial_price_data) > 20:
        current_grid_levels = create_grids(initial_price_data['close'].values, GRID_COUNT)
        print(f"Initial grid levels created: {np.around(current_grid_levels[:5], 2)}... (first 5)")
        # Populate recent prices for adaptive grid
        for price in initial_price_data['close'].values[-(LIVE_LOOKBACK_WINDOW_GRID//2):]: # prime part of it
            live_recent_prices_for_grid.append(price)
    else:
        print("Could not fetch enough initial data for grid setup. Using default wide grids.")
        # Fallback grids if data fetch fails, adjust as needed
        avg_price_guess = 60000
        current_grid_levels = np.linspace(avg_price_guess * 0.8, avg_price_guess * 1.2, GRID_COUNT + 1)[1:-1]

    # Fetch initial balance from Testnet (optional, or use hardcoded start)
    # For this example, we use the hardcoded current_usdt_balance and current_btc_held
    print(f"Initial live trading balance: USDT: {current_usdt_balance}, BTC: {current_btc_held}")

    return True


def recalculate_grids_live(prices_list):
    """Recalculate grids based on recent price window for live trading."""
    if not prices_list or len(prices_list) < 50: # Need enough data
        return current_grid_levels # Return existing if not enough data
    
    recent_prices = np.array(prices_list)
    low = np.percentile(recent_prices, 10)
    high = np.percentile(recent_prices, 90)
    
    if high <= low: # Safety check
        print("Warning: Grid recalculation - high <= low. Widening range.")
        high = low * 1.05 # Ensure some spread
        if high == low : high = low + 100 # if low is 0 or very small

    new_grids = np.linspace(low, high, num=GRID_COUNT + 1)[1:-1]
    if len(new_grids) == 0: # another safety
        print("Warning: Grid recalculation resulted in empty grids. Keeping old ones.")
        return current_grid_levels
    return new_grids


def run_live_trading_cycle():
    global current_usdt_balance, current_btc_held, current_grid_levels
    global live_steps_since_recal, live_recent_prices_for_grid
    global lstm_predictor_live, dqn_agent_live, min_max_scaler_live, binance_client

    print(f"\n[{time.ctime()}] --- Running Live Trading Cycle ---")

    # 1. Fetch Market Data
    # Need SEQ_LENGTH for LSTM input + some buffer for feature calculation (e.g., rolling volatility)
    # The number of features for scaling is 7: 'open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility'
    required_klines = SEQ_LENGTH + 20 # 20 for rolling window of volatility
    df_live_raw = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback=str(required_klines))

    if df_live_raw.empty or len(df_live_raw) < required_klines:
        print("Not enough live data fetched. Skipping cycle.")
        return

    current_price = df_live_raw['close'].iloc[-1]
    live_recent_prices_for_grid.append(current_price)
    print(f"Current Price ({TICKER}): {current_price:.2f}")

    # 2. Preprocess Data for LSTM
    df_features = df_live_raw[['open', 'high', 'low', 'close', 'volume']].copy()
    df_features['Returns'] = df_features['close'].pct_change()
    df_features['Volatility'] = df_features['Returns'].rolling(window=20).std() # Match training
    df_features.dropna(inplace=True) # Remove NaNs from rolling calculations

    if len(df_features) < SEQ_LENGTH:
        print("Not enough data after feature engineering. Skipping cycle.")
        return

    # Select the exact features used for scaling during training
    features_to_scale = df_features[['open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility']]
    scaled_live_features = min_max_scaler_live.transform(features_to_scale)
    
    lstm_input_sequence = scaled_live_features[-SEQ_LENGTH:] # Shape: (SEQ_LENGTH, LSTM_INPUT_FEATURES)
    lstm_input_tensor = torch.tensor(lstm_input_sequence[np.newaxis, ...], dtype=torch.float32).to(device)

    # 3. Get LSTM Prediction
    with torch.no_grad():
        # Assuming LSTM predicts the next closing price (actual value, not scaled)
        # This needs to match how LSTM was trained and how its output was used in env.get_state()
        lstm_predicted_price = lstm_predictor_live(lstm_input_tensor).cpu().item()
    
    # The state uses prediction / price.
    # If LSTM output is already a price, this is fine.
    # If LSTM output is scaled, it needs to be inverse_transformed first.
    # Your LSTMPredictor outputs a single value, assumed to be the price prediction.
    normalized_lstm_prediction = lstm_predicted_price / current_price if current_price != 0 else 0
    print(f"LSTM Predicted Price: {lstm_predicted_price:.2f}, Normalized for state: {normalized_lstm_prediction:.4f}")

    # 4. Construct DQN State
    # Last tick of scaled data for the state
    current_scaled_market_data_tick = lstm_input_sequence[-1] 
    
    # Grid position
    if len(current_grid_levels) == 0: # Safety for uninitialized grids
        grid_position_live = 0.5 # Default to middle
    else:
        grid_position_live = np.digitize(current_price, current_grid_levels) / len(current_grid_levels) # Normalized
        grid_position_live = np.clip(grid_position_live, 0, 1) # Ensure it's within [0,1]


    # Normalize balance and holdings for the state
    # Using INITIAL_BALANCE_REF as the denominator for normalization consistency
    norm_balance = current_usdt_balance / INITIAL_BALANCE_REF
    norm_btc_value = (current_btc_held * current_price) / INITIAL_BALANCE_REF

    live_state_np = np.array([
        *current_scaled_market_data_tick,
        norm_balance,
        norm_btc_value,
        grid_position_live,
        normalized_lstm_prediction
    ], dtype=np.float32)

    if len(live_state_np) != DQN_STATE_SIZE:
        print(f"FATAL: Constructed state size {len(live_state_np)} != DQN_STATE_SIZE {DQN_STATE_SIZE}. Mismatch in features.")
        return

    live_state_tensor = torch.tensor(live_state_np, dtype=torch.float32).unsqueeze(0).to(device)

    # 5. Get DQN Action
    action = dqn_agent_live.act(live_state_tensor) # 0: hold, 1: buy, 2: sell
    action_map = {0: "HOLD", 1: "BUY", 2: "SELL"}
    print(f"DQN Action: {action_map[action]}")

    # 6. Execute Trade
    if action == 1:  # Buy
        # Logic adapted from your TradingEnvironment.step()
        # Buy more when price is near lower grids (grid_position_live close to 0)
        buy_multiplier = max(0.1, 1 - grid_position_live)
        # Example: allocate a percentage of balance based on multiplier, e.g., 5% of balance * multiplier
        # This is a simplification; your original code might have more complex sizing.
        # Ensure this is a dynamic part of your strategy.
        # Let's say we decide to use up to 10% of available USDT balance for a trade, scaled by multiplier
        max_spend_usd = current_usdt_balance * 0.10 
        amount_to_spend_usd = max_spend_usd * buy_multiplier
        
        if amount_to_spend_usd >= MIN_TRADE_AMOUNT_USD and current_usdt_balance >= amount_to_spend_usd :
            print(f"Attempting BUY: Spend {amount_to_spend_usd:.2f} USDT for {TICKER} at ~{current_price:.2f}")
            try:
                order = binance_client.create_order( # Use create_order for real testnet trades
                    symbol=TICKER,
                    side=Client.SIDE_BUY,
                    type=ORDER_TYPE,
                    quoteOrderQty=f"{amount_to_spend_usd:.8f}") # Binance API needs string for precision
                print(f"BUY Test Order successful: {order}")
                # For real orders, you'd update balance after confirmation:
                # current_usdt_balance -= actual_cost_from_order_fills
                # current_btc_held += actual_btc_bought_from_order_fills
            except BinanceAPIException as e:
                print(f"Binance API Exception (BUY): {e}")
            except Exception as e:
                print(f"Error executing BUY order: {e}")
        else:
            print(f"BUY condition not met: Spend amount {amount_to_spend_usd:.2f} < min OR insufficient balance.")

    elif action == 2:  # Sell
        # Sell more when price is near upper grids (grid_position_live close to 1)
        sell_multiplier = max(0.1, grid_position_live)
        # Example: sell a percentage of BTC holdings, e.g., 10% of holdings * multiplier
        max_sell_btc = current_btc_held * 0.10 
        amount_to_sell_btc = max_sell_btc * sell_multiplier
        
        value_of_btc_to_sell = amount_to_sell_btc * current_price
        if current_btc_held > 0 and amount_to_sell_btc > 0 and value_of_btc_to_sell >= MIN_TRADE_AMOUNT_USD:
             # Ensure quantity meets Binance minimums (e.g. for BTC often 0.00001, check symbol info)
            min_btc_qty_binance = 0.00001 # Example, fetch dynamically for robustness
            if amount_to_sell_btc < min_btc_qty_binance:
                print(f"SELL quantity {amount_to_sell_btc:.8f} BTC is below Binance minimum {min_btc_qty_binance:.8f} BTC.")
            else:
                print(f"Attempting SELL: {amount_to_sell_btc:.8f} {TICKER} at ~{current_price:.2f}")
                try:
                    order = binance_client.create_order( # Use create_order for real testnet trades
                        symbol=TICKER,
                        side=Client.SIDE_SELL,
                        type=ORDER_TYPE,
                        quantity=f"{amount_to_sell_btc:.8f}") # Binance API needs string for precision
                    print(f"SELL Test Order successful: {order}")
                    # For real orders, update balance:
                    # current_usdt_balance += actual_revenue_from_order_fills
                    # current_btc_held -= actual_btc_sold_from_order_fills
                except BinanceAPIException as e:
                    print(f"Binance API Exception (SELL): {e}")
                except Exception as e:
                    print(f"Error executing SELL order: {e}")
        else:
            print(f"SELL condition not met: Sell amount {amount_to_sell_btc:.8f} BTC (value {value_of_btc_to_sell:.2f} USD) too small or no BTC held.")
    
    print(f"Current Portfolio: USDT: {current_usdt_balance:.2f}, BTC: {current_btc_held:.8f}, Value: ~{(current_usdt_balance + current_btc_held * current_price):.2f} USDT")

    # 7. Adapt Grids Periodically
    live_steps_since_recal += 1
    if live_steps_since_recal >= LIVE_RECALIBRATION_INTERVAL:
        if len(live_recent_prices_for_grid) >= LIVE_LOOKBACK_WINDOW_GRID:
            print("Recalculating grid levels...")
            new_grids = recalculate_grids_live(list(live_recent_prices_for_grid))
            if not np.array_equal(new_grids, current_grid_levels) and len(new_grids) > 0:
                 current_grid_levels = new_grids
                 print(f"Grid levels adapted. New first 5: {np.around(current_grid_levels[:5], 2)}...")
            else:
                print("Grid levels unchanged or recalculation failed.")
            live_steps_since_recal = 0
        else:
            print(f"Not enough data in live_recent_prices_for_grid ({len(live_recent_prices_for_grid)}/{LIVE_LOOKBACK_WINDOW_GRID}) to adapt grids yet.")


def start_live_trading_bot():
    print("Initializing live trading bot...")
    if not initialize_live_trader():
        print("Bot initialization failed. Exiting.")
        return

    print("Live trading bot initialized. Starting 1-minute trading cycle.")
    print("Using TEST orders. For actual Testnet trades, change create_test_order to create_order.")
    print("Press Ctrl+C to stop the bot.")

    # Run the first cycle immediately
    run_live_trading_cycle() 
    
    # Schedule the job
    schedule.every(1).minutes.do(run_live_trading_cycle)

    while True:
        try:
            schedule.run_pending()
            time.sleep(1)
        except KeyboardInterrupt:
            print("\nStopping live trading bot...")
            break
        except Exception as e:
            print(f"An error occurred in the main loop: {e}")
            time.sleep(60) # Wait a bit before retrying if a major error occurs

# To run the bot:
start_live_trading_bot()
# Out:
# Using device for live trading: cuda
# Initializing live trading bot...
# Binance Testnet client initialized and connected.
# MinMaxScaler loaded successfully.
# LSTM model loaded successfully.
# DQN model loaded successfully.
# Fetching initial data for grid setup...
# Initial grid levels created: [104693.26 104698.08 104702.9  104707.71 104712.53]... (first 5)
# Initial live trading balance: USDT: 1000.0, BTC: 0.0
# Live trading bot initialized. Starting 1-minute trading cycle.
# Using TEST orders. For actual Testnet trades, change create_test_order to create_order.
# Press Ctrl+C to stop the bot.
#
# [Fri Jun 13 19:50:50 2025] --- Running Live Trading Cycle ---
# Current Price (BTCUSDT): 104968.01
# LSTM Predicted Price: 107519.86, Normalized for state: 1.0243
# DQN Action: HOLD
# Current Portfolio: USDT: 1000.00, BTC: 0.00000000, Value: ~1000.00 USDT

# %%
from binance.client import Client

api_key = 'OrR1dfYW9wa8pjjgfOrk5XhdICHZEwFvsKSCgmUgyGrFu7YMfvR2WBhbTMELu858'
api_secret = 'JOENNjZJ7PWeVp6GbQBMcBJC95VzjlASitaeSVol1jIzjmIpnLXUWsganegbQZVE'
client = Client(api_key, api_secret)
client.API_URL = 'https://testnet.binance.vision/api'

# Get current market price for BTC/USDT
ticker = client.get_symbol_ticker(symbol='BTCUSDT')
market_price = float(ticker['price'])

print(f"Current BTC/USDT Market Price: {market_price}")

# %%
usdt_to_spend = 10  # for example
quantity_to_buy = round(usdt_to_spend / market_price, 6)  # 6 decimal precision
print(f"Quantity of BTC to buy with ${usdt_to_spend}: {quantity_to_buy}")

# %%
client.order_market_buy(symbol='BTCUSDT', quantity=0.001)
client.order_market_sell(symbol='BTCUSDT', quantity=0.001)

# %%
client.order_market_buy(symbol='BTCUSDT', quoteOrderQty=100)
client.order_market_sell(symbol='BTCUSDT', quoteOrderQty=100)
