# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
import random
from collections import deque
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
import os
# Configuration
TICKER = 'BTCUSDT'
SEQ_LENGTH = 60
PREDICTION_STEPS = 10
INITIAL_BALANCE = 10000.0
TRADE_FEE_RATE = 0.0001
MIN_TRADE_AMOUNT = 10
GRID_COUNT = 20
EPOCHS = 0
EPISODES = 100
BATCH_SIZE = 256
MEMORY_SIZE = 10000
GAMMA = 0.95
EPSILON_DECAY = 0.9999995
MIN_EPSILON = 0.1
LEARNING_RATE = 0.0001
TARGET_UPDATE_FREQ = 100
LSTM_LEARNING_RATE = 100
LSTM_PATH = 'lstm_predictor_fixed_grid2.pth'
DOUBLE_DQN_PATH = 'dqn_agent_fixed_grid.pth'

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

class DataProcessor:
    def __init__(self, filepath):
        self.data = pd.read_csv(filepath)
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        
    def preprocess(self):
        df = self.data.copy()
        # Feature engineering
        df['Returns'] = df['close'].pct_change()
        df['Volatility'] = df['Returns'].rolling(20).std()
        df.dropna(inplace=True)
        
        # Scale features
        scaled = self.scaler.fit_transform(df[['open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility']])
        return scaled, df['close'].values
    
    def create_sequences(self, data, target):
        X, y = [], []
        for i in range(len(data) - SEQ_LENGTH - PREDICTION_STEPS):
            X.append(data[i:i+SEQ_LENGTH])
            y.append(target[i+SEQ_LENGTH+PREDICTION_STEPS-1])
        return np.array(X), np.array(y)

class AdaptiveLRScheduler:
    def __init__(self, optimizer, patience=5, factor=0.5, min_lr=1e-20, max_lr=1.0, threshold=1e-4, fluctuation_threshold=0.2):
        self.optimizer = optimizer
        self.patience = patience
        self.factor = factor
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.threshold = threshold
        self.fluctuation_threshold = fluctuation_threshold
        
        self.loss_history = []
        self.wait = 0
        self.best_loss = float('inf')
    def step(self, current_loss):
        self.loss_history.append(current_loss)

        if len(self.loss_history) > 2:
            fluctuation = abs(self.loss_history[-1] - self.loss_history[-2]) / (self.loss_history[-2] + 1e-8)
        else:
            fluctuation = 0

        # 1. Detect fluctuations
        if fluctuation > self.fluctuation_threshold:
            self._reduce_lr("High fluctuation detected")
            self.wait = 0
            return

        # 2. Detect improvement
        improvement = self.best_loss - current_loss
        if improvement > self.threshold:
            self.best_loss = current_loss
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self._reduce_lr("Loss plateau detected")
                self.wait = 0

    def _reduce_lr(self, reason):
        for param_group in self.optimizer.param_groups:
            old_lr = param_group['lr']
            new_lr = max(old_lr * self.factor, self.min_lr)
            param_group['lr'] = new_lr
        print(f"[LR SCHEDULER] {reason}. LR reduced to: {new_lr:.10f}")

class LSTMPredictor(nn.Module):
    def __init__(self, input_size, hidden_size=50, num_layers=2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

    def save(self, path, best_loss):
        torch.save({
            'model_state_dict': self.state_dict(),
            'best_loss': best_loss
        }, path)
        print(best_loss)
    def load(self, path, map_location=None):
        if os.path.exists(path):
            checkpoint = torch.load(path, map_location=map_location)
            self.load_state_dict(checkpoint['model_state_dict'])
            self.eval()  # Optional: switch to eval mode.
            return checkpoint.get('best_loss', float('inf'))
        else:
            print(f"⚠️ Warning: No checkpoint found at {path}.")
            return float('inf')


class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class TradingEnvironment:
    def __init__(self, data, prices, predictor, grids):
        self.data = data
        self.prices = prices
        self.predictor = predictor
        self.grids = grids
        self.reset()
        
    def reset(self):
        self.current_step = SEQ_LENGTH
        self.balance = INITIAL_BALANCE
        self.btc_held = 0.0
        self.portfolio_value = [INITIAL_BALANCE]
        self.trades = []
        self.done = False
        self.prev_portfolio_value = INITIAL_BALANCE   # <-- Add this line
        return self.get_state()

    
    def get_state(self):
        current_data = self.data[self.current_step]
        price = self.prices[self.current_step]
        grid_position = np.digitize(price, self.grids) / GRID_COUNT
        
        # Get prediction
        with torch.no_grad():
            seq_data = self.data[self.current_step-SEQ_LENGTH:self.current_step]
            seq_tensor = torch.tensor(seq_data[np.newaxis, ...], dtype=torch.float32).to(device)
            prediction = self.predictor(seq_tensor).cpu().item()
        
        return np.array([
            *current_data,
            self.balance / INITIAL_BALANCE,
            self.btc_held * price / INITIAL_BALANCE,
            grid_position,
            prediction / price
        ])
    
    def execute_trade(self, action, amount):
        fee = amount * TRADE_FEE_RATE
        return amount - fee
    
    def step(self, action):
        """
        Actions:
        0 = hold
        1 = buy
        2 = sell
        """
        price = self.prices[self.current_step]
        grid_position = np.digitize(price, self.grids) / len(self.grids)  # normalized 0-1
        
        trade_amount = 0
        min_trade_usd = 10  # Minimum USD amount per trade, for example
        min_trade_btc = 0.001  # Minimum BTC amount per trade
        
        if action == 1:  # Buy
            # Buy more when price is near lower grids (grid_position close to 0)
            multiplier = max(0.1, 1 - grid_position)  # from 1 at bottom grid to 0.1 near top grid
            amount_to_spend = self.balance * multiplier
            trade_amount = max(amount_to_spend, min_trade_usd)
            
            btc_to_buy = trade_amount / price
            btc_to_buy = min(btc_to_buy, self.balance / price)  # Can't buy more than balance allows
            btc_to_buy = max(btc_to_buy, min_trade_btc)
            
            # Execute buy
            cost = btc_to_buy * price
            if cost <= self.balance:
                self.balance -= cost
                self.btc_held += btc_to_buy
                self.trades.append(('buy', price, self.current_step))
        
        elif action == 2:  # Sell
            # Sell more when price is near upper grids (grid_position close to 1)
            multiplier = max(0.1, grid_position)  # from 0.1 at bottom grid to 1 near top grid
            btc_to_sell = self.btc_held * multiplier
            btc_to_sell = max(btc_to_sell, min_trade_btc)
            
            # Execute sell
            if btc_to_sell <= self.btc_held:
                revenue = btc_to_sell * price
                self.balance += revenue
                self.btc_held -= btc_to_sell
                self.trades.append(('sell', price, self.current_step))
        
        else:
            # Hold - no trade
            pass
        
        # Update portfolio value, rewards, etc.
        self.current_step += 1
        self.done = self.current_step >= len(self.prices) - 1
        
        portfolio_value = self.balance + self.btc_held * price
        reward = portfolio_value - self.prev_portfolio_value
        self.prev_portfolio_value = portfolio_value
        
        next_state = self.get_state()
        
        return next_state, reward, self.done, portfolio_value

class AdaptiveTradingEnvironment(TradingEnvironment):
    def __init__(self, data, prices, predictor, initial_grids, 
                 recalibration_interval=100, lookback_window=500):
        self.original_grids = initial_grids
        self.recalibration_interval = recalibration_interval
        self.lookback_window = lookback_window
        self.steps_since_recalibration = 0
        self.grid_history = [initial_grids.copy()]
        super().__init__(data, prices, predictor, initial_grids)
    def reset(self):
        self.steps_since_recalibration = 0
        self.grids = self.original_grids.copy()
        return super().reset()
    
    def recalculate_grids(self):
        """Recalculate grids based on recent price window"""
        start_idx = max(0, self.current_step - self.lookback_window)
        recent_prices = self.prices[start_idx:self.current_step]
        
        # Use percentiles to avoid extreme values
        low = np.percentile(recent_prices, 10)  # 10th percentile
        high = np.percentile(recent_prices, 90)  # 90th percentile
        
        # Safety checks
        if high <= low:
            high = low * 1.2  # Prevent invalid range
            
        new_grids = np.linspace(low, high, num=GRID_COUNT+1)[1:-1]
        self.grid_history.append(new_grids)
        return new_grids
    
    def step(self, action):
        # Recalculate grids periodically
        self.steps_since_recalibration += 1
        if self.steps_since_recalibration >= self.recalibration_interval:
            self.grids = self.recalculate_grids()
            self.steps_since_recalibration = 0
        
        return super().step(action)
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=MEMORY_SIZE)
        self.epsilon = 1
        self.model = DQN(state_size, action_size).to(device)
        self.target_model = DQN(state_size, action_size).to(device)
        self.target_model.load_state_dict(self.model.state_dict())
        self.target_model.eval()
        self.optimizer = optim.Adam(self.model.parameters(), lr=LEARNING_RATE)
        self.scheduler = StepLR(self.optimizer, step_size=50, gamma=0.95)
        self.criterion = nn.MSELoss()
        self.steps = 0
    
    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            with torch.no_grad():
                q_values = self.model(state_tensor)
            return torch.argmax(q_values).item()
    
    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        
        minibatch = random.sample(self.memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)
        
        states = torch.tensor(np.array(states), dtype=torch.float32).to(device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32).to(device)
        dones = torch.tensor(dones, dtype=torch.float32).to(device)
        
        # Get current Q values
        current_q = self.model(states).gather(1, actions)
        
        # Get target Q values
        with torch.no_grad():
            next_q = self.target_model(next_states).max(1)[0]
            target_q = rewards + (1 - dones) * GAMMA * next_q
        
        # Compute loss
        loss = self.criterion(current_q.squeeze(), target_q)
        
        # Optimize the model
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()
        # Update target network
        self.steps += 1
        if self.steps % TARGET_UPDATE_FREQ == 0:
            self.update_target_model()
        
        # Epsilon decay
        if self.epsilon > MIN_EPSILON:
            self.epsilon *= EPSILON_DECAY
            
    def save(self, path):
        torch.save(self.model.state_dict(), path)
    
    def load(self, path):
        self.model.load_state_dict(torch.load(path))

def create_grids(prices, num_grids=GRID_COUNT):
    low = np.percentile(prices, 5)
    high = np.percentile(prices, 95)
    return np.linspace(low, high, num=num_grids+1)[1:-1]

def plot_grid_history(env):
    plt.figure(figsize=(12, 6))
    plt.plot(env.prices, label='Price', alpha=0.5)
    
    # Plot all grid levels over time
    for i, grids in enumerate(env.grid_history):
        if i % 5 == 0:  # Plot every 5th recalibration for clarity
            step = i * env.recalibration_interval
            for grid in grids:
                plt.axhline(y=grid, color='gray', alpha=0.1)
    
    plt.title('Adaptive Grid Levels Over Time')
    plt.legend()
    plt.show()
    
def train_lstm(X_train, y_train, input_size, epochs=20, batch_size=64):
    model = LSTMPredictor(input_size).to(device)
    best_val_loss = model.load(LSTM_PATH, map_location=device)
    print('loaded', best_val_loss)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=LSTM_LEARNING_RATE)
    scheduler = AdaptiveLRScheduler(optimizer, patience=10, factor=0.5)
    # Convert to tensors
    X_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1).to(device)
    
    dataset = TensorDataset(X_tensor, y_tensor)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for X_batch, y_batch in loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss/len(loader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
        scheduler.step(avg_loss)
        if avg_loss < best_val_loss:
            best_val_loss = avg_loss
            model.save(LSTM_PATH, best_val_loss)
            print('saved')
    return model
# Out:
# Using device: cuda

# %%
import time
from binance.client import Client
import pandas as pd
import os
from requests.exceptions import ReadTimeout, RequestException

client = Client()


def get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='60', retries=3, delay=20):
    """Fetch latest Binance OHLCV data with retry mechanism."""
    attempt = 0
    while attempt < retries:
        try:
            klines = client.get_klines(symbol=symbol, interval=interval, limit=int(lookback))
            break  # Break if successful
        except (ReadTimeout, RequestException) as e:
            attempt += 1
            print(f"[Attempt {attempt}/{retries}] Error fetching data: {e}. Retrying in {delay} seconds...")
            time.sleep(delay)
    else:
        print("Failed to fetch Binance data after multiple retries.")
        return pd.DataFrame()  # Return empty DataFrame on failure

    df = pd.DataFrame(klines, columns=[
        'timestamp', 'open', 'high', 'low', 'close', 'volume',
        'close_time', 'quote_asset_volume', 'num_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ])

    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume']].astype({
        'open': float, 'high': float, 'low': float, 'close': float, 'volume': float
    })

    return df

# %%
import joblib
def train_model(csv):
    
    processor = DataProcessor(csv)
    scaled_data, raw_prices = processor.preprocess()
    X, y = processor.create_sequences(scaled_data, raw_prices)
    joblib.dump(processor.scaler, 'min_max_scaler.joblib')
    # Split data
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    # 2. Train LSTM Price Predictor
    print("Training LSTM Price Predictor...")
    lstm_model = train_lstm(X_train, y_train, input_size=X.shape[2], epochs=EPOCHS, batch_size=BATCH_SIZE)

    lstm_model.eval()
    
    # 3. Prepare Trading Environment
    grids = create_grids(raw_prices)
    env = AdaptiveTradingEnvironment(
    scaled_data, 
    raw_prices, 
    lstm_model, 
    initial_grids=grids,
    recalibration_interval=1000,  # Recalculate every 200 steps
    lookback_window=500         # Use last 500 prices for recalculation
    )
    # 4. Initialize DQN Agent
    state_size = env.get_state().shape[0]
    action_size = 3  # hold, buy, sell
    agent = DQNAgent(state_size, action_size)
    agent.epsilon = 0.5

    # 5. Training Loop
    print("\nTraining DQN Agent...")
    portfolio_history = []

    for e in range(EPISODES):
        state = env.reset()
        total_reward = 0
        episode_portfolio = [INITIAL_BALANCE]
        
        while not env.done:
            action = agent.act(state)
            next_state, reward, done, portfolio_value = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            episode_portfolio.append(portfolio_value)
            
            if len(agent.memory) > BATCH_SIZE:
                agent.replay(BATCH_SIZE)
        
        portfolio_history.append(episode_portfolio[-1])
        print(f"Episode {e+1}/{EPISODES}, Reward: {total_reward:.4f}, Portfolio: ${episode_portfolio[-1]:,.2f}, Epsilon: {agent.epsilon:.4f}")
        if (e+1) % 10 == 0:
            agent.save('dqn_agent_fixed_grid.pth')
            print("Models saved successfully")
    # 6. Evaluation
    print("\nEvaluating on test data...")
    test_env = TradingEnvironment(scaled_data[split:], raw_prices[split:], lstm_model, grids)
    state = test_env.reset()
    portfolio_values = []
    trade_log = []

    while not test_env.done:
        action = agent.act(state)
        next_state, reward, done, portfolio_value = test_env.step(action)
        state = next_state
        portfolio_values.append(portfolio_value)
        
        if test_env.trades and test_env.trades[-1][0] in ['buy', 'sell']:
            trade_log.append(test_env.trades[-1])

    # 7. Results
    final_value = test_env.balance + test_env.btc_held * test_env.prices[-1]
    print(f"\n{'='*50}")
    print(f"Initial Balance: ${INITIAL_BALANCE:,.2f}")
    print(f"Final Portfolio Value: ${final_value:,.2f}")
    print(f"Total Return: {((final_value - INITIAL_BALANCE) / INITIAL_BALANCE)*100:.2f}%")
    print(f"Total Trades Executed: {len(test_env.trades)}")
    print(f"Grid Levels: {np.around(grids, 2)}")

    # # Plot results
    # plt.figure(figsize=(15, 10))

    # # Price and grid levels
    # plt.subplot(3, 1, 1)
    # plt.plot(test_env.prices, label='Price')
    # for grid in grids:
    #     plt.axhline(y=grid, color='gray', linestyle='--', alpha=0.3)
    # plt.title('Price with Grid Levels')
    # plt.legend()

    # # Portfolio value
    # plt.subplot(3, 1, 2)
    # plt.plot(portfolio_values)
    # plt.title('Portfolio Value')
    # plt.xlabel('Time Step')
    # plt.ylabel('Value (USD)')

    # # Trade visualization
    # plt.subplot(3, 1, 3)
    # buys = [t[1] for t in trade_log if t[0] == 'buy']
    # sells = [t[1] for t in trade_log if t[0] == 'sell']
    # plt.plot(test_env.prices, label='Price')
    # plt.scatter([i for i, t in enumerate(trade_log) if t[0]=='buy'], buys, 
    #             color='green', marker='^', alpha=0.7, label='Buy')
    # plt.scatter([i for i, t in enumerate(trade_log) if t[0]=='sell'], sells, 
    #             color='red', marker='v', alpha=0.7, label='Sell')
    # plt.title('Trading Signals')
    # plt.legend()

    # plt.tight_layout()
    # plt.savefig('trading_results.png')
    # plt.show()

    # plot_grid_history(env)
    # # Save models
    # torch.save(lstm_model.state_dict(), 'lstm_predictor_fixed_grid.pth')
    # agent.save('dqn_agent_fixed_grid.pth')
    # print("Models saved successfully")

# 1. Data Preparation
def dataCreation():
    df_live = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='1000')
    if df_live.empty:
        raise Exception("No data retrieved; skipping model training.")
    temp_csv = 'live_temp.csv'
    df_live.to_csv(temp_csv, index=False)
    return temp_csv

for i in range(1000):
    try:
        print(f"=== Iteration {i+1} ===")
        temp_csv = dataCreation()
        train_model(temp_csv)
    except Exception as e:
        print(f"Error in loop iteration {i+1}: {e}")
# Out:
# === Iteration 1 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 191.5150, Portfolio: $10,191.52, Epsilon: 0.4998
# Episode 2/100, Reward: 276.5317, Portfolio: $10,276.53, Epsilon: 0.4996
# Episode 3/100, Reward: 241.7375, Portfolio: $10,241.74, Epsilon: 0.4994
# Episode 4/100, Reward: 175.5864, Portfolio: $10,175.59, Epsilon: 0.4991
# Episode 5/100, Reward: 225.4284, Portfolio: $10,225.43, Epsilon: 0.4989
# Episode 6/100, Reward: 175.0459, Portfolio: $10,175.05, Epsilon: 0.4987
# Episode 7/100, Reward: 271.4977, Portfolio: $10,271.50, Epsilon: 0.4985
# Episode 8/100, Reward: 250.6263, Portfolio: $10,250.63, Epsilon: 0.4982
# Episode 9/100, Reward: 262.0239, Portfolio: $10,262.02, Epsilon: 0.4980
# Episode 10/100, Reward: 257.8684, Portfolio: $10,257.87, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 214.9637, Portfolio: $10,214.96, Epsilon: 0.4975
# Episode 12/100, Reward: 147.4363, Portfolio: $10,147.44, Epsilon: 0.4973
# Episode 13/100, Reward: 179.3152, Portfolio: $10,179.32, Epsilon: 0.4971
# Episode 14/100, Reward: 161.9911, Portfolio: $10,161.99, Epsilon: 0.4969
# Episode 15/100, Reward: 252.9669, Portfolio: $10,252.97, Epsilon: 0.4966
# Episode 16/100, Reward: 255.5524, Portfolio: $10,255.55, Epsilon: 0.4964
# Episode 17/100, Reward: 177.4194, Portfolio: $10,177.42, Epsilon: 0.4962
# Episode 18/100, Reward: 163.9282, Portfolio: $10,163.93, Epsilon: 0.4959
# Episode 19/100, Reward: 192.4879, Portfolio: $10,192.49, Epsilon: 0.4957
# Episode 20/100, Reward: 208.4725, Portfolio: $10,208.47, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 173.0234, Portfolio: $10,173.02, Epsilon: 0.4953
# Episode 22/100, Reward: 239.0889, Portfolio: $10,239.09, Epsilon: 0.4950
# Episode 23/100, Reward: 173.2760, Portfolio: $10,173.28, Epsilon: 0.4948
# Episode 24/100, Reward: 170.5404, Portfolio: $10,170.54, Epsilon: 0.4946
# Episode 25/100, Reward: 220.6072, Portfolio: $10,220.61, Epsilon: 0.4944
# Episode 26/100, Reward: 210.3323, Portfolio: $10,210.33, Epsilon: 0.4941
# Episode 27/100, Reward: 253.8646, Portfolio: $10,253.86, Epsilon: 0.4939
# Episode 28/100, Reward: 158.4046, Portfolio: $10,158.40, Epsilon: 0.4937
# Episode 29/100, Reward: 208.4440, Portfolio: $10,208.44, Epsilon: 0.4934
# Episode 30/100, Reward: 188.8011, Portfolio: $10,188.80, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 162.2392, Portfolio: $10,162.24, Epsilon: 0.4930
# Episode 32/100, Reward: 182.3669, Portfolio: $10,182.37, Epsilon: 0.4928
# Episode 33/100, Reward: 233.1853, Portfolio: $10,233.19, Epsilon: 0.4925
# Episode 34/100, Reward: 249.3437, Portfolio: $10,249.34, Epsilon: 0.4923
# Episode 35/100, Reward: 136.4046, Portfolio: $10,136.40, Epsilon: 0.4921
# Episode 36/100, Reward: 196.0982, Portfolio: $10,196.10, Epsilon: 0.4919
# Episode 37/100, Reward: 246.2545, Portfolio: $10,246.25, Epsilon: 0.4916
# Episode 38/100, Reward: 120.5765, Portfolio: $10,120.58, Epsilon: 0.4914
# Episode 39/100, Reward: 230.5705, Portfolio: $10,230.57, Epsilon: 0.4912
# Episode 40/100, Reward: 156.4610, Portfolio: $10,156.46, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 266.5886, Portfolio: $10,266.59, Epsilon: 0.4907
# Episode 42/100, Reward: 274.6169, Portfolio: $10,274.62, Epsilon: 0.4905
# Episode 43/100, Reward: 190.6233, Portfolio: $10,190.62, Epsilon: 0.4903
# Episode 44/100, Reward: 188.1149, Portfolio: $10,188.11, Epsilon: 0.4901
# Episode 45/100, Reward: 184.3155, Portfolio: $10,184.32, Epsilon: 0.4898
# Episode 46/100, Reward: 243.9062, Portfolio: $10,243.91, Epsilon: 0.4896
# Episode 47/100, Reward: 152.8643, Portfolio: $10,152.86, Epsilon: 0.4894
# Episode 48/100, Reward: 174.8536, Portfolio: $10,174.85, Epsilon: 0.4892
# Episode 49/100, Reward: 137.0930, Portfolio: $10,137.09, Epsilon: 0.4889
# Episode 50/100, Reward: 145.3763, Portfolio: $10,145.38, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 170.2169, Portfolio: $10,170.22, Epsilon: 0.4885
# Episode 52/100, Reward: 210.9486, Portfolio: $10,210.95, Epsilon: 0.4883
# Episode 53/100, Reward: 200.5549, Portfolio: $10,200.55, Epsilon: 0.4880
# Episode 54/100, Reward: 181.7911, Portfolio: $10,181.79, Epsilon: 0.4878
# Episode 55/100, Reward: 213.2386, Portfolio: $10,213.24, Epsilon: 0.4876
# Episode 56/100, Reward: 202.8746, Portfolio: $10,202.87, Epsilon: 0.4874
# Episode 57/100, Reward: 160.8636, Portfolio: $10,160.86, Epsilon: 0.4871
# Episode 58/100, Reward: 165.2004, Portfolio: $10,165.20, Epsilon: 0.4869
# Episode 59/100, Reward: 230.1596, Portfolio: $10,230.16, Epsilon: 0.4867
# Episode 60/100, Reward: 194.8090, Portfolio: $10,194.81, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 215.8665, Portfolio: $10,215.87, Epsilon: 0.4862
# Episode 62/100, Reward: 193.8295, Portfolio: $10,193.83, Epsilon: 0.4860
# Episode 63/100, Reward: 251.0370, Portfolio: $10,251.04, Epsilon: 0.4858
# Episode 64/100, Reward: 139.1858, Portfolio: $10,139.19, Epsilon: 0.4856
# Episode 65/100, Reward: 159.3277, Portfolio: $10,159.33, Epsilon: 0.4853
# Episode 66/100, Reward: 198.6464, Portfolio: $10,198.65, Epsilon: 0.4851
# Episode 67/100, Reward: 137.4353, Portfolio: $10,137.44, Epsilon: 0.4849
# Episode 68/100, Reward: 156.6861, Portfolio: $10,156.69, Epsilon: 0.4847
# Episode 69/100, Reward: 202.9096, Portfolio: $10,202.91, Epsilon: 0.4845
# Episode 70/100, Reward: 184.2691, Portfolio: $10,184.27, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 113.7918, Portfolio: $10,113.79, Epsilon: 0.4840
# Episode 72/100, Reward: 272.8047, Portfolio: $10,272.80, Epsilon: 0.4838
# Episode 73/100, Reward: 195.5815, Portfolio: $10,195.58, Epsilon: 0.4836
# Episode 74/100, Reward: 199.5231, Portfolio: $10,199.52, Epsilon: 0.4833
# Episode 75/100, Reward: 235.9986, Portfolio: $10,236.00, Epsilon: 0.4831
# Episode 76/100, Reward: 182.7411, Portfolio: $10,182.74, Epsilon: 0.4829
# Episode 77/100, Reward: 120.3725, Portfolio: $10,120.37, Epsilon: 0.4827
# Episode 78/100, Reward: 157.1333, Portfolio: $10,157.13, Epsilon: 0.4825
# Episode 79/100, Reward: 208.7272, Portfolio: $10,208.73, Epsilon: 0.4822
# Episode 80/100, Reward: 207.9902, Portfolio: $10,207.99, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 226.9632, Portfolio: $10,226.96, Epsilon: 0.4818
# Episode 82/100, Reward: 127.5083, Portfolio: $10,127.51, Epsilon: 0.4816
# Episode 83/100, Reward: 236.6384, Portfolio: $10,236.64, Epsilon: 0.4814
# Episode 84/100, Reward: 198.7251, Portfolio: $10,198.73, Epsilon: 0.4811
# Episode 85/100, Reward: 166.1143, Portfolio: $10,166.11, Epsilon: 0.4809
# Episode 86/100, Reward: 181.5138, Portfolio: $10,181.51, Epsilon: 0.4807
# Episode 87/100, Reward: 179.7101, Portfolio: $10,179.71, Epsilon: 0.4805
# Episode 88/100, Reward: 167.0078, Portfolio: $10,167.01, Epsilon: 0.4802
# Episode 89/100, Reward: 231.5879, Portfolio: $10,231.59, Epsilon: 0.4800
# Episode 90/100, Reward: 342.3661, Portfolio: $10,342.37, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 186.5439, Portfolio: $10,186.54, Epsilon: 0.4796
# Episode 92/100, Reward: 174.7581, Portfolio: $10,174.76, Epsilon: 0.4794
# Episode 93/100, Reward: 224.2868, Portfolio: $10,224.29, Epsilon: 0.4791
# Episode 94/100, Reward: 168.6618, Portfolio: $10,168.66, Epsilon: 0.4789
# Episode 95/100, Reward: 223.3192, Portfolio: $10,223.32, Epsilon: 0.4787
# Episode 96/100, Reward: 131.7495, Portfolio: $10,131.75, Epsilon: 0.4785
# Episode 97/100, Reward: 182.1235, Portfolio: $10,182.12, Epsilon: 0.4783
# Episode 98/100, Reward: 212.4966, Portfolio: $10,212.50, Epsilon: 0.4780
# Episode 99/100, Reward: 175.9506, Portfolio: $10,175.95, Epsilon: 0.4778
# Episode 100/100, Reward: 128.6100, Portfolio: $10,128.61, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,020.50
# Total Return: 0.21%
# Total Trades Executed: 123
# Grid Levels: [103505.25 103610.59 103715.94 103821.28 103926.63 104031.98 104137.32
#  104242.67 104348.02 104453.36 104558.71 104664.05 104769.4  104874.75
#  104980.09 105085.44 105190.78 105296.13 105401.48]
# === Iteration 2 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 222.6621, Portfolio: $10,222.66, Epsilon: 0.4998
# Episode 2/100, Reward: 274.1176, Portfolio: $10,274.12, Epsilon: 0.4996
# Episode 3/100, Reward: 149.4423, Portfolio: $10,149.44, Epsilon: 0.4994
# Episode 4/100, Reward: 238.8446, Portfolio: $10,238.84, Epsilon: 0.4991
# Episode 5/100, Reward: 241.6708, Portfolio: $10,241.67, Epsilon: 0.4989
# Episode 6/100, Reward: 252.7081, Portfolio: $10,252.71, Epsilon: 0.4987
# Episode 7/100, Reward: 242.7121, Portfolio: $10,242.71, Epsilon: 0.4985
# Episode 8/100, Reward: 183.1965, Portfolio: $10,183.20, Epsilon: 0.4982
# Episode 9/100, Reward: 182.3793, Portfolio: $10,182.38, Epsilon: 0.4980
# Episode 10/100, Reward: 164.7250, Portfolio: $10,164.73, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 226.2461, Portfolio: $10,226.25, Epsilon: 0.4975
# Episode 12/100, Reward: 232.8039, Portfolio: $10,232.80, Epsilon: 0.4973
# Episode 13/100, Reward: 228.4582, Portfolio: $10,228.46, Epsilon: 0.4971
# Episode 14/100, Reward: 183.0353, Portfolio: $10,183.04, Epsilon: 0.4969
# Episode 15/100, Reward: 237.6606, Portfolio: $10,237.66, Epsilon: 0.4966
# Episode 16/100, Reward: 245.6525, Portfolio: $10,245.65, Epsilon: 0.4964
# Episode 17/100, Reward: 173.9970, Portfolio: $10,174.00, Epsilon: 0.4962
# Episode 18/100, Reward: 206.0445, Portfolio: $10,206.04, Epsilon: 0.4959
# Episode 19/100, Reward: 151.9002, Portfolio: $10,151.90, Epsilon: 0.4957
# Episode 20/100, Reward: 201.6686, Portfolio: $10,201.67, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 264.2203, Portfolio: $10,264.22, Epsilon: 0.4953
# Episode 22/100, Reward: 175.0558, Portfolio: $10,175.06, Epsilon: 0.4950
# Episode 23/100, Reward: 183.2354, Portfolio: $10,183.24, Epsilon: 0.4948
# Episode 24/100, Reward: 223.6676, Portfolio: $10,223.67, Epsilon: 0.4946
# Episode 25/100, Reward: 177.7848, Portfolio: $10,177.78, Epsilon: 0.4944
# Episode 26/100, Reward: 202.2657, Portfolio: $10,202.27, Epsilon: 0.4941
# Episode 27/100, Reward: 204.1333, Portfolio: $10,204.13, Epsilon: 0.4939
# Episode 28/100, Reward: 209.1784, Portfolio: $10,209.18, Epsilon: 0.4937
# Episode 29/100, Reward: 226.8239, Portfolio: $10,226.82, Epsilon: 0.4934
# Episode 30/100, Reward: 191.2726, Portfolio: $10,191.27, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 206.3998, Portfolio: $10,206.40, Epsilon: 0.4930
# Episode 32/100, Reward: 175.9715, Portfolio: $10,175.97, Epsilon: 0.4928
# Episode 33/100, Reward: 172.5459, Portfolio: $10,172.55, Epsilon: 0.4925
# Episode 34/100, Reward: 187.5160, Portfolio: $10,187.52, Epsilon: 0.4923
# Episode 35/100, Reward: 242.6098, Portfolio: $10,242.61, Epsilon: 0.4921
# Episode 36/100, Reward: 208.9101, Portfolio: $10,208.91, Epsilon: 0.4919
# Episode 37/100, Reward: 186.3144, Portfolio: $10,186.31, Epsilon: 0.4916
# Episode 38/100, Reward: 207.8336, Portfolio: $10,207.83, Epsilon: 0.4914
# Episode 39/100, Reward: 180.1753, Portfolio: $10,180.18, Epsilon: 0.4912
# Episode 40/100, Reward: 227.4492, Portfolio: $10,227.45, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 192.7990, Portfolio: $10,192.80, Epsilon: 0.4907
# Episode 42/100, Reward: 194.4635, Portfolio: $10,194.46, Epsilon: 0.4905
# Episode 43/100, Reward: 206.7815, Portfolio: $10,206.78, Epsilon: 0.4903
# Episode 44/100, Reward: 253.8577, Portfolio: $10,253.86, Epsilon: 0.4901
# Episode 45/100, Reward: 201.0883, Portfolio: $10,201.09, Epsilon: 0.4898
# Episode 46/100, Reward: 228.3816, Portfolio: $10,228.38, Epsilon: 0.4896
# Episode 47/100, Reward: 205.4279, Portfolio: $10,205.43, Epsilon: 0.4894
# Episode 48/100, Reward: 165.5870, Portfolio: $10,165.59, Epsilon: 0.4892
# Episode 49/100, Reward: 180.7095, Portfolio: $10,180.71, Epsilon: 0.4889
# Episode 50/100, Reward: 182.9053, Portfolio: $10,182.91, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 248.7680, Portfolio: $10,248.77, Epsilon: 0.4885
# Episode 52/100, Reward: 163.6047, Portfolio: $10,163.60, Epsilon: 0.4883
# Episode 53/100, Reward: 180.3827, Portfolio: $10,180.38, Epsilon: 0.4880
# Episode 54/100, Reward: 194.2842, Portfolio: $10,194.28, Epsilon: 0.4878
# Episode 55/100, Reward: 215.3145, Portfolio: $10,215.31, Epsilon: 0.4876
# Episode 56/100, Reward: 198.9725, Portfolio: $10,198.97, Epsilon: 0.4874
# Episode 57/100, Reward: 170.2519, Portfolio: $10,170.25, Epsilon: 0.4871
# Episode 58/100, Reward: 274.4057, Portfolio: $10,274.41, Epsilon: 0.4869
# Episode 59/100, Reward: 178.4855, Portfolio: $10,178.49, Epsilon: 0.4867
# Episode 60/100, Reward: 196.7736, Portfolio: $10,196.77, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 260.0124, Portfolio: $10,260.01, Epsilon: 0.4862
# Episode 62/100, Reward: 238.3845, Portfolio: $10,238.38, Epsilon: 0.4860
# Episode 63/100, Reward: 196.4762, Portfolio: $10,196.48, Epsilon: 0.4858
# Episode 64/100, Reward: 227.0061, Portfolio: $10,227.01, Epsilon: 0.4856
# Episode 65/100, Reward: 181.8672, Portfolio: $10,181.87, Epsilon: 0.4853
# Episode 66/100, Reward: 169.9954, Portfolio: $10,170.00, Epsilon: 0.4851
# Episode 67/100, Reward: 208.5237, Portfolio: $10,208.52, Epsilon: 0.4849
# Episode 68/100, Reward: 184.1989, Portfolio: $10,184.20, Epsilon: 0.4847
# Episode 69/100, Reward: 256.9375, Portfolio: $10,256.94, Epsilon: 0.4845
# Episode 70/100, Reward: 159.3926, Portfolio: $10,159.39, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 219.0780, Portfolio: $10,219.08, Epsilon: 0.4840
# Episode 72/100, Reward: 199.0359, Portfolio: $10,199.04, Epsilon: 0.4838
# Episode 73/100, Reward: 196.3176, Portfolio: $10,196.32, Epsilon: 0.4836
# Episode 74/100, Reward: 150.5399, Portfolio: $10,150.54, Epsilon: 0.4833
# Episode 75/100, Reward: 292.2413, Portfolio: $10,292.24, Epsilon: 0.4831
# Episode 76/100, Reward: 258.9064, Portfolio: $10,258.91, Epsilon: 0.4829
# Episode 77/100, Reward: 253.5088, Portfolio: $10,253.51, Epsilon: 0.4827
# Episode 78/100, Reward: 257.2906, Portfolio: $10,257.29, Epsilon: 0.4825
# Episode 79/100, Reward: 195.7042, Portfolio: $10,195.70, Epsilon: 0.4822
# Episode 80/100, Reward: 175.2668, Portfolio: $10,175.27, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 152.9565, Portfolio: $10,152.96, Epsilon: 0.4818
# Episode 82/100, Reward: 162.9864, Portfolio: $10,162.99, Epsilon: 0.4816
# Episode 83/100, Reward: 159.0595, Portfolio: $10,159.06, Epsilon: 0.4814
# Episode 84/100, Reward: 187.4746, Portfolio: $10,187.47, Epsilon: 0.4811
# Episode 85/100, Reward: 257.9128, Portfolio: $10,257.91, Epsilon: 0.4809
# Episode 86/100, Reward: 205.0222, Portfolio: $10,205.02, Epsilon: 0.4807
# Episode 87/100, Reward: 215.4959, Portfolio: $10,215.50, Epsilon: 0.4805
# Episode 88/100, Reward: 203.3659, Portfolio: $10,203.37, Epsilon: 0.4802
# Episode 89/100, Reward: 168.9035, Portfolio: $10,168.90, Epsilon: 0.4800
# Episode 90/100, Reward: 190.0129, Portfolio: $10,190.01, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 267.0743, Portfolio: $10,267.07, Epsilon: 0.4796
# Episode 92/100, Reward: 231.0656, Portfolio: $10,231.07, Epsilon: 0.4794
# Episode 93/100, Reward: 174.2068, Portfolio: $10,174.21, Epsilon: 0.4791
# Episode 94/100, Reward: 163.9620, Portfolio: $10,163.96, Epsilon: 0.4789
# Episode 95/100, Reward: 164.1752, Portfolio: $10,164.18, Epsilon: 0.4787
# Episode 96/100, Reward: 238.0820, Portfolio: $10,238.08, Epsilon: 0.4785
# Episode 97/100, Reward: 226.4691, Portfolio: $10,226.47, Epsilon: 0.4783
# Episode 98/100, Reward: 215.4286, Portfolio: $10,215.43, Epsilon: 0.4780
# Episode 99/100, Reward: 141.6021, Portfolio: $10,141.60, Epsilon: 0.4778
# Episode 100/100, Reward: 181.4538, Portfolio: $10,181.45, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,027.34
# Total Return: 0.27%
# Total Trades Executed: 85
# Grid Levels: [103510.18 103620.46 103730.75 103841.03 103951.31 104061.59 104171.87
#  104282.15 104392.44 104502.72 104613.   104723.28 104833.56 104943.84
#  105054.13 105164.41 105274.69 105384.97 105495.25]
# === Iteration 3 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 215.2711, Portfolio: $10,215.27, Epsilon: 0.4998
# Episode 2/100, Reward: 211.1272, Portfolio: $10,211.13, Epsilon: 0.4996
# Episode 3/100, Reward: 236.5457, Portfolio: $10,236.55, Epsilon: 0.4994
# Episode 4/100, Reward: 167.8509, Portfolio: $10,167.85, Epsilon: 0.4991
# Episode 5/100, Reward: 223.0036, Portfolio: $10,223.00, Epsilon: 0.4989
# Episode 6/100, Reward: 216.8241, Portfolio: $10,216.82, Epsilon: 0.4987
# Episode 7/100, Reward: 154.6289, Portfolio: $10,154.63, Epsilon: 0.4985
# Episode 8/100, Reward: 192.3876, Portfolio: $10,192.39, Epsilon: 0.4982
# Episode 9/100, Reward: 168.9878, Portfolio: $10,168.99, Epsilon: 0.4980
# Episode 10/100, Reward: 164.4408, Portfolio: $10,164.44, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 141.5166, Portfolio: $10,141.52, Epsilon: 0.4975
# Episode 12/100, Reward: 175.2721, Portfolio: $10,175.27, Epsilon: 0.4973
# Episode 13/100, Reward: 232.6119, Portfolio: $10,232.61, Epsilon: 0.4971
# Episode 14/100, Reward: 211.8780, Portfolio: $10,211.88, Epsilon: 0.4969
# Episode 15/100, Reward: 184.6808, Portfolio: $10,184.68, Epsilon: 0.4966
# Episode 16/100, Reward: 149.6883, Portfolio: $10,149.69, Epsilon: 0.4964
# Episode 17/100, Reward: 208.4668, Portfolio: $10,208.47, Epsilon: 0.4962
# Episode 18/100, Reward: 69.7780, Portfolio: $10,069.78, Epsilon: 0.4959
# Episode 19/100, Reward: 169.9643, Portfolio: $10,169.96, Epsilon: 0.4957
# Episode 20/100, Reward: 82.4489, Portfolio: $10,082.45, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 160.9486, Portfolio: $10,160.95, Epsilon: 0.4953
# Episode 22/100, Reward: 91.5243, Portfolio: $10,091.52, Epsilon: 0.4950
# Episode 23/100, Reward: 145.7705, Portfolio: $10,145.77, Epsilon: 0.4948
# Episode 24/100, Reward: 229.3222, Portfolio: $10,229.32, Epsilon: 0.4946
# Episode 25/100, Reward: 171.2381, Portfolio: $10,171.24, Epsilon: 0.4944
# Episode 26/100, Reward: 180.9438, Portfolio: $10,180.94, Epsilon: 0.4941
# Episode 27/100, Reward: 156.7946, Portfolio: $10,156.79, Epsilon: 0.4939
# Episode 28/100, Reward: 188.1503, Portfolio: $10,188.15, Epsilon: 0.4937
# Episode 29/100, Reward: 176.5126, Portfolio: $10,176.51, Epsilon: 0.4934
# Episode 30/100, Reward: 167.2912, Portfolio: $10,167.29, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 197.6352, Portfolio: $10,197.64, Epsilon: 0.4930
# Episode 32/100, Reward: 204.3157, Portfolio: $10,204.32, Epsilon: 0.4928
# Episode 33/100, Reward: 203.8054, Portfolio: $10,203.81, Epsilon: 0.4925
# Episode 34/100, Reward: 133.4460, Portfolio: $10,133.45, Epsilon: 0.4923
# Episode 35/100, Reward: 124.8155, Portfolio: $10,124.82, Epsilon: 0.4921
# Episode 36/100, Reward: 251.1825, Portfolio: $10,251.18, Epsilon: 0.4919
# Episode 37/100, Reward: 197.3374, Portfolio: $10,197.34, Epsilon: 0.4916
# Episode 38/100, Reward: 182.6654, Portfolio: $10,182.67, Epsilon: 0.4914
# Episode 39/100, Reward: 238.1900, Portfolio: $10,238.19, Epsilon: 0.4912
# Episode 40/100, Reward: 118.9545, Portfolio: $10,118.95, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 121.1473, Portfolio: $10,121.15, Epsilon: 0.4907
# Episode 42/100, Reward: 178.4896, Portfolio: $10,178.49, Epsilon: 0.4905
# Episode 43/100, Reward: 146.8864, Portfolio: $10,146.89, Epsilon: 0.4903
# Episode 44/100, Reward: 164.5386, Portfolio: $10,164.54, Epsilon: 0.4901
# Episode 45/100, Reward: 144.3458, Portfolio: $10,144.35, Epsilon: 0.4898
# Episode 46/100, Reward: 244.9979, Portfolio: $10,245.00, Epsilon: 0.4896
# Episode 47/100, Reward: 193.6726, Portfolio: $10,193.67, Epsilon: 0.4894
# Episode 48/100, Reward: 168.0270, Portfolio: $10,168.03, Epsilon: 0.4892
# Episode 49/100, Reward: 181.5973, Portfolio: $10,181.60, Epsilon: 0.4889
# Episode 50/100, Reward: 83.5264, Portfolio: $10,083.53, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 252.0792, Portfolio: $10,252.08, Epsilon: 0.4885
# Episode 52/100, Reward: 232.0465, Portfolio: $10,232.05, Epsilon: 0.4883
# Episode 53/100, Reward: 139.4586, Portfolio: $10,139.46, Epsilon: 0.4880
# Episode 54/100, Reward: 190.6765, Portfolio: $10,190.68, Epsilon: 0.4878
# Episode 55/100, Reward: 142.5887, Portfolio: $10,142.59, Epsilon: 0.4876
# Episode 56/100, Reward: 142.6447, Portfolio: $10,142.64, Epsilon: 0.4874
# Episode 57/100, Reward: 193.3826, Portfolio: $10,193.38, Epsilon: 0.4871
# Episode 58/100, Reward: 166.7391, Portfolio: $10,166.74, Epsilon: 0.4869
# Episode 59/100, Reward: 196.7961, Portfolio: $10,196.80, Epsilon: 0.4867
# Episode 60/100, Reward: 234.5472, Portfolio: $10,234.55, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 191.3360, Portfolio: $10,191.34, Epsilon: 0.4862
# Episode 62/100, Reward: 172.8474, Portfolio: $10,172.85, Epsilon: 0.4860
# Episode 63/100, Reward: 179.9728, Portfolio: $10,179.97, Epsilon: 0.4858
# Episode 64/100, Reward: 125.3017, Portfolio: $10,125.30, Epsilon: 0.4856
# Episode 65/100, Reward: 181.8353, Portfolio: $10,181.84, Epsilon: 0.4853
# Episode 66/100, Reward: 171.4436, Portfolio: $10,171.44, Epsilon: 0.4851
# Episode 67/100, Reward: 143.1371, Portfolio: $10,143.14, Epsilon: 0.4849
# Episode 68/100, Reward: 151.1070, Portfolio: $10,151.11, Epsilon: 0.4847
# Episode 69/100, Reward: 176.4638, Portfolio: $10,176.46, Epsilon: 0.4845
# Episode 70/100, Reward: 198.8697, Portfolio: $10,198.87, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 149.7774, Portfolio: $10,149.78, Epsilon: 0.4840
# Episode 72/100, Reward: 164.4641, Portfolio: $10,164.46, Epsilon: 0.4838
# Episode 73/100, Reward: 130.3360, Portfolio: $10,130.34, Epsilon: 0.4836
# Episode 74/100, Reward: 180.8959, Portfolio: $10,180.90, Epsilon: 0.4833
# Episode 75/100, Reward: 166.5824, Portfolio: $10,166.58, Epsilon: 0.4831
# Episode 76/100, Reward: 108.6615, Portfolio: $10,108.66, Epsilon: 0.4829
# Episode 77/100, Reward: 141.4483, Portfolio: $10,141.45, Epsilon: 0.4827
# Episode 78/100, Reward: 171.6388, Portfolio: $10,171.64, Epsilon: 0.4825
# Episode 79/100, Reward: 156.9919, Portfolio: $10,156.99, Epsilon: 0.4822
# Episode 80/100, Reward: 221.5695, Portfolio: $10,221.57, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 171.4372, Portfolio: $10,171.44, Epsilon: 0.4818
# Episode 82/100, Reward: 162.5429, Portfolio: $10,162.54, Epsilon: 0.4816
# Episode 83/100, Reward: 192.2048, Portfolio: $10,192.20, Epsilon: 0.4814
# Episode 84/100, Reward: 195.4351, Portfolio: $10,195.44, Epsilon: 0.4811
# Episode 85/100, Reward: 93.3551, Portfolio: $10,093.36, Epsilon: 0.4809
# Episode 86/100, Reward: 221.8067, Portfolio: $10,221.81, Epsilon: 0.4807
# Episode 87/100, Reward: 201.0618, Portfolio: $10,201.06, Epsilon: 0.4805
# Episode 88/100, Reward: 175.6752, Portfolio: $10,175.68, Epsilon: 0.4802
# Episode 89/100, Reward: 177.0945, Portfolio: $10,177.09, Epsilon: 0.4800
# Episode 90/100, Reward: 157.2580, Portfolio: $10,157.26, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 167.4623, Portfolio: $10,167.46, Epsilon: 0.4796
# Episode 92/100, Reward: 156.4567, Portfolio: $10,156.46, Epsilon: 0.4794
# Episode 93/100, Reward: 157.6214, Portfolio: $10,157.62, Epsilon: 0.4791
# Episode 94/100, Reward: 212.7988, Portfolio: $10,212.80, Epsilon: 0.4789
# Episode 95/100, Reward: 252.8214, Portfolio: $10,252.82, Epsilon: 0.4787
# Episode 96/100, Reward: 173.4181, Portfolio: $10,173.42, Epsilon: 0.4785
# Episode 97/100, Reward: 205.0654, Portfolio: $10,205.07, Epsilon: 0.4783
# Episode 98/100, Reward: 206.1088, Portfolio: $10,206.11, Epsilon: 0.4780
# Episode 99/100, Reward: 189.9978, Portfolio: $10,190.00, Epsilon: 0.4778
# Episode 100/100, Reward: 199.5008, Portfolio: $10,199.50, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,030.60
# Total Return: 0.31%
# Total Trades Executed: 88
# Grid Levels: [103559.65 103668.1  103776.54 103884.99 103993.43 104101.88 104210.32
#  104318.76 104427.21 104535.65 104644.1  104752.54 104860.98 104969.43
#  105077.87 105186.32 105294.76 105403.21 105511.65]
# === Iteration 4 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 159.6680, Portfolio: $10,159.67, Epsilon: 0.4998
# Episode 2/100, Reward: 167.9565, Portfolio: $10,167.96, Epsilon: 0.4996
# Episode 3/100, Reward: 129.4372, Portfolio: $10,129.44, Epsilon: 0.4994
# Episode 4/100, Reward: 146.3915, Portfolio: $10,146.39, Epsilon: 0.4991
# Episode 5/100, Reward: 165.2481, Portfolio: $10,165.25, Epsilon: 0.4989
# Episode 6/100, Reward: 84.4678, Portfolio: $10,084.47, Epsilon: 0.4987
# Episode 7/100, Reward: 163.3544, Portfolio: $10,163.35, Epsilon: 0.4985
# Episode 8/100, Reward: 78.7066, Portfolio: $10,078.71, Epsilon: 0.4982
# Episode 9/100, Reward: 140.9762, Portfolio: $10,140.98, Epsilon: 0.4980
# Episode 10/100, Reward: 109.3330, Portfolio: $10,109.33, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 165.0894, Portfolio: $10,165.09, Epsilon: 0.4975
# Episode 12/100, Reward: 113.4932, Portfolio: $10,113.49, Epsilon: 0.4973
# Episode 13/100, Reward: 205.2098, Portfolio: $10,205.21, Epsilon: 0.4971
# Episode 14/100, Reward: 143.9205, Portfolio: $10,143.92, Epsilon: 0.4969
# Episode 15/100, Reward: 143.1447, Portfolio: $10,143.14, Epsilon: 0.4966
# Episode 16/100, Reward: 168.7999, Portfolio: $10,168.80, Epsilon: 0.4964
# Episode 17/100, Reward: 140.2328, Portfolio: $10,140.23, Epsilon: 0.4962
# Episode 18/100, Reward: 169.8222, Portfolio: $10,169.82, Epsilon: 0.4959
# Episode 19/100, Reward: 126.1610, Portfolio: $10,126.16, Epsilon: 0.4957
# Episode 20/100, Reward: 129.3033, Portfolio: $10,129.30, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 183.3591, Portfolio: $10,183.36, Epsilon: 0.4953
# Episode 22/100, Reward: 107.9439, Portfolio: $10,107.94, Epsilon: 0.4950
# Episode 23/100, Reward: 182.2242, Portfolio: $10,182.22, Epsilon: 0.4948
# Episode 24/100, Reward: 125.2844, Portfolio: $10,125.28, Epsilon: 0.4946
# Episode 25/100, Reward: 96.8534, Portfolio: $10,096.85, Epsilon: 0.4944
# Episode 26/100, Reward: 207.1430, Portfolio: $10,207.14, Epsilon: 0.4941
# Episode 27/100, Reward: 167.9927, Portfolio: $10,167.99, Epsilon: 0.4939
# Episode 28/100, Reward: 104.9589, Portfolio: $10,104.96, Epsilon: 0.4937
# Episode 29/100, Reward: 110.5961, Portfolio: $10,110.60, Epsilon: 0.4934
# Episode 30/100, Reward: 91.2515, Portfolio: $10,091.25, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 136.3413, Portfolio: $10,136.34, Epsilon: 0.4930
# Episode 32/100, Reward: 163.6260, Portfolio: $10,163.63, Epsilon: 0.4928
# Episode 33/100, Reward: 183.1393, Portfolio: $10,183.14, Epsilon: 0.4925
# Episode 34/100, Reward: 205.4578, Portfolio: $10,205.46, Epsilon: 0.4923
# Episode 35/100, Reward: 143.6092, Portfolio: $10,143.61, Epsilon: 0.4921
# Episode 36/100, Reward: 123.3716, Portfolio: $10,123.37, Epsilon: 0.4919
# Episode 37/100, Reward: 222.7384, Portfolio: $10,222.74, Epsilon: 0.4916
# Episode 38/100, Reward: 144.2189, Portfolio: $10,144.22, Epsilon: 0.4914
# Episode 39/100, Reward: 182.7695, Portfolio: $10,182.77, Epsilon: 0.4912
# Episode 40/100, Reward: 171.9293, Portfolio: $10,171.93, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 126.3461, Portfolio: $10,126.35, Epsilon: 0.4907
# Episode 42/100, Reward: 177.5466, Portfolio: $10,177.55, Epsilon: 0.4905
# Episode 43/100, Reward: 160.9383, Portfolio: $10,160.94, Epsilon: 0.4903
# Episode 44/100, Reward: 150.6391, Portfolio: $10,150.64, Epsilon: 0.4901
# Episode 45/100, Reward: 95.8594, Portfolio: $10,095.86, Epsilon: 0.4898
# Episode 46/100, Reward: 183.9513, Portfolio: $10,183.95, Epsilon: 0.4896
# Episode 47/100, Reward: 159.4935, Portfolio: $10,159.49, Epsilon: 0.4894
# Episode 48/100, Reward: 166.5681, Portfolio: $10,166.57, Epsilon: 0.4892
# Episode 49/100, Reward: 157.1112, Portfolio: $10,157.11, Epsilon: 0.4889
# Episode 50/100, Reward: 166.4245, Portfolio: $10,166.42, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 119.4343, Portfolio: $10,119.43, Epsilon: 0.4885
# Episode 52/100, Reward: 82.9349, Portfolio: $10,082.93, Epsilon: 0.4883
# Episode 53/100, Reward: 216.2472, Portfolio: $10,216.25, Epsilon: 0.4880
# Episode 54/100, Reward: 95.1750, Portfolio: $10,095.17, Epsilon: 0.4878
# Episode 55/100, Reward: 245.2061, Portfolio: $10,245.21, Epsilon: 0.4876
# Episode 56/100, Reward: 215.1294, Portfolio: $10,215.13, Epsilon: 0.4874
# Episode 57/100, Reward: 236.5711, Portfolio: $10,236.57, Epsilon: 0.4871
# Episode 58/100, Reward: 129.5468, Portfolio: $10,129.55, Epsilon: 0.4869
# Episode 59/100, Reward: 170.5066, Portfolio: $10,170.51, Epsilon: 0.4867
# Episode 60/100, Reward: 81.7546, Portfolio: $10,081.75, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 89.1596, Portfolio: $10,089.16, Epsilon: 0.4862
# Episode 62/100, Reward: 169.7135, Portfolio: $10,169.71, Epsilon: 0.4860
# Episode 63/100, Reward: 191.1782, Portfolio: $10,191.18, Epsilon: 0.4858
# Episode 64/100, Reward: 161.4487, Portfolio: $10,161.45, Epsilon: 0.4856
# Episode 65/100, Reward: 45.6085, Portfolio: $10,045.61, Epsilon: 0.4853
# Episode 66/100, Reward: 176.3044, Portfolio: $10,176.30, Epsilon: 0.4851
# Episode 67/100, Reward: 135.7446, Portfolio: $10,135.74, Epsilon: 0.4849
# Episode 68/100, Reward: 224.8818, Portfolio: $10,224.88, Epsilon: 0.4847
# Episode 69/100, Reward: 172.3091, Portfolio: $10,172.31, Epsilon: 0.4845
# Episode 70/100, Reward: 114.3424, Portfolio: $10,114.34, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 138.1179, Portfolio: $10,138.12, Epsilon: 0.4840
# Episode 72/100, Reward: 198.0917, Portfolio: $10,198.09, Epsilon: 0.4838
# Episode 73/100, Reward: 190.9676, Portfolio: $10,190.97, Epsilon: 0.4836
# Episode 74/100, Reward: 175.8734, Portfolio: $10,175.87, Epsilon: 0.4833
# Episode 75/100, Reward: 124.1365, Portfolio: $10,124.14, Epsilon: 0.4831
# Episode 76/100, Reward: 200.3714, Portfolio: $10,200.37, Epsilon: 0.4829
# Episode 77/100, Reward: 85.9519, Portfolio: $10,085.95, Epsilon: 0.4827
# Episode 78/100, Reward: 87.9085, Portfolio: $10,087.91, Epsilon: 0.4825
# Episode 79/100, Reward: 116.9500, Portfolio: $10,116.95, Epsilon: 0.4822
# Episode 80/100, Reward: 124.8210, Portfolio: $10,124.82, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 86.7745, Portfolio: $10,086.77, Epsilon: 0.4818
# Episode 82/100, Reward: 97.3564, Portfolio: $10,097.36, Epsilon: 0.4816
# Episode 83/100, Reward: 88.3645, Portfolio: $10,088.36, Epsilon: 0.4814
# Episode 84/100, Reward: 131.2293, Portfolio: $10,131.23, Epsilon: 0.4811
# Episode 85/100, Reward: 149.9503, Portfolio: $10,149.95, Epsilon: 0.4809
# Episode 86/100, Reward: 171.3417, Portfolio: $10,171.34, Epsilon: 0.4807
# Episode 87/100, Reward: 194.5796, Portfolio: $10,194.58, Epsilon: 0.4805
# Episode 88/100, Reward: 208.0964, Portfolio: $10,208.10, Epsilon: 0.4802
# Episode 89/100, Reward: 168.4787, Portfolio: $10,168.48, Epsilon: 0.4800
# Episode 90/100, Reward: 84.3124, Portfolio: $10,084.31, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 166.5071, Portfolio: $10,166.51, Epsilon: 0.4796
# Episode 92/100, Reward: 85.3476, Portfolio: $10,085.35, Epsilon: 0.4794
# Episode 93/100, Reward: 129.6455, Portfolio: $10,129.65, Epsilon: 0.4791
# Episode 94/100, Reward: 156.8730, Portfolio: $10,156.87, Epsilon: 0.4789
# Episode 95/100, Reward: 135.3821, Portfolio: $10,135.38, Epsilon: 0.4787
# Episode 96/100, Reward: 150.0443, Portfolio: $10,150.04, Epsilon: 0.4785
# Episode 97/100, Reward: 168.7019, Portfolio: $10,168.70, Epsilon: 0.4783
# Episode 98/100, Reward: 165.0147, Portfolio: $10,165.01, Epsilon: 0.4780
# Episode 99/100, Reward: 179.0172, Portfolio: $10,179.02, Epsilon: 0.4778
# Episode 100/100, Reward: 147.2897, Portfolio: $10,147.29, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,066.16
# Total Return: 0.66%
# Total Trades Executed: 148
# Grid Levels: [103673.04 103775.51 103877.99 103980.47 104082.94 104185.42 104287.9
#  104390.37 104492.85 104595.33 104697.8  104800.28 104902.76 105005.23
#  105107.71 105210.19 105312.66 105415.14 105517.62]
# === Iteration 5 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 165.9540, Portfolio: $10,165.95, Epsilon: 0.4998
# Episode 2/100, Reward: 195.1688, Portfolio: $10,195.17, Epsilon: 0.4996
# Episode 3/100, Reward: 153.9385, Portfolio: $10,153.94, Epsilon: 0.4994
# Episode 4/100, Reward: 205.0987, Portfolio: $10,205.10, Epsilon: 0.4991
# Episode 5/100, Reward: 164.5977, Portfolio: $10,164.60, Epsilon: 0.4989
# Episode 6/100, Reward: 183.0631, Portfolio: $10,183.06, Epsilon: 0.4987
# Episode 7/100, Reward: 120.8848, Portfolio: $10,120.88, Epsilon: 0.4985
# Episode 8/100, Reward: 151.5467, Portfolio: $10,151.55, Epsilon: 0.4982
# Episode 9/100, Reward: 164.7729, Portfolio: $10,164.77, Epsilon: 0.4980
# Episode 10/100, Reward: 135.4585, Portfolio: $10,135.46, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 142.2051, Portfolio: $10,142.21, Epsilon: 0.4975
# Episode 12/100, Reward: 226.2223, Portfolio: $10,226.22, Epsilon: 0.4973
# Episode 13/100, Reward: 141.0878, Portfolio: $10,141.09, Epsilon: 0.4971
# Episode 14/100, Reward: 150.6076, Portfolio: $10,150.61, Epsilon: 0.4969
# Episode 15/100, Reward: 166.6955, Portfolio: $10,166.70, Epsilon: 0.4966
# Episode 16/100, Reward: 193.2087, Portfolio: $10,193.21, Epsilon: 0.4964
# Episode 17/100, Reward: 161.2558, Portfolio: $10,161.26, Epsilon: 0.4962
# Episode 18/100, Reward: 174.5204, Portfolio: $10,174.52, Epsilon: 0.4959
# Episode 19/100, Reward: 127.9728, Portfolio: $10,127.97, Epsilon: 0.4957
# Episode 20/100, Reward: 209.6145, Portfolio: $10,209.61, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 194.5991, Portfolio: $10,194.60, Epsilon: 0.4953
# Episode 22/100, Reward: 150.3971, Portfolio: $10,150.40, Epsilon: 0.4950
# Episode 23/100, Reward: 178.2603, Portfolio: $10,178.26, Epsilon: 0.4948
# Episode 24/100, Reward: 175.8115, Portfolio: $10,175.81, Epsilon: 0.4946
# Episode 25/100, Reward: 108.8804, Portfolio: $10,108.88, Epsilon: 0.4944
# Episode 26/100, Reward: 101.8456, Portfolio: $10,101.85, Epsilon: 0.4941
# Episode 27/100, Reward: 229.0678, Portfolio: $10,229.07, Epsilon: 0.4939
# Episode 28/100, Reward: 143.4172, Portfolio: $10,143.42, Epsilon: 0.4937
# Episode 29/100, Reward: 140.2085, Portfolio: $10,140.21, Epsilon: 0.4934
# Episode 30/100, Reward: 94.2270, Portfolio: $10,094.23, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 130.6333, Portfolio: $10,130.63, Epsilon: 0.4930
# Episode 32/100, Reward: 169.5906, Portfolio: $10,169.59, Epsilon: 0.4928
# Episode 33/100, Reward: 156.1219, Portfolio: $10,156.12, Epsilon: 0.4925
# Episode 34/100, Reward: 75.6292, Portfolio: $10,075.63, Epsilon: 0.4923
# Episode 35/100, Reward: 134.6497, Portfolio: $10,134.65, Epsilon: 0.4921
# Episode 36/100, Reward: 173.5450, Portfolio: $10,173.55, Epsilon: 0.4919
# Episode 37/100, Reward: 224.4669, Portfolio: $10,224.47, Epsilon: 0.4916
# Episode 38/100, Reward: 161.7769, Portfolio: $10,161.78, Epsilon: 0.4914
# Episode 39/100, Reward: 178.4545, Portfolio: $10,178.45, Epsilon: 0.4912
# Episode 40/100, Reward: 203.6915, Portfolio: $10,203.69, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 208.8913, Portfolio: $10,208.89, Epsilon: 0.4907
# Episode 42/100, Reward: 136.4093, Portfolio: $10,136.41, Epsilon: 0.4905
# Episode 43/100, Reward: 171.7874, Portfolio: $10,171.79, Epsilon: 0.4903
# Episode 44/100, Reward: 123.7436, Portfolio: $10,123.74, Epsilon: 0.4901
# Episode 45/100, Reward: 127.7934, Portfolio: $10,127.79, Epsilon: 0.4898
# Episode 46/100, Reward: 180.1749, Portfolio: $10,180.17, Epsilon: 0.4896
# Episode 47/100, Reward: 178.1417, Portfolio: $10,178.14, Epsilon: 0.4894
# Episode 48/100, Reward: 177.0569, Portfolio: $10,177.06, Epsilon: 0.4892
# Episode 49/100, Reward: 163.2119, Portfolio: $10,163.21, Epsilon: 0.4889
# Episode 50/100, Reward: 150.9716, Portfolio: $10,150.97, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 143.2248, Portfolio: $10,143.22, Epsilon: 0.4885
# Episode 52/100, Reward: 284.8017, Portfolio: $10,284.80, Epsilon: 0.4883
# Episode 53/100, Reward: 92.4692, Portfolio: $10,092.47, Epsilon: 0.4880
# Episode 54/100, Reward: 224.4376, Portfolio: $10,224.44, Epsilon: 0.4878
# Episode 55/100, Reward: 137.9077, Portfolio: $10,137.91, Epsilon: 0.4876
# Episode 56/100, Reward: 259.4592, Portfolio: $10,259.46, Epsilon: 0.4874
# Episode 57/100, Reward: 220.6601, Portfolio: $10,220.66, Epsilon: 0.4871
# Episode 58/100, Reward: 235.5960, Portfolio: $10,235.60, Epsilon: 0.4869
# Episode 59/100, Reward: 178.5368, Portfolio: $10,178.54, Epsilon: 0.4867
# Episode 60/100, Reward: 71.7908, Portfolio: $10,071.79, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 215.7903, Portfolio: $10,215.79, Epsilon: 0.4862
# Episode 62/100, Reward: 128.8459, Portfolio: $10,128.85, Epsilon: 0.4860
# Episode 63/100, Reward: 194.1228, Portfolio: $10,194.12, Epsilon: 0.4858
# Episode 64/100, Reward: 134.0582, Portfolio: $10,134.06, Epsilon: 0.4856
# Episode 65/100, Reward: 86.7952, Portfolio: $10,086.80, Epsilon: 0.4853
# Episode 66/100, Reward: 159.1451, Portfolio: $10,159.15, Epsilon: 0.4851
# Episode 67/100, Reward: 222.6805, Portfolio: $10,222.68, Epsilon: 0.4849
# Episode 68/100, Reward: 158.9447, Portfolio: $10,158.94, Epsilon: 0.4847
# Episode 69/100, Reward: 170.9454, Portfolio: $10,170.95, Epsilon: 0.4845
# Episode 70/100, Reward: 171.7009, Portfolio: $10,171.70, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 235.8800, Portfolio: $10,235.88, Epsilon: 0.4840
# Episode 72/100, Reward: 175.0290, Portfolio: $10,175.03, Epsilon: 0.4838
# Episode 73/100, Reward: 210.7834, Portfolio: $10,210.78, Epsilon: 0.4836
# Episode 74/100, Reward: 241.8353, Portfolio: $10,241.84, Epsilon: 0.4833
# Episode 75/100, Reward: 174.0023, Portfolio: $10,174.00, Epsilon: 0.4831
# Episode 76/100, Reward: 160.2922, Portfolio: $10,160.29, Epsilon: 0.4829
# Episode 77/100, Reward: 174.8316, Portfolio: $10,174.83, Epsilon: 0.4827
# Episode 78/100, Reward: 156.2196, Portfolio: $10,156.22, Epsilon: 0.4825
# Episode 79/100, Reward: 123.7325, Portfolio: $10,123.73, Epsilon: 0.4822
# Episode 80/100, Reward: 187.8852, Portfolio: $10,187.89, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 196.4843, Portfolio: $10,196.48, Epsilon: 0.4818
# Episode 82/100, Reward: 142.2014, Portfolio: $10,142.20, Epsilon: 0.4816
# Episode 83/100, Reward: 165.4198, Portfolio: $10,165.42, Epsilon: 0.4814
# Episode 84/100, Reward: 100.6244, Portfolio: $10,100.62, Epsilon: 0.4811
# Episode 85/100, Reward: 185.9333, Portfolio: $10,185.93, Epsilon: 0.4809
# Episode 86/100, Reward: 190.2766, Portfolio: $10,190.28, Epsilon: 0.4807
# Episode 87/100, Reward: 180.9367, Portfolio: $10,180.94, Epsilon: 0.4805
# Episode 88/100, Reward: 152.7587, Portfolio: $10,152.76, Epsilon: 0.4802
# Episode 89/100, Reward: 170.4267, Portfolio: $10,170.43, Epsilon: 0.4800
# Episode 90/100, Reward: 83.0668, Portfolio: $10,083.07, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 157.9809, Portfolio: $10,157.98, Epsilon: 0.4796
# Episode 92/100, Reward: 149.2472, Portfolio: $10,149.25, Epsilon: 0.4794
# Episode 93/100, Reward: 157.1332, Portfolio: $10,157.13, Epsilon: 0.4791
# Episode 94/100, Reward: 177.9183, Portfolio: $10,177.92, Epsilon: 0.4789
# Episode 95/100, Reward: 156.3484, Portfolio: $10,156.35, Epsilon: 0.4787
# Episode 96/100, Reward: 116.9267, Portfolio: $10,116.93, Epsilon: 0.4785
# Episode 97/100, Reward: 117.3069, Portfolio: $10,117.31, Epsilon: 0.4783
# Episode 98/100, Reward: 135.8884, Portfolio: $10,135.89, Epsilon: 0.4780
# Episode 99/100, Reward: 144.7911, Portfolio: $10,144.79, Epsilon: 0.4778
# Episode 100/100, Reward: 159.7395, Portfolio: $10,159.74, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,027.62
# Total Return: 0.28%
# Total Trades Executed: 149
# Grid Levels: [103796.83 103892.79 103988.75 104084.71 104180.67 104276.63 104372.6
#  104468.56 104564.52 104660.48 104756.44 104852.4  104948.36 105044.33
#  105140.29 105236.25 105332.21 105428.17 105524.13]
# === Iteration 6 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 143.6084, Portfolio: $10,143.61, Epsilon: 0.4998
# Episode 2/100, Reward: 134.8252, Portfolio: $10,134.83, Epsilon: 0.4996
# Episode 3/100, Reward: 210.0703, Portfolio: $10,210.07, Epsilon: 0.4994
# Episode 4/100, Reward: 67.4758, Portfolio: $10,067.48, Epsilon: 0.4991
# Episode 5/100, Reward: 192.4166, Portfolio: $10,192.42, Epsilon: 0.4989
# Episode 6/100, Reward: 185.6031, Portfolio: $10,185.60, Epsilon: 0.4987
# Episode 7/100, Reward: 165.1179, Portfolio: $10,165.12, Epsilon: 0.4985
# Episode 8/100, Reward: 172.8560, Portfolio: $10,172.86, Epsilon: 0.4982
# Episode 9/100, Reward: 154.3418, Portfolio: $10,154.34, Epsilon: 0.4980
# Episode 10/100, Reward: 172.4711, Portfolio: $10,172.47, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 251.5637, Portfolio: $10,251.56, Epsilon: 0.4975
# Episode 12/100, Reward: 215.6442, Portfolio: $10,215.64, Epsilon: 0.4973
# Episode 13/100, Reward: 143.6076, Portfolio: $10,143.61, Epsilon: 0.4971
# Episode 14/100, Reward: 117.2180, Portfolio: $10,117.22, Epsilon: 0.4969
# Episode 15/100, Reward: 203.1886, Portfolio: $10,203.19, Epsilon: 0.4966
# Episode 16/100, Reward: 158.9776, Portfolio: $10,158.98, Epsilon: 0.4964
# Episode 17/100, Reward: 180.4743, Portfolio: $10,180.47, Epsilon: 0.4962
# Episode 18/100, Reward: 139.5882, Portfolio: $10,139.59, Epsilon: 0.4959
# Episode 19/100, Reward: 147.3645, Portfolio: $10,147.36, Epsilon: 0.4957
# Episode 20/100, Reward: 226.8651, Portfolio: $10,226.87, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 206.3309, Portfolio: $10,206.33, Epsilon: 0.4953
# Episode 22/100, Reward: 185.2690, Portfolio: $10,185.27, Epsilon: 0.4950
# Episode 23/100, Reward: 134.2190, Portfolio: $10,134.22, Epsilon: 0.4948
# Episode 24/100, Reward: 109.9076, Portfolio: $10,109.91, Epsilon: 0.4946
# Episode 25/100, Reward: 130.3361, Portfolio: $10,130.34, Epsilon: 0.4944
# Episode 26/100, Reward: 165.6062, Portfolio: $10,165.61, Epsilon: 0.4941
# Episode 27/100, Reward: 200.7524, Portfolio: $10,200.75, Epsilon: 0.4939
# Episode 28/100, Reward: 161.1591, Portfolio: $10,161.16, Epsilon: 0.4937
# Episode 29/100, Reward: 142.0092, Portfolio: $10,142.01, Epsilon: 0.4934
# Episode 30/100, Reward: 159.6492, Portfolio: $10,159.65, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 135.9238, Portfolio: $10,135.92, Epsilon: 0.4930
# Episode 32/100, Reward: 214.3166, Portfolio: $10,214.32, Epsilon: 0.4928
# Episode 33/100, Reward: 127.1533, Portfolio: $10,127.15, Epsilon: 0.4925
# Episode 34/100, Reward: 138.0551, Portfolio: $10,138.06, Epsilon: 0.4923
# Episode 35/100, Reward: 182.9327, Portfolio: $10,182.93, Epsilon: 0.4921
# Episode 36/100, Reward: 179.9707, Portfolio: $10,179.97, Epsilon: 0.4919
# Episode 37/100, Reward: 152.5109, Portfolio: $10,152.51, Epsilon: 0.4916
# Episode 38/100, Reward: 221.3781, Portfolio: $10,221.38, Epsilon: 0.4914
# Episode 39/100, Reward: 184.5556, Portfolio: $10,184.56, Epsilon: 0.4912
# Episode 40/100, Reward: 135.5265, Portfolio: $10,135.53, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 199.2623, Portfolio: $10,199.26, Epsilon: 0.4907
# Episode 42/100, Reward: 169.6303, Portfolio: $10,169.63, Epsilon: 0.4905
# Episode 43/100, Reward: 192.1369, Portfolio: $10,192.14, Epsilon: 0.4903
# Episode 44/100, Reward: 226.3054, Portfolio: $10,226.31, Epsilon: 0.4901
# Episode 45/100, Reward: 211.2036, Portfolio: $10,211.20, Epsilon: 0.4898
# Episode 46/100, Reward: 158.4348, Portfolio: $10,158.43, Epsilon: 0.4896
# Episode 47/100, Reward: 149.4756, Portfolio: $10,149.48, Epsilon: 0.4894
# Episode 48/100, Reward: 200.6768, Portfolio: $10,200.68, Epsilon: 0.4892
# Episode 49/100, Reward: 252.3836, Portfolio: $10,252.38, Epsilon: 0.4889
# Episode 50/100, Reward: 213.9624, Portfolio: $10,213.96, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 140.3780, Portfolio: $10,140.38, Epsilon: 0.4885
# Episode 52/100, Reward: 206.1963, Portfolio: $10,206.20, Epsilon: 0.4883
# Episode 53/100, Reward: 172.4787, Portfolio: $10,172.48, Epsilon: 0.4880
# Episode 54/100, Reward: 127.4962, Portfolio: $10,127.50, Epsilon: 0.4878
# Episode 55/100, Reward: 169.5637, Portfolio: $10,169.56, Epsilon: 0.4876
# Episode 56/100, Reward: 195.3489, Portfolio: $10,195.35, Epsilon: 0.4874
# Episode 57/100, Reward: 248.9878, Portfolio: $10,248.99, Epsilon: 0.4871
# Episode 58/100, Reward: 182.6024, Portfolio: $10,182.60, Epsilon: 0.4869
# Episode 59/100, Reward: 85.6201, Portfolio: $10,085.62, Epsilon: 0.4867
# Episode 60/100, Reward: 167.9054, Portfolio: $10,167.91, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 163.8524, Portfolio: $10,163.85, Epsilon: 0.4862
# Episode 62/100, Reward: 185.5197, Portfolio: $10,185.52, Epsilon: 0.4860
# Episode 63/100, Reward: 177.6808, Portfolio: $10,177.68, Epsilon: 0.4858
# Episode 64/100, Reward: 159.7238, Portfolio: $10,159.72, Epsilon: 0.4856
# Episode 65/100, Reward: 126.3757, Portfolio: $10,126.38, Epsilon: 0.4853
# Episode 66/100, Reward: 228.7618, Portfolio: $10,228.76, Epsilon: 0.4851
# Episode 67/100, Reward: 173.4534, Portfolio: $10,173.45, Epsilon: 0.4849
# Episode 68/100, Reward: 203.1646, Portfolio: $10,203.16, Epsilon: 0.4847
# Episode 69/100, Reward: 169.4661, Portfolio: $10,169.47, Epsilon: 0.4845
# Episode 70/100, Reward: 144.7454, Portfolio: $10,144.75, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 216.7153, Portfolio: $10,216.72, Epsilon: 0.4840
# Episode 72/100, Reward: 132.2828, Portfolio: $10,132.28, Epsilon: 0.4838
# Episode 73/100, Reward: 161.3703, Portfolio: $10,161.37, Epsilon: 0.4836
# Episode 74/100, Reward: 176.3822, Portfolio: $10,176.38, Epsilon: 0.4833
# Episode 75/100, Reward: 160.7775, Portfolio: $10,160.78, Epsilon: 0.4831
# Episode 76/100, Reward: 145.4381, Portfolio: $10,145.44, Epsilon: 0.4829
# Episode 77/100, Reward: 162.6436, Portfolio: $10,162.64, Epsilon: 0.4827
# Episode 78/100, Reward: 206.8479, Portfolio: $10,206.85, Epsilon: 0.4825
# Episode 79/100, Reward: 129.0869, Portfolio: $10,129.09, Epsilon: 0.4822
# Episode 80/100, Reward: 158.4427, Portfolio: $10,158.44, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 238.8750, Portfolio: $10,238.88, Epsilon: 0.4818
# Episode 82/100, Reward: 100.6941, Portfolio: $10,100.69, Epsilon: 0.4816
# Episode 83/100, Reward: 134.0713, Portfolio: $10,134.07, Epsilon: 0.4814
# Episode 84/100, Reward: 206.1880, Portfolio: $10,206.19, Epsilon: 0.4811
# Episode 85/100, Reward: 179.2589, Portfolio: $10,179.26, Epsilon: 0.4809
# Episode 86/100, Reward: 211.2863, Portfolio: $10,211.29, Epsilon: 0.4807
# Episode 87/100, Reward: 114.0881, Portfolio: $10,114.09, Epsilon: 0.4805
# Episode 88/100, Reward: 153.2397, Portfolio: $10,153.24, Epsilon: 0.4802
# Episode 89/100, Reward: 161.0727, Portfolio: $10,161.07, Epsilon: 0.4800
# Episode 90/100, Reward: 189.2916, Portfolio: $10,189.29, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 135.4022, Portfolio: $10,135.40, Epsilon: 0.4796
# Episode 92/100, Reward: 183.9465, Portfolio: $10,183.95, Epsilon: 0.4794
# Episode 93/100, Reward: 138.8546, Portfolio: $10,138.85, Epsilon: 0.4791
# Episode 94/100, Reward: 160.2506, Portfolio: $10,160.25, Epsilon: 0.4789
# Episode 95/100, Reward: 185.7826, Portfolio: $10,185.78, Epsilon: 0.4787
# Episode 96/100, Reward: 204.5656, Portfolio: $10,204.57, Epsilon: 0.4785
# Episode 97/100, Reward: 158.2932, Portfolio: $10,158.29, Epsilon: 0.4783
# Episode 98/100, Reward: 200.7406, Portfolio: $10,200.74, Epsilon: 0.4780
# Episode 99/100, Reward: 175.0680, Portfolio: $10,175.07, Epsilon: 0.4778
# Episode 100/100, Reward: 197.7341, Portfolio: $10,197.73, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# ...
# Episode 44/100, Reward: 137.1849, Portfolio: $10,137.18, Epsilon: 0.4901
# Episode 45/100, Reward: 165.5242, Portfolio: $10,165.52, Epsilon: 0.4898
# Episode 46/100, Reward: 101.6204, Portfolio: $10,101.62, Epsilon: 0.4896
# Episode 47/100, Reward: 201.7044, Portfolio: $10,201.70, Epsilon: 0.4894
# Episode 48/100, Reward: 109.3770, Portfolio: $10,109.38, Epsilon: 0.4892
# Episode 49/100, Reward: 59.5497, Portfolio: $10,059.55, Epsilon: 0.4889
# Episode 50/100, Reward: 136.8489, Portfolio: $10,136.85, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 166.6930, Portfolio: $10,166.69, Epsilon: 0.4885
# Episode 52/100, Reward: 102.3559, Portfolio: $10,102.36, Epsilon: 0.4883
# Episode 53/100, Reward: 152.7777, Portfolio: $10,152.78, Epsilon: 0.4880
# Episode 54/100, Reward: 114.7821, Portfolio: $10,114.78, Epsilon: 0.4878
# Episode 55/100, Reward: 192.2315, Portfolio: $10,192.23, Epsilon: 0.4876
# Episode 56/100, Reward: 132.2659, Portfolio: $10,132.27, Epsilon: 0.4874
# Episode 57/100, Reward: 88.7830, Portfolio: $10,088.78, Epsilon: 0.4871
# Episode 58/100, Reward: 157.8317, Portfolio: $10,157.83, Epsilon: 0.4869
# Episode 59/100, Reward: 173.1530, Portfolio: $10,173.15, Epsilon: 0.4867
# Episode 60/100, Reward: 160.5434, Portfolio: $10,160.54, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 242.5760, Portfolio: $10,242.58, Epsilon: 0.4862
# Episode 62/100, Reward: 128.7705, Portfolio: $10,128.77, Epsilon: 0.4860
# Episode 63/100, Reward: 173.9076, Portfolio: $10,173.91, Epsilon: 0.4858
# Episode 64/100, Reward: 132.1280, Portfolio: $10,132.13, Epsilon: 0.4856
# Episode 65/100, Reward: 134.6332, Portfolio: $10,134.63, Epsilon: 0.4853
# Episode 66/100, Reward: 115.4060, Portfolio: $10,115.41, Epsilon: 0.4851
# Episode 67/100, Reward: 92.8984, Portfolio: $10,092.90, Epsilon: 0.4849
# Episode 68/100, Reward: 95.6094, Portfolio: $10,095.61, Epsilon: 0.4847
# Episode 69/100, Reward: 196.6746, Portfolio: $10,196.67, Epsilon: 0.4845
# Episode 70/100, Reward: 228.0300, Portfolio: $10,228.03, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 96.9858, Portfolio: $10,096.99, Epsilon: 0.4840
# Episode 72/100, Reward: 98.7872, Portfolio: $10,098.79, Epsilon: 0.4838
# Episode 73/100, Reward: 137.1909, Portfolio: $10,137.19, Epsilon: 0.4836
# Episode 74/100, Reward: 93.1189, Portfolio: $10,093.12, Epsilon: 0.4833
# Episode 75/100, Reward: 107.0161, Portfolio: $10,107.02, Epsilon: 0.4831
# Episode 76/100, Reward: 114.4506, Portfolio: $10,114.45, Epsilon: 0.4829
# Episode 77/100, Reward: 99.6520, Portfolio: $10,099.65, Epsilon: 0.4827
# Episode 78/100, Reward: 164.0821, Portfolio: $10,164.08, Epsilon: 0.4825
# Episode 79/100, Reward: 159.8429, Portfolio: $10,159.84, Epsilon: 0.4822
# Episode 80/100, Reward: 154.5731, Portfolio: $10,154.57, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 178.7595, Portfolio: $10,178.76, Epsilon: 0.4818
# Episode 82/100, Reward: 192.0609, Portfolio: $10,192.06, Epsilon: 0.4816
# Episode 83/100, Reward: 91.9581, Portfolio: $10,091.96, Epsilon: 0.4814
# Episode 84/100, Reward: 70.8066, Portfolio: $10,070.81, Epsilon: 0.4811
# Episode 85/100, Reward: 109.3720, Portfolio: $10,109.37, Epsilon: 0.4809
# Episode 86/100, Reward: 96.3894, Portfolio: $10,096.39, Epsilon: 0.4807
# Episode 87/100, Reward: 127.6060, Portfolio: $10,127.61, Epsilon: 0.4805
# Episode 88/100, Reward: 164.7134, Portfolio: $10,164.71, Epsilon: 0.4802
# Episode 89/100, Reward: 128.2307, Portfolio: $10,128.23, Epsilon: 0.4800
# Episode 90/100, Reward: 171.0034, Portfolio: $10,171.00, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 165.7441, Portfolio: $10,165.74, Epsilon: 0.4796
# Episode 92/100, Reward: 162.8632, Portfolio: $10,162.86, Epsilon: 0.4794
# Episode 93/100, Reward: 143.5314, Portfolio: $10,143.53, Epsilon: 0.4791
# Episode 94/100, Reward: 132.9474, Portfolio: $10,132.95, Epsilon: 0.4789
# Episode 95/100, Reward: 207.2363, Portfolio: $10,207.24, Epsilon: 0.4787
# Episode 96/100, Reward: 190.2136, Portfolio: $10,190.21, Epsilon: 0.4785
# Episode 97/100, Reward: 95.5954, Portfolio: $10,095.60, Epsilon: 0.4783
# Episode 98/100, Reward: 175.9588, Portfolio: $10,175.96, Epsilon: 0.4780
# Episode 99/100, Reward: 60.5985, Portfolio: $10,060.60, Epsilon: 0.4778
# Episode 100/100, Reward: 180.9727, Portfolio: $10,180.97, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $10,029.38
# Total Return: 0.29%
# Total Trades Executed: 151
# Grid Levels: [104004.31 104089.35 104174.39 104259.43 104344.48 104429.52 104514.56
#  104599.6  104684.64 104769.68 104854.72 104939.76 105024.81 105109.85
#  105194.89 105279.93 105364.97 105450.01 105535.05]
# === Iteration 9 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 103.6600, Portfolio: $10,103.66, Epsilon: 0.4998
# Episode 2/100, Reward: 102.7297, Portfolio: $10,102.73, Epsilon: 0.4996
# Episode 3/100, Reward: 145.1053, Portfolio: $10,145.11, Epsilon: 0.4994
# Episode 4/100, Reward: 184.9164, Portfolio: $10,184.92, Epsilon: 0.4991
# Episode 5/100, Reward: 133.8742, Portfolio: $10,133.87, Epsilon: 0.4989
# Episode 6/100, Reward: 150.9048, Portfolio: $10,150.90, Epsilon: 0.4987
# Episode 7/100, Reward: 187.9623, Portfolio: $10,187.96, Epsilon: 0.4985
# Episode 8/100, Reward: 61.1283, Portfolio: $10,061.13, Epsilon: 0.4982
# Episode 9/100, Reward: 181.4309, Portfolio: $10,181.43, Epsilon: 0.4980
# Episode 10/100, Reward: 152.0932, Portfolio: $10,152.09, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 145.9188, Portfolio: $10,145.92, Epsilon: 0.4975
# Episode 12/100, Reward: 139.2159, Portfolio: $10,139.22, Epsilon: 0.4973
# Episode 13/100, Reward: 134.6002, Portfolio: $10,134.60, Epsilon: 0.4971
# Episode 14/100, Reward: 170.6806, Portfolio: $10,170.68, Epsilon: 0.4969
# Episode 15/100, Reward: 263.8611, Portfolio: $10,263.86, Epsilon: 0.4966
# Episode 16/100, Reward: 209.7599, Portfolio: $10,209.76, Epsilon: 0.4964
# Episode 17/100, Reward: 169.8116, Portfolio: $10,169.81, Epsilon: 0.4962
# Episode 18/100, Reward: 156.5751, Portfolio: $10,156.58, Epsilon: 0.4959
# Episode 19/100, Reward: 147.6251, Portfolio: $10,147.63, Epsilon: 0.4957
# Episode 20/100, Reward: 234.5995, Portfolio: $10,234.60, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 184.0383, Portfolio: $10,184.04, Epsilon: 0.4953
# Episode 22/100, Reward: 166.3162, Portfolio: $10,166.32, Epsilon: 0.4950
# Episode 23/100, Reward: 275.0343, Portfolio: $10,275.03, Epsilon: 0.4948
# Episode 24/100, Reward: 209.1515, Portfolio: $10,209.15, Epsilon: 0.4946
# Episode 25/100, Reward: 249.8630, Portfolio: $10,249.86, Epsilon: 0.4944
# Episode 26/100, Reward: 155.4853, Portfolio: $10,155.49, Epsilon: 0.4941
# Episode 27/100, Reward: 125.7819, Portfolio: $10,125.78, Epsilon: 0.4939
# Episode 28/100, Reward: 208.9009, Portfolio: $10,208.90, Epsilon: 0.4937
# Episode 29/100, Reward: 161.0908, Portfolio: $10,161.09, Epsilon: 0.4934
# Episode 30/100, Reward: 172.4778, Portfolio: $10,172.48, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 189.6361, Portfolio: $10,189.64, Epsilon: 0.4930
# Episode 32/100, Reward: 164.2083, Portfolio: $10,164.21, Epsilon: 0.4928
# Episode 33/100, Reward: 180.5410, Portfolio: $10,180.54, Epsilon: 0.4925
# Episode 34/100, Reward: 226.0726, Portfolio: $10,226.07, Epsilon: 0.4923
# Episode 35/100, Reward: 212.4422, Portfolio: $10,212.44, Epsilon: 0.4921
# Episode 36/100, Reward: 184.1697, Portfolio: $10,184.17, Epsilon: 0.4919
# Episode 37/100, Reward: 254.6229, Portfolio: $10,254.62, Epsilon: 0.4916
# Episode 38/100, Reward: 190.9407, Portfolio: $10,190.94, Epsilon: 0.4914
# Episode 39/100, Reward: 202.0537, Portfolio: $10,202.05, Epsilon: 0.4912
# Episode 40/100, Reward: 204.7123, Portfolio: $10,204.71, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 209.7659, Portfolio: $10,209.77, Epsilon: 0.4907
# Episode 42/100, Reward: 158.4253, Portfolio: $10,158.43, Epsilon: 0.4905
# Episode 43/100, Reward: 224.8892, Portfolio: $10,224.89, Epsilon: 0.4903
# Episode 44/100, Reward: 197.1289, Portfolio: $10,197.13, Epsilon: 0.4901
# Episode 45/100, Reward: 152.9995, Portfolio: $10,153.00, Epsilon: 0.4898
# Episode 46/100, Reward: 154.1781, Portfolio: $10,154.18, Epsilon: 0.4896
# Episode 47/100, Reward: 222.4756, Portfolio: $10,222.48, Epsilon: 0.4894
# Episode 48/100, Reward: 168.6589, Portfolio: $10,168.66, Epsilon: 0.4892
# Episode 49/100, Reward: 294.0379, Portfolio: $10,294.04, Epsilon: 0.4889
# Episode 50/100, Reward: 189.5824, Portfolio: $10,189.58, Epsilon: 0.4887
# Models saved successfully
# Episode 51/100, Reward: 190.8919, Portfolio: $10,190.89, Epsilon: 0.4885
# Episode 52/100, Reward: 160.4295, Portfolio: $10,160.43, Epsilon: 0.4883
# Episode 53/100, Reward: 84.1773, Portfolio: $10,084.18, Epsilon: 0.4880
# Episode 54/100, Reward: 213.8110, Portfolio: $10,213.81, Epsilon: 0.4878
# Episode 55/100, Reward: 103.0906, Portfolio: $10,103.09, Epsilon: 0.4876
# Episode 56/100, Reward: 137.8791, Portfolio: $10,137.88, Epsilon: 0.4874
# Episode 57/100, Reward: 205.2022, Portfolio: $10,205.20, Epsilon: 0.4871
# Episode 58/100, Reward: 251.6718, Portfolio: $10,251.67, Epsilon: 0.4869
# Episode 59/100, Reward: 192.7406, Portfolio: $10,192.74, Epsilon: 0.4867
# Episode 60/100, Reward: 138.8210, Portfolio: $10,138.82, Epsilon: 0.4865
# Models saved successfully
# Episode 61/100, Reward: 141.1005, Portfolio: $10,141.10, Epsilon: 0.4862
# Episode 62/100, Reward: 199.9313, Portfolio: $10,199.93, Epsilon: 0.4860
# Episode 63/100, Reward: 214.4201, Portfolio: $10,214.42, Epsilon: 0.4858
# Episode 64/100, Reward: 153.6654, Portfolio: $10,153.67, Epsilon: 0.4856
# Episode 65/100, Reward: 177.1167, Portfolio: $10,177.12, Epsilon: 0.4853
# Episode 66/100, Reward: 260.6656, Portfolio: $10,260.67, Epsilon: 0.4851
# Episode 67/100, Reward: 144.5284, Portfolio: $10,144.53, Epsilon: 0.4849
# Episode 68/100, Reward: 180.0526, Portfolio: $10,180.05, Epsilon: 0.4847
# Episode 69/100, Reward: 188.3427, Portfolio: $10,188.34, Epsilon: 0.4845
# Episode 70/100, Reward: 213.7674, Portfolio: $10,213.77, Epsilon: 0.4842
# Models saved successfully
# Episode 71/100, Reward: 150.2590, Portfolio: $10,150.26, Epsilon: 0.4840
# Episode 72/100, Reward: 158.8356, Portfolio: $10,158.84, Epsilon: 0.4838
# Episode 73/100, Reward: 209.3875, Portfolio: $10,209.39, Epsilon: 0.4836
# Episode 74/100, Reward: 174.1980, Portfolio: $10,174.20, Epsilon: 0.4833
# Episode 75/100, Reward: 85.7591, Portfolio: $10,085.76, Epsilon: 0.4831
# Episode 76/100, Reward: 132.1042, Portfolio: $10,132.10, Epsilon: 0.4829
# Episode 77/100, Reward: 236.5658, Portfolio: $10,236.57, Epsilon: 0.4827
# Episode 78/100, Reward: 187.4596, Portfolio: $10,187.46, Epsilon: 0.4825
# Episode 79/100, Reward: 275.3310, Portfolio: $10,275.33, Epsilon: 0.4822
# Episode 80/100, Reward: 183.2428, Portfolio: $10,183.24, Epsilon: 0.4820
# Models saved successfully
# Episode 81/100, Reward: 183.3237, Portfolio: $10,183.32, Epsilon: 0.4818
# Episode 82/100, Reward: 166.7405, Portfolio: $10,166.74, Epsilon: 0.4816
# Episode 83/100, Reward: 235.3491, Portfolio: $10,235.35, Epsilon: 0.4814
# Episode 84/100, Reward: 215.0550, Portfolio: $10,215.05, Epsilon: 0.4811
# Episode 85/100, Reward: 211.4068, Portfolio: $10,211.41, Epsilon: 0.4809
# Episode 86/100, Reward: 156.6662, Portfolio: $10,156.67, Epsilon: 0.4807
# Episode 87/100, Reward: 197.1400, Portfolio: $10,197.14, Epsilon: 0.4805
# Episode 88/100, Reward: 168.7662, Portfolio: $10,168.77, Epsilon: 0.4802
# Episode 89/100, Reward: 205.8310, Portfolio: $10,205.83, Epsilon: 0.4800
# Episode 90/100, Reward: 176.0152, Portfolio: $10,176.02, Epsilon: 0.4798
# Models saved successfully
# Episode 91/100, Reward: 197.3957, Portfolio: $10,197.40, Epsilon: 0.4796
# Episode 92/100, Reward: 222.5877, Portfolio: $10,222.59, Epsilon: 0.4794
# Episode 93/100, Reward: 143.3137, Portfolio: $10,143.31, Epsilon: 0.4791
# Episode 94/100, Reward: 170.8218, Portfolio: $10,170.82, Epsilon: 0.4789
# Episode 95/100, Reward: 128.7818, Portfolio: $10,128.78, Epsilon: 0.4787
# Episode 96/100, Reward: 143.7620, Portfolio: $10,143.76, Epsilon: 0.4785
# Episode 97/100, Reward: 227.1594, Portfolio: $10,227.16, Epsilon: 0.4783
# Episode 98/100, Reward: 287.0479, Portfolio: $10,287.05, Epsilon: 0.4780
# Episode 99/100, Reward: 176.5863, Portfolio: $10,176.59, Epsilon: 0.4778
# Episode 100/100, Reward: 202.2803, Portfolio: $10,202.28, Epsilon: 0.4776
# Models saved successfully
#
# Evaluating on test data...
#
# ==================================================
# Initial Balance: $10,000.00
# Final Portfolio Value: $9,995.39
# Total Return: -0.05%
# Total Trades Executed: 115
# Grid Levels: [104066.99 104148.73 104230.47 104312.21 104393.96 104475.7  104557.44
#  104639.18 104720.93 104802.67 104884.41 104966.15 105047.9  105129.64
#  105211.38 105293.12 105374.87 105456.61 105538.35]
# === Iteration 10 ===
# Training LSTM Price Predictor...
# loaded 95962.83333333333
#
# Training DQN Agent...
# Episode 1/100, Reward: 199.3434, Portfolio: $10,199.34, Epsilon: 0.4998
# Episode 2/100, Reward: 148.0223, Portfolio: $10,148.02, Epsilon: 0.4996
# Episode 3/100, Reward: 175.9359, Portfolio: $10,175.94, Epsilon: 0.4994
# Episode 4/100, Reward: 183.9682, Portfolio: $10,183.97, Epsilon: 0.4991
# Episode 5/100, Reward: 169.7474, Portfolio: $10,169.75, Epsilon: 0.4989
# Episode 6/100, Reward: 161.2676, Portfolio: $10,161.27, Epsilon: 0.4987
# Episode 7/100, Reward: 167.6303, Portfolio: $10,167.63, Epsilon: 0.4985
# Episode 8/100, Reward: 143.8206, Portfolio: $10,143.82, Epsilon: 0.4982
# Episode 9/100, Reward: 218.6402, Portfolio: $10,218.64, Epsilon: 0.4980
# Episode 10/100, Reward: 162.5774, Portfolio: $10,162.58, Epsilon: 0.4978
# Models saved successfully
# Episode 11/100, Reward: 104.1738, Portfolio: $10,104.17, Epsilon: 0.4975
# Episode 12/100, Reward: 228.7084, Portfolio: $10,228.71, Epsilon: 0.4973
# Episode 13/100, Reward: 255.1458, Portfolio: $10,255.15, Epsilon: 0.4971
# Episode 14/100, Reward: 59.0456, Portfolio: $10,059.05, Epsilon: 0.4969
# Episode 15/100, Reward: 80.8042, Portfolio: $10,080.80, Epsilon: 0.4966
# Episode 16/100, Reward: 67.3569, Portfolio: $10,067.36, Epsilon: 0.4964
# Episode 17/100, Reward: 165.0596, Portfolio: $10,165.06, Epsilon: 0.4962
# Episode 18/100, Reward: 141.3081, Portfolio: $10,141.31, Epsilon: 0.4959
# Episode 19/100, Reward: 88.4206, Portfolio: $10,088.42, Epsilon: 0.4957
# Episode 20/100, Reward: 165.7010, Portfolio: $10,165.70, Epsilon: 0.4955
# Models saved successfully
# Episode 21/100, Reward: 171.4036, Portfolio: $10,171.40, Epsilon: 0.4953
# Episode 22/100, Reward: 180.5469, Portfolio: $10,180.55, Epsilon: 0.4950
# Episode 23/100, Reward: 230.9472, Portfolio: $10,230.95, Epsilon: 0.4948
# Episode 24/100, Reward: 112.5904, Portfolio: $10,112.59, Epsilon: 0.4946
# Episode 25/100, Reward: 38.7982, Portfolio: $10,038.80, Epsilon: 0.4944
# Episode 26/100, Reward: 146.8561, Portfolio: $10,146.86, Epsilon: 0.4941
# Episode 27/100, Reward: 94.8317, Portfolio: $10,094.83, Epsilon: 0.4939
# Episode 28/100, Reward: 100.4438, Portfolio: $10,100.44, Epsilon: 0.4937
# Episode 29/100, Reward: 163.6148, Portfolio: $10,163.61, Epsilon: 0.4934
# Episode 30/100, Reward: 164.9148, Portfolio: $10,164.91, Epsilon: 0.4932
# Models saved successfully
# Episode 31/100, Reward: 195.0361, Portfolio: $10,195.04, Epsilon: 0.4930
# Episode 32/100, Reward: 42.8215, Portfolio: $10,042.82, Epsilon: 0.4928
# Episode 33/100, Reward: 84.9525, Portfolio: $10,084.95, Epsilon: 0.4925
# Episode 34/100, Reward: 140.9056, Portfolio: $10,140.91, Epsilon: 0.4923
# Episode 35/100, Reward: 152.9399, Portfolio: $10,152.94, Epsilon: 0.4921
# Episode 36/100, Reward: 99.8604, Portfolio: $10,099.86, Epsilon: 0.4919
# Episode 37/100, Reward: 218.3545, Portfolio: $10,218.35, Epsilon: 0.4916
# Episode 38/100, Reward: 152.0987, Portfolio: $10,152.10, Epsilon: 0.4914
# Episode 39/100, Reward: 208.3585, Portfolio: $10,208.36, Epsilon: 0.4912
# Episode 40/100, Reward: 206.8299, Portfolio: $10,206.83, Epsilon: 0.4910
# Models saved successfully
# Episode 41/100, Reward: 132.9983, Portfolio: $10,133.00, Epsilon: 0.4907

# %%
import os
import time
import schedule
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from binance.client import Client
from binance.exceptions import BinanceAPIException, BinanceOrderException
from collections import deque
import joblib # For loading scaler  

# --- Configuration (mostly from your Cell 1) ---
TICKER = 'BTCUSDT'
SEQ_LENGTH = 60
PREDICTION_STEPS = 1 # Not directly used in live state construction if LSTM predicts next price
INITIAL_BALANCE_REF = 10000.0 # Reference for normalization, actual balance managed live
TRADE_FEE_RATE = 0.0001 # For local simulation if needed, actual fees by Binance
MIN_TRADE_AMOUNT_USD = 10 # Minimum trade value in USD
GRID_COUNT = 100
LSTM_INPUT_FEATURES = 7 # open, high, low, close, volume, Returns, Volatility
DQN_STATE_SIZE = 11    # 7 market features + norm_balance + norm_btc_value + grid_pos + pred/price
ACTION_SIZE = 3        # Hold, Buy, Sell

# Live trading parameters
LIVE_RECALIBRATION_INTERVAL = 200 # Steps (minutes)
LIVE_LOOKBACK_WINDOW_GRID = 500 # Steps (minutes) for grid recalc
ORDER_TYPE = Client.ORDER_TYPE_MARKET

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device for live trading: {device}")

# --- Global State (Initialize once) ---
# These will be initialized in start_live_trading_bot()
binance_client = None
lstm_predictor_live = None
dqn_agent_live = None
min_max_scaler_live = None

# Portfolio and Grid State
current_usdt_balance = 1000.0 # Example: Starting USDT for live test
current_btc_held = 0.0
current_grid_levels = np.array([])
live_steps_since_recal = 0
live_recent_prices_for_grid = deque(maxlen=LIVE_LOOKBACK_WINDOW_GRID)

# --- Helper: Load your LSTMPredictor and DQN classes (copy from Cell 1) ---
# class LSTMPredictor(nn.Module): ... (already defined in your notebook)
# class DQN(nn.Module): ... (already defined in your notebook)
# class DQNAgent: ... (already defined in your notebook, we only need its model for acting)
# def create_grids(prices, num_grids=GRID_COUNT): ... (already defined)
# def get_binance_data(...): ... (already defined)

def initialize_live_trader():
    global binance_client, lstm_predictor_live, dqn_agent_live, min_max_scaler_live
    global current_grid_levels, current_usdt_balance, current_btc_held

    # 1. Initialize Binance Client (Testnet)

    api_key = 'OrR1dfYW9wa8pjjgfOrk5XhdICHZEwFvsKSCgmUgyGrFu7YMfvR2WBhbTMELu858'
    api_secret = 'JOENNjZJ7PWeVp6GbQBMcBJC95VzjlASitaeSVol1jIzjmIpnLXUWsganegbQZVE'
    if not api_key or not api_secret:
        print("FATAL: Binance Testnet API keys not found in environment variables.")
        return False
    binance_client = Client(api_key, api_secret, testnet=True)
    try:
        binance_client.ping()
        print("Binance Testnet client initialized and connected.")
    except Exception as e:
        print(f"Failed to connect to Binance Testnet: {e}")
        return False

    # 2. Load Scaler
    try:
        min_max_scaler_live = joblib.load('min_max_scaler.joblib')
        print("MinMaxScaler loaded successfully.")
    except FileNotFoundError:
        print("FATAL: min_max_scaler.joblib not found. Train model first to generate it.")
        return False
    except Exception as e:
        print(f"Error loading scaler: {e}")
        return False

    # 3. Load LSTM Predictor
    lstm_predictor_live = LSTMPredictor(input_size=LSTM_INPUT_FEATURES).to(device)
    try:
        lstm_predictor_live.load_state_dict(torch.load('lstm_predictor_fixed_grid.pth', map_location=device))
        lstm_predictor_live.eval()
        print("LSTM model loaded successfully.")
    except FileNotFoundError:
        print("FATAL: lstm_predictor_fixed_grid.pth not found.")
        return False
    except Exception as e:
        print(f"Error loading LSTM model: {e}")
        return False

    # 4. Load DQN Agent's Model
    # We need the DQNAgent class definition if not already available globally
    # For simplicity, we'll load the state_dict into a DQN model instance
    dqn_model_live = DQN(DQN_STATE_SIZE, ACTION_SIZE).to(device)
    try:
        # Assuming dqn_agent_fixed_grid.pth saves the model.state_dict()
        dqn_model_live.load_state_dict(torch.load('dqn_agent_fixed_grid.pth', map_location=device))
        dqn_model_live.eval()
        # Wrap it in a simple structure for the .act() method or use dqn_model_live directly
        class TempDQNAgent:
            def __init__(self, model):
                self.model = model
                self.action_size = model.fc3.out_features # Infer action_size
                self.epsilon = 0.0 # No exploration in live trading

            def act(self, state_tensor): # Expects a tensor
                if np.random.rand() <= self.epsilon:
                    return random.randrange(self.action_size)
                with torch.no_grad():
                    q_values = self.model(state_tensor)
                return torch.argmax(q_values).item()

        dqn_agent_live = TempDQNAgent(dqn_model_live)
        print("DQN model loaded successfully.")

    except FileNotFoundError:
        print("FATAL: dqn_agent_fixed_grid.pth not found.")
        return False
    except Exception as e:
        print(f"Error loading DQN model: {e}")
        return False

    # 5. Initialize Grids (fetch some recent data to base them on)
    print("Fetching initial data for grid setup...")
    initial_price_data = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback='200')
    if not initial_price_data.empty and len(initial_price_data) > 20:
        current_grid_levels = create_grids(initial_price_data['close'].values, GRID_COUNT)
        print(f"Initial grid levels created: {np.around(current_grid_levels[:5], 2)}... (first 5)")
        # Populate recent prices for adaptive grid
        for price in initial_price_data['close'].values[-(LIVE_LOOKBACK_WINDOW_GRID//2):]: # prime part of it
            live_recent_prices_for_grid.append(price)
    else:
        print("Could not fetch enough initial data for grid setup. Using default wide grids.")
        # Fallback grids if data fetch fails, adjust as needed
        avg_price_guess = 60000
        current_grid_levels = np.linspace(avg_price_guess * 0.8, avg_price_guess * 1.2, GRID_COUNT + 1)[1:-1]

    # Fetch initial balance from Testnet (optional, or use hardcoded start)
    # For this example, we use the hardcoded current_usdt_balance and current_btc_held
    print(f"Initial live trading balance: USDT: {current_usdt_balance}, BTC: {current_btc_held}")

    return True


def recalculate_grids_live(prices_list):
    """Recalculate grids based on recent price window for live trading."""
    if not prices_list or len(prices_list) < 50: # Need enough data
        return current_grid_levels # Return existing if not enough data
    
    recent_prices = np.array(prices_list)
    low = np.percentile(recent_prices, 10)
    high = np.percentile(recent_prices, 90)
    
    if high <= low: # Safety check
        print("Warning: Grid recalculation - high <= low. Widening range.")
        high = low * 1.05 # Ensure some spread
        if high == low : high = low + 100 # if low is 0 or very small

    new_grids = np.linspace(low, high, num=GRID_COUNT + 1)[1:-1]
    if len(new_grids) == 0: # another safety
        print("Warning: Grid recalculation resulted in empty grids. Keeping old ones.")
        return current_grid_levels
    return new_grids


def run_live_trading_cycle():
    global current_usdt_balance, current_btc_held, current_grid_levels
    global live_steps_since_recal, live_recent_prices_for_grid
    global lstm_predictor_live, dqn_agent_live, min_max_scaler_live, binance_client

    print(f"\n[{time.ctime()}] --- Running Live Trading Cycle ---")

    # 1. Fetch Market Data
    # Need SEQ_LENGTH for LSTM input + some buffer for feature calculation (e.g., rolling volatility)
    # The number of features for scaling is 7: 'open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility'
    required_klines = SEQ_LENGTH + 20 # 20 for rolling window of volatility
    df_live_raw = get_binance_data(symbol=TICKER, interval=Client.KLINE_INTERVAL_1MINUTE, lookback=str(required_klines))

    if df_live_raw.empty or len(df_live_raw) < required_klines:
        print("Not enough live data fetched. Skipping cycle.")
        return

    current_price = df_live_raw['close'].iloc[-1]
    live_recent_prices_for_grid.append(current_price)
    print(f"Current Price ({TICKER}): {current_price:.2f}")

    # 2. Preprocess Data for LSTM
    df_features = df_live_raw[['open', 'high', 'low', 'close', 'volume']].copy()
    df_features['Returns'] = df_features['close'].pct_change()
    df_features['Volatility'] = df_features['Returns'].rolling(window=20).std() # Match training
    df_features.dropna(inplace=True) # Remove NaNs from rolling calculations

    if len(df_features) < SEQ_LENGTH:
        print("Not enough data after feature engineering. Skipping cycle.")
        return

    # Select the exact features used for scaling during training
    features_to_scale = df_features[['open', 'high', 'low', 'close', 'volume', 'Returns', 'Volatility']]
    scaled_live_features = min_max_scaler_live.transform(features_to_scale)
    
    lstm_input_sequence = scaled_live_features[-SEQ_LENGTH:] # Shape: (SEQ_LENGTH, LSTM_INPUT_FEATURES)
    lstm_input_tensor = torch.tensor(lstm_input_sequence[np.newaxis, ...], dtype=torch.float32).to(device)

    # 3. Get LSTM Prediction
    with torch.no_grad():
        # Assuming LSTM predicts the next closing price (actual value, not scaled)
        # This needs to match how LSTM was trained and how its output was used in env.get_state()
        lstm_predicted_price = lstm_predictor_live(lstm_input_tensor).cpu().item()
    
    # The state uses prediction / price.
    # If LSTM output is already a price, this is fine.
    # If LSTM output is scaled, it needs to be inverse_transformed first.
    # Your LSTMPredictor outputs a single value, assumed to be the price prediction.
    normalized_lstm_prediction = lstm_predicted_price / current_price if current_price != 0 else 0
    print(f"LSTM Predicted Price: {lstm_predicted_price:.2f}, Normalized for state: {normalized_lstm_prediction:.4f}")

    # 4. Construct DQN State
    # Last tick of scaled data for the state
    current_scaled_market_data_tick = lstm_input_sequence[-1] 
    
    # Grid position
    if len(current_grid_levels) == 0: # Safety for uninitialized grids
        grid_position_live = 0.5 # Default to middle
    else:
        grid_position_live = np.digitize(current_price, current_grid_levels) / len(current_grid_levels) # Normalized
        grid_position_live = np.clip(grid_position_live, 0, 1) # Ensure it's within [0,1]


    # Normalize balance and holdings for the state
    # Using INITIAL_BALANCE_REF as the denominator for normalization consistency
    norm_balance = current_usdt_balance / INITIAL_BALANCE_REF
    norm_btc_value = (current_btc_held * current_price) / INITIAL_BALANCE_REF

    live_state_np = np.array([
        *current_scaled_market_data_tick,
        norm_balance,
        norm_btc_value,
        grid_position_live,
        normalized_lstm_prediction
    ], dtype=np.float32)

    if len(live_state_np) != DQN_STATE_SIZE:
        print(f"FATAL: Constructed state size {len(live_state_np)} != DQN_STATE_SIZE {DQN_STATE_SIZE}. Mismatch in features.")
        return

    live_state_tensor = torch.tensor(live_state_np, dtype=torch.float32).unsqueeze(0).to(device)

    # 5. Get DQN Action
    action = dqn_agent_live.act(live_state_tensor) # 0: hold, 1: buy, 2: sell
    action_map = {0: "HOLD", 1: "BUY", 2: "SELL"}
    print(f"DQN Action: {action_map[action]}")

    # 6. Execute Trade
    if action == 1:  # Buy
        # Logic adapted from your TradingEnvironment.step()
        # Buy more when price is near lower grids (grid_position_live close to 0)
        buy_multiplier = max(0.1, 1 - grid_position_live)
        # Example: allocate a percentage of balance based on multiplier, e.g., 5% of balance * multiplier
        # This is a simplification; your original code might have more complex sizing.
        # Ensure this is a dynamic part of your strategy.
        # Let's say we decide to use up to 10% of available USDT balance for a trade, scaled by multiplier
        max_spend_usd = current_usdt_balance * 0.10 
        amount_to_spend_usd = max_spend_usd * buy_multiplier
        
        if amount_to_spend_usd >= MIN_TRADE_AMOUNT_USD and current_usdt_balance >= amount_to_spend_usd :
            print(f"Attempting BUY: Spend {amount_to_spend_usd:.2f} USDT for {TICKER} at ~{current_price:.2f}")
            try:
                order = binance_client.create_order( # Use create_order for real testnet trades
                    symbol=TICKER,
                    side=Client.SIDE_BUY,
                    type=ORDER_TYPE,
                    quoteOrderQty=f"{amount_to_spend_usd:.8f}") # Binance API needs string for precision
                print(f"BUY Test Order successful: {order}")
                # For real orders, you'd update balance after confirmation:
                # current_usdt_balance -= actual_cost_from_order_fills
                # current_btc_held += actual_btc_bought_from_order_fills
            except BinanceAPIException as e:
                print(f"Binance API Exception (BUY): {e}")
            except Exception as e:
                print(f"Error executing BUY order: {e}")
        else:
            print(f"BUY condition not met: Spend amount {amount_to_spend_usd:.2f} < min OR insufficient balance.")

    elif action == 2:  # Sell
        # Sell more when price is near upper grids (grid_position_live close to 1)
        sell_multiplier = max(0.1, grid_position_live)
        # Example: sell a percentage of BTC holdings, e.g., 10% of holdings * multiplier
        max_sell_btc = current_btc_held * 0.10 
        amount_to_sell_btc = max_sell_btc * sell_multiplier
        
        value_of_btc_to_sell = amount_to_sell_btc * current_price
        if current_btc_held > 0 and amount_to_sell_btc > 0 and value_of_btc_to_sell >= MIN_TRADE_AMOUNT_USD:
             # Ensure quantity meets Binance minimums (e.g. for BTC often 0.00001, check symbol info)
            min_btc_qty_binance = 0.00001 # Example, fetch dynamically for robustness
            if amount_to_sell_btc < min_btc_qty_binance:
                print(f"SELL quantity {amount_to_sell_btc:.8f} BTC is below Binance minimum {min_btc_qty_binance:.8f} BTC.")
            else:
                print(f"Attempting SELL: {amount_to_sell_btc:.8f} {TICKER} at ~{current_price:.2f}")
                try:
                    order = binance_client.create_order( # Use create_order for real testnet trades
                        symbol=TICKER,
                        side=Client.SIDE_SELL,
                        type=ORDER_TYPE,
                        quantity=f"{amount_to_sell_btc:.8f}") # Binance API needs string for precision
                    print(f"SELL Test Order successful: {order}")
                    # For real orders, update balance:
                    # current_usdt_balance += actual_revenue_from_order_fills
                    # current_btc_held -= actual_btc_sold_from_order_fills
                except BinanceAPIException as e:
                    print(f"Binance API Exception (SELL): {e}")
                except Exception as e:
                    print(f"Error executing SELL order: {e}")
        else:
            print(f"SELL condition not met: Sell amount {amount_to_sell_btc:.8f} BTC (value {value_of_btc_to_sell:.2f} USD) too small or no BTC held.")
    
    print(f"Current Portfolio: USDT: {current_usdt_balance:.2f}, BTC: {current_btc_held:.8f}, Value: ~{(current_usdt_balance + current_btc_held * current_price):.2f} USDT")

    # 7. Adapt Grids Periodically
    live_steps_since_recal += 1
    if live_steps_since_recal >= LIVE_RECALIBRATION_INTERVAL:
        if len(live_recent_prices_for_grid) >= LIVE_LOOKBACK_WINDOW_GRID:
            print("Recalculating grid levels...")
            new_grids = recalculate_grids_live(list(live_recent_prices_for_grid))
            if not np.array_equal(new_grids, current_grid_levels) and len(new_grids) > 0:
                 current_grid_levels = new_grids
                 print(f"Grid levels adapted. New first 5: {np.around(current_grid_levels[:5], 2)}...")
            else:
                print("Grid levels unchanged or recalculation failed.")
            live_steps_since_recal = 0
        else:
            print(f"Not enough data in live_recent_prices_for_grid ({len(live_recent_prices_for_grid)}/{LIVE_LOOKBACK_WINDOW_GRID}) to adapt grids yet.")


def start_live_trading_bot():
    print("Initializing live trading bot...")
    if not initialize_live_trader():
        print("Bot initialization failed. Exiting.")
        return

    print("Live trading bot initialized. Starting 1-minute trading cycle.")
    print("Using TEST orders. For actual Testnet trades, change create_test_order to create_order.")
    print("Press Ctrl+C to stop the bot.")

    # Run the first cycle immediately
    run_live_trading_cycle() 
    
    # Schedule the job
    schedule.every(1).minutes.do(run_live_trading_cycle)

    while True:
        try:
            schedule.run_pending()
            time.sleep(1)
        except KeyboardInterrupt:
            print("\nStopping live trading bot...")
            break
        except Exception as e:
            print(f"An error occurred in the main loop: {e}")
            time.sleep(60) # Wait a bit before retrying if a major error occurs

# To run the bot:
start_live_trading_bot()

# %%
from binance.client import Client

api_key = 'OrR1dfYW9wa8pjjgfOrk5XhdICHZEwFvsKSCgmUgyGrFu7YMfvR2WBhbTMELu858'
api_secret = 'JOENNjZJ7PWeVp6GbQBMcBJC95VzjlASitaeSVol1jIzjmIpnLXUWsganegbQZVE'
client = Client(api_key, api_secret)
client.API_URL = 'https://testnet.binance.vision/api'

# Get current market price for BTC/USDT
ticker = client.get_symbol_ticker(symbol='BTCUSDT')
market_price = float(ticker['price'])

print(f"Current BTC/USDT Market Price: {market_price}")

# %%
usdt_to_spend = 10  # for example
quantity_to_buy = round(usdt_to_spend / market_price, 6)  # 6 decimal precision
print(f"Quantity of BTC to buy with ${usdt_to_spend}: {quantity_to_buy}")

# %%
client.order_market_buy(symbol='BTCUSDT', quantity=0.001)
client.order_market_sell(symbol='BTCUSDT', quantity=0.001)

# %%
client.order_market_buy(symbol='BTCUSDT', quoteOrderQty=100)
client.order_market_sell(symbol='BTCUSDT', quoteOrderQty=100)
